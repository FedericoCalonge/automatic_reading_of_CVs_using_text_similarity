# %% [markdown]
# ### Jupyter Notebook "2-TF_IDF_Cosine_&_Word2vec_WMD":
# * 3-Imports.
#      * 3.1-Import librerias necesarias.
#      * 3.2-Import de DFs del Jupyter Notebook anterior.
# * 4-División DFs para usarlos en los distintos cálculos y entrenamientos.
# * 5-Realizando Comparaciones y obteniendo Similitudes.
#      * 5.1- TF-IDF & Cosine Similarity.
#      * 5.2- Word Embedding (Word2vec) & WMD.
# * 6-Observación valores de Cosine Similarity y WMD.
#      * 6.1-Candidate 'Bradly Johnston (ML Engineer)'
#      * 6.2-Job 'Security Specialist 2'.
# * 7-Export del DF para usarlo en el siguiente Jupyter Notebook.

# %% [markdown]
# ### 3-Imports.

# %% [markdown]
# ### 3.1-Import librerias necesarias.

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

#Calculo de TFIDF y Cosine:
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import paired_cosine_distances as pcd

#Word2vec: 
import gensim
from gensim.models import Word2Vec

#Para medir tiempos de ejecución:
from datetime import datetime

# %% [markdown]
# ### 3.2-Import de DFs del Jupyter Notebook anterior.

# %%
df_Candidatos_loaded = pd.read_pickle('DF_624_CVs')
df_Candidatos_loaded.shape
# Out:
# (624, 3)

# %%
df_Candidatos_loaded.head()
# Out:
#                Candidate_Name  \
# 0   DataScientist_Karla_Lewis
# 1   DataScientist_Rahul_Malik
# 2        HCM_Federico_Calonge
# 3            HCM_Robert_Smith
# 4  MLEngineer_Bradly_Johnston
#
#                                     clean_Content_CV  \
# 0  data_scientist brooklyn ny data_scientist grub...
# 1  nlp data_scientist brooklyn ny nlp data_scient...
# 2  hcm technical consultant working oracle tool p...
# 3  sap_hcm consultant com qwikresume marshville r...
# 4  kasey vista detroit senior software_engineer m...
#
#                                    tokens_Content_CV
# 0  [data_scientist, brooklyn, ny, data_scientist,...
# 1  [nlp, data_scientist, brooklyn, ny, nlp, data_...
# 2  [hcm, technical, consultant, working, oracle, ...
# 3  [sap_hcm, consultant, com, qwikresume, marshvi...
# 4  [kasey, vista, detroit, senior, software_engin...

# %%
df_Jobs_loaded = pd.read_pickle('DF_20593_Job_Desc') # load
df_Jobs_loaded.shape
# Out:
# (20593, 3)

# %%
df_Jobs_loaded.head()
# Out:
#                    Job_Title  \
# 0             Data Scientist
# 1           Data Scientist 2
# 2             HCM Consultant
# 3           HCM Consultant 2
# 4  Machine Learning Engineer
#
#                                clean_Job_Description  \
# 0  master_degree stem field including_limited com...
# 1  reporting director data analytics senior data_...
# 2  oracle cloud hcm absence consultant responsibl...
# 3  peoplesoft oracle_eb implementation support hc...
# 4  leveraging_latest machine deep_learning techni...
#
#                               tokens_Job_Description
# 0  [master_degree, stem, field, including_limited...
# 1  [reporting, director, data, analytics, senior,...
# 2  [oracle, cloud, hcm, absence, consultant, resp...
# 3  [peoplesoft, oracle_eb, implementation, suppor...
# 4  [leveraging_latest, machine, deep_learning, te...

# %% [markdown]
# ### 4-División DFs para usarlos en los distintos cálculos y entrenamientos.

# %% [markdown]
# Los DFs enteros (**df_Candidatos_loaded** - 624 CVs) y (**df_Jobs_loaded** - 20593 Puestos de IT) serán utilizados para entrenar TF-IDF y los Word Embeddings con nuestro Corpus para el cálculo de Cosine SImilarity y WMD respectivamete.
#
# Luego definiremos 2 nuevos DFs para obtener los cálculos de WMD y Cosine Sim.; y para luego entrenar K-means y KNN:
#   * **df_Candidatos_modif** - 31 CVs.
#   * **df_Jobs_modif** - 101 Jobs Descriptions.
#
# Al realizar los cálculos compararemos cada CV con cada Job Description, obteniendo un dataframe total **df_compar_cand_jobs** de 3131 filas con sus respectivo valores de WMD y Cosine Sim.
#
# Por último eliminaremos 1 CV y 1 Job Description (un total de 131 filas) de **df_compar_cand_jobs**, estos los utilizaremos para clasificar nuevas muestras predeciendo con KNN.
#
# De esta manera nos quedará el **df_compar_cand_jobs** con 3000 filas / puntos para entrenar K-means y KNN.

# %% [markdown]
# #### 4.1-Creación de df_Candidatos_modif

# %%
df_Candidatos_modif = df_Candidatos_loaded.truncate(before=0, after=100)
df_Candidatos_modif
# Out:
#                  Candidate_Name  \
# 0     DataScientist_Karla_Lewis
# 1     DataScientist_Rahul_Malik
# 2          HCM_Federico_Calonge
# 3              HCM_Robert_Smith
# 4    MLEngineer_Bradly_Johnston
# ..                          ...
# 96                 Naveen Arora
# 97         Naveen Kumar Bandela
# 98              Naveen.S_Resume
# 99              Navneeth Resume
# 100               Neha Mugghala
#
#                                       clean_Content_CV  \
# 0    data_scientist brooklyn ny data_scientist grub...
# 1    nlp data_scientist brooklyn ny nlp data_scient...
# 2    hcm technical consultant working oracle tool p...
# 3    sap_hcm consultant com qwikresume marshville r...
# 4    kasey vista detroit senior software_engineer m...
# ..                                                 ...
# 96   naveen arora current location_chicago il visa ...
# 97   naveen kumar bandela java full_stack developer...
# 98   naveen looking contribute design analysis deve...
# 99   navneet gupta project program_manager pmp pmp_...
# 100  sourya senior java_ee developer working variou...
#
#                                      tokens_Content_CV
# 0    [data_scientist, brooklyn, ny, data_scientist,...
# 1    [nlp, data_scientist, brooklyn, ny, nlp, data_...
# 2    [hcm, technical, consultant, working, oracle, ...
# 3    [sap_hcm, consultant, com, qwikresume, marshvi...
# 4    [kasey, vista, detroit, senior, software_engin...
# ..                                                 ...
# 96   [naveen, arora, current, location_chicago, il,...
# 97   [naveen, kumar, bandela, java, full_stack, dev...
# 98   [naveen, looking, contribute, design, analysis...
# 99   [navneet, gupta, project, program_manager, pmp...
# 100  [sourya, senior, java_ee, developer, working, ...
#
# [101 rows x 3 columns]

# %% [markdown]
# #### 4.2-Creación de df_Jobs_modif

# %%
df_Jobs_modif = df_Jobs_loaded.truncate(before=0, after=30)
df_Jobs_modif
# Out:
#                                             Job_Title  \
# 0                                      Data Scientist
# 1                                    Data Scientist 2
# 2                                      HCM Consultant
# 3                                    HCM Consultant 2
# 4                           Machine Learning Engineer
# 5                         Machine Learning Engineer 2
# 6                                 Security Specialist
# 7                               Security Specialist 2
# 8                            Web Developer Full Stack
# 9                          Web Developer Full Stack 2
# 10                           AUTOMATION TEST ENGINEER
# 11                      Information Security Engineer
# 12                       Business Solutions Architect
# 13  Java Developer (mid level)- FT- GREAT culture,...
# 14                                    DevOps Engineer
# 15                                 SAP FICO Architect
# 16                                   Network Engineer
# 17  Sr. Web Application Developer (Cloud Team) - C...
# 18                                Front End Developer
# 19                       Application Support Engineer
# 20                         OpenStack Engineer - 12185
# 21      9001 Data Security Administrator - Unix & IAM
# 22                          Software Engineer Manager
# 23                        Sales Engineer - Los Angles
# 24                                    Project Manager
# 25                       Windows System Administrator
# 26                           Test Lead / Test Manager
# 27  Principal Application Analyst-Supply Chain Lawson
# 28                            Messaging Administrator
# 29             Java Architect - Denver, CO - Fulltime
# 30                                IT Business Analyst
#
#                                 clean_Job_Description  \
# 0   master_degree stem field including_limited com...
# 1   reporting director data analytics senior data_...
# 2   oracle cloud hcm absence consultant responsibl...
# 3   peoplesoft oracle_eb implementation support hc...
# 4   leveraging_latest machine deep_learning techni...
# 5   collaborate multidisciplinary_team gain_insigh...
# 6   fast_paced environment combine technical secur...
# 7   handling incoming_request assistance business ...
# 8   graduate_degree information technology similar...
# 9   enter existing codebases extend functionality ...
# 10  looking selenium engineer must solid java codi...
# 11  university chicago rapidly_growing security pr...
# 12  galaxe_solutionsevery day solution affect_peop...
# 13  java developerfull time direct hirebolingbrook...
# 14  midtown based high tech firm immediate innovat...
# 15  looking senior sap_fico architect join_u fullt...
# 16  network engineer description network engineer ...
# 17  bluebeam looking_talented sr web developer pas...
# 18  fulltime_position javascript developer financi...
# 19  summaryour_client leading_provider online vide...
# 20  description senior member team responsible pro...
# 21  must unix iam identity_access management scrip...
# 22  vanderhouwen_job like find please join talent ...
# 23  genesis currently_seeking sale engineer steel ...
# 24  vanderhouwen_job like find please join talent ...
# 25  window system administrator window system admi...
# 26  location_atlanta gajob title test lead manager...
# 27  vanderhouwen_job like find please join talent ...
# 28  genesis actively_seeking messaging administrat...
# 29  client healthcare software industry seeking ja...
# 30  genesis looking business analyst long_term con...
#
#                                tokens_Job_Description
# 0   [master_degree, stem, field, including_limited...
# 1   [reporting, director, data, analytics, senior,...
# 2   [oracle, cloud, hcm, absence, consultant, resp...
# 3   [peoplesoft, oracle_eb, implementation, suppor...
# 4   [leveraging_latest, machine, deep_learning, te...
# 5   [collaborate, multidisciplinary_team, gain_ins...
# 6   [fast_paced, environment, combine, technical, ...
# 7   [handling, incoming_request, assistance, busin...
# 8   [graduate_degree, information, technology, sim...
# 9   [enter, existing, codebases, extend, functiona...
# 10  [looking, selenium, engineer, must, solid, jav...
# 11  [university, chicago, rapidly_growing, securit...
# 12  [galaxe_solutionsevery, day, solution, affect_...
# 13  [java, developerfull, time, direct, hireboling...
# 14  [midtown, based, high, tech, firm, immediate, ...
# 15  [looking, senior, sap_fico, architect, join_u,...
# 16  [network, engineer, description, network, engi...
# 17  [bluebeam, looking_talented, sr, web, develope...
# 18  [fulltime_position, javascript, developer, fin...
# 19  [summaryour_client, leading_provider, online, ...
# 20  [description, senior, member, team, responsibl...
# 21  [must, unix, iam, identity_access, management,...
# 22  [vanderhouwen_job, like, find, please, join, t...
# 23  [genesis, currently_seeking, sale, engineer, s...
# 24  [vanderhouwen_job, like, find, please, join, t...
# 25  [window, system, administrator, window, system...
# 26  [location_atlanta, gajob, title, test, lead, m...
# 27  [vanderhouwen_job, like, find, please, join, t...
# 28  [genesis, actively_seeking, messaging, adminis...
# 29  [client, healthcare, software, industry, seeki...
# 30  [genesis, looking, business, analyst, long_ter...

# %% [markdown]
# ###  5-Realizando Comparaciones y obteniendo Similitudes.

# %% [markdown]
# ###### Creamos un nuevo DF concatenando los 2 dataframe de manera que se comparen todos los CVs con todos los Jobs:

# %%
df_compar_cand_jobs = pd.merge(df_Candidatos_modif.assign(A=1), df_Jobs_modif.assign(A=1), on='A').drop('A', 1)
df_compar_cand_jobs
# Out:
# <ipython-input-71-8d861a22d867>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_compar_cand_jobs = pd.merge(df_Candidatos_modif.assign(A=1), df_Jobs_modif.assign(A=1), on='A').drop('A', 1)
#                  Candidate_Name  \
# 0     DataScientist_Karla_Lewis
# 1     DataScientist_Karla_Lewis
# 2     DataScientist_Karla_Lewis
# 3     DataScientist_Karla_Lewis
# 4     DataScientist_Karla_Lewis
# ...                         ...
# 3126              Neha Mugghala
# 3127              Neha Mugghala
# 3128              Neha Mugghala
# 3129              Neha Mugghala
# 3130              Neha Mugghala
#
#                                        clean_Content_CV  \
# 0     data_scientist brooklyn ny data_scientist grub...
# 1     data_scientist brooklyn ny data_scientist grub...
# 2     data_scientist brooklyn ny data_scientist grub...
# 3     data_scientist brooklyn ny data_scientist grub...
# 4     data_scientist brooklyn ny data_scientist grub...
# ...                                                 ...
# 3126  sourya senior java_ee developer working variou...
# 3127  sourya senior java_ee developer working variou...
# 3128  sourya senior java_ee developer working variou...
# 3129  sourya senior java_ee developer working variou...
# 3130  sourya senior java_ee developer working variou...
#
#                                       tokens_Content_CV  \
# 0     [data_scientist, brooklyn, ny, data_scientist,...
# 1     [data_scientist, brooklyn, ny, data_scientist,...
# 2     [data_scientist, brooklyn, ny, data_scientist,...
# 3     [data_scientist, brooklyn, ny, data_scientist,...
# 4     [data_scientist, brooklyn, ny, data_scientist,...
# ...                                                 ...
# 3126  [sourya, senior, java_ee, developer, working, ...
# 3127  [sourya, senior, java_ee, developer, working, ...
# 3128  [sourya, senior, java_ee, developer, working, ...
# 3129  [sourya, senior, java_ee, developer, working, ...
# 3130  [sourya, senior, java_ee, developer, working, ...
#
#                                               Job_Title  \
# 0                                        Data Scientist
# 1                                      Data Scientist 2
# 2                                        HCM Consultant
# 3                                      HCM Consultant 2
# 4                             Machine Learning Engineer
# ...                                                 ...
# 3126                           Test Lead / Test Manager
# 3127  Principal Application Analyst-Supply Chain Lawson
# 3128                            Messaging Administrator
# 3129             Java Architect - Denver, CO - Fulltime
# 3130                                IT Business Analyst
#
#                                   clean_Job_Description  \
# 0     master_degree stem field including_limited com...
# 1     reporting director data analytics senior data_...
# 2     oracle cloud hcm absence consultant responsibl...
# 3     peoplesoft oracle_eb implementation support hc...
# 4     leveraging_latest machine deep_learning techni...
# ...                                                 ...
# 3126  location_atlanta gajob title test lead manager...
# 3127  vanderhouwen_job like find please join talent ...
# 3128  genesis actively_seeking messaging administrat...
# 3129  client healthcare software industry seeking ja...
# 3130  genesis looking business analyst long_term con...
#
#                                  tokens_Job_Description
# 0     [master_degree, stem, field, including_limited...
# 1     [reporting, director, data, analytics, senior,...
# 2     [oracle, cloud, hcm, absence, consultant, resp...
# 3     [peoplesoft, oracle_eb, implementation, suppor...
# 4     [leveraging_latest, machine, deep_learning, te...
# ...                                                 ...
# 3126  [location_atlanta, gajob, title, test, lead, m...
# 3127  [vanderhouwen_job, like, find, please, join, t...
# 3128  [genesis, actively_seeking, messaging, adminis...
# 3129  [client, healthcare, software, industry, seeki...
# 3130  [genesis, looking, business, analyst, long_ter...
#
# [3131 rows x 6 columns]

# %% [markdown]
# ### 5.1- TF-IDF & Cosine Similarity.

# %% [markdown]
# #### Definimos los vectores que utilizaremos para entrenar y evaluar TF-IDF / Cosine Sim:

# %%
#Para entrenar tf-idf usamos todo nuestro Corpus:
array_unicode_CV_train   = df_Candidatos_loaded['clean_Content_CV'].astype('U').values
array_unicode_Jobs_train = df_Jobs_loaded['clean_Job_Description'].astype('U').values

print(len(array_unicode_CV_train))
print(array_unicode_CV_train[0])       #Primer valor de la lista.
print(len(array_unicode_Jobs_train))
print(array_unicode_Jobs_train[20592]) #Último valor de la lista.

#Juntamos los vectores:
array_CV_and_Jobs_train = np.concatenate((array_unicode_CV_train, array_unicode_Jobs_train)) #np = numpy.
print(len(array_CV_and_Jobs_train)) 

print('###################################################################################')

#Y para transform usamos únicamente los que queremos evaluar:
array_unicode_CV_transf   = df_compar_cand_jobs['clean_Content_CV'].astype('U').values
array_unicode_Jobs_transf = df_compar_cand_jobs['clean_Job_Description'].astype('U').values
print(len(array_unicode_CV_transf))
print(len(array_unicode_Jobs_transf))
# Out:
# 624
# data_scientist brooklyn ny data_scientist grubhub current new_york ny implemented various time_series forecasting technique predict surge customer order lower average customer wait time minute github deployed recommendation engine production conditionally recommend menu item based past order history increase average order size designed model portland pilot program increase incentive driver peak ordering hour resulting_increase driver availability peak ordering time statistic rutgers university data_scientist new brunswick_nj adobe new_york ny worked product marketing team identify customer interaction free trial maximize likelihood conversion resulting conversion_rate increase built customer attrition random forest model improved monthly python numpy_panda scikit_learn retention basis point customer likely attrit kera flask servicing relevant product feature sql mysql postgres worked_closely product team build production git recommendation engine python improved average length user resulted incremental annual_revenue time_series forecasting productionizing model recommendation engine data analyst customer segmentation adobe new_york ny aws worked product manager perform cohort analysis identiﬁed opportunity reduce pricing segment user boost yearly revenue built operational reporting tableau ﬁnd area improvement contractor resulting annual incremental revenue implemented long_term pricing experiment improved customer lifetime value
# 20593
# c_c programmingdevelopment win programming win xp must using debugger windbgexperience window kernel mode driver good problem_solver good analysis mandatory win programming expertc c programming expertwindbg debugging good knowledge
# 21217
# ###################################################################################
# 3131
# 3131

# %%
#Exportamos el DF de 3131 filas + estos 3 vectores para usarlos como ejemplo en '2.1-Entrenamiento de TF-IDF & Cosine para 4 ejemplos':

#type(array_unicode_CV_transf)  #type(array_unicode_CV_transf)

df_compar_cand_jobs.to_pickle('DF_Exportado_Jobs_And_CVs_Para2_1')   #DF de CVs y Descripciones de Puestos para agregar columna 'tfidf_cosine' una vez aplicado TF-IDF y Cosine Sim.
np.save('array_CV_and_Jobs_train.npy', array_CV_and_Jobs_train)      #vector de CVs y Descripciones de Puestos para entrenar TF-IDF.
np.save('array_unicode_CV_transf.npy', array_unicode_CV_transf)      #vector de CVs para aplicar Cosine Sim.
np.save('array_unicode_Jobs_transf.npy', array_unicode_Jobs_transf)  #vector de Descripciones de Puestos para aplicar Cosine Sim.

# %% [markdown]
# #### Entrenamos TF-IDF y lo aplicamos junto a Cosine Sim

# %%
#https://www.py4u.net/discuss/188191
    
#Ahora calcularemos cosine similarity usando vectores tf-idf entre 'search queries' y 'matched documents'.
#Mi 'search query' es la columna de clean_content_CV y el 'matched documents' son los clean_Job_Description.
    #Al hacer el FIT entrenamos nuestro modelo con los cvs y job descriptions. Este modelo luego lo usaremos 
    #al hacer el TRANSFORM donde le pasamos la query para que se fije los TF-IDF que tiene ya entrenados del modelo. 

#VEr imports:
    #TfidfVectorizer
    #pcd  (cosine)

# Inicializamos una instancia de tf-idf Vectorizer:
tfidf_vectorizer = TfidfVectorizer()

start_time_fit = datetime.now()

# Generamos los vectores tf-idf para el Corpus:
tfidf_vectorizer.fit(array_CV_and_Jobs_train)             #array_CV_and_Jobs_train obtenido en la celda anterior.

end_time_fit = datetime.now()
print('Duration train tf-idf: {}'.format(end_time_fit - start_time_fit))
# Out:
# Duration train tf-idf: 0:00:03.847551

# %%
###AGREGADO AHORA###
#Vemos los vectores TF-IDF obtenidos:

tfidf_vectorizer
print(tfidf_vectorizer.get_feature_names())    
print(tfidf_vectorizer.shape)

#from sklearn.feature_extraction.text import TfidfVectorizer
#import pandas as pd

#vect = TfidfVectorizer()
#tfidf_matrix = vect.fit_transform(array_CV_and_Jobs_train)
#df = pd.DataFrame(tfidf_matrix.toarray(), columns = vect.get_feature_names())
#print(df)
# Out:
# ['__', '_____', '______', '________', '_________', '__________', '___________', '______________', '_______________', '________________', '___________________', '_____________________', '________________________', '__________________________', '___________________________', '____________________________________', '______________________________________', '__________________________________________', '___________________________________________', '____________________________________________', '_________________________________________________________________', '__________________________________________________________________', '___________________________________________________________________', '_______________________________________________________________________', '_______________________________________________________________________________', '________________________________________________________________________________', '___________________________________________________________________________________________', '____________________________________________________________________________________________', '__________________________________________________________________________________________________', '______________________________________________________________________________________________________', '_______________________________________________________________________________________________________________', '_______________________________________________________________________________________________________________________________', '____________________________________________________________________________________________________________________________________', '______________________________________________________________________________________________________________________________________________________________', '__________________________________________________________________________________________________________________________________________________________________________________________', '________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________', '_____________________________________________________________________________________________________________________________________________________________________________miracle', '_______________________________________________________________________________________________________________________________________required', '____________________________________________________________________________________________position', '__________________________________________________________________________________________front', '_______________________________________________________________________________________suneel', '_____________________________________________________________________________________position', '____________________________________________________________________________________amick', '____________________________________________________________________________________excellen ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-ed981ca91b6d> in <module>
#       4 tfidf_vectorizer
#       5 print(tfidf_vectorizer.get_feature_names())
# ----> 6 print(tfidf_vectorizer.shape)
#       7
#       8 #from sklearn.feature_extraction.text import TfidfVectorizer
#
# AttributeError: 'TfidfVectorizer' object has no attribute 'shape'

# %%
###AGREGADO AHORA###

feature_names = tfidf.get_feature_names()
corpus_index = [n for n in corpus]
import pandas as pd
df = pd.DataFrame(tfs.T.todense(), index=feature_names, columns=corpus_index)
print(df)

# %%
#Calculamos cosine similarity:
    #Parametros de pcd:
        #Xarray-like of shape (n_samples, n_features)
        #Yarray-like of shape (n_samples, n_features)
    #Retorna:
        #distancesndarray of shape (n_samples,)

start_time_cosine = datetime.now()

A = tfidf_vectorizer.transform(array_unicode_CV_transf)   #array_unicode_CV_transf obtenido en la celda anterior. 
B = tfidf_vectorizer.transform(array_unicode_Jobs_transf) #array_unicode_Jobs_transf obtenido en la celda anterior. 

cosine = 1 - pcd(A, B)   #array de tamaño n_samples
df_compar_cand_jobs['tfidf_cosine'] = cosine

end_time_cosine = datetime.now()
print('Duration cosine: {}'.format(end_time_cosine - start_time_cosine))

df_compar_cand_jobs
# Out:
# Duration cosine: 0:00:03.854675
#                  Candidate_Name  \
# 0     DataScientist_Karla_Lewis
# 1     DataScientist_Karla_Lewis
# 2     DataScientist_Karla_Lewis
# 3     DataScientist_Karla_Lewis
# 4     DataScientist_Karla_Lewis
# ...                         ...
# 3126              Neha Mugghala
# 3127              Neha Mugghala
# 3128              Neha Mugghala
# 3129              Neha Mugghala
# 3130              Neha Mugghala
#
#                                        clean_Content_CV  \
# 0     data_scientist brooklyn ny data_scientist grub...
# 1     data_scientist brooklyn ny data_scientist grub...
# 2     data_scientist brooklyn ny data_scientist grub...
# 3     data_scientist brooklyn ny data_scientist grub...
# 4     data_scientist brooklyn ny data_scientist grub...
# ...                                                 ...
# 3126  sourya senior java_ee developer working variou...
# 3127  sourya senior java_ee developer working variou...
# 3128  sourya senior java_ee developer working variou...
# 3129  sourya senior java_ee developer working variou...
# 3130  sourya senior java_ee developer working variou...
#
#                                       tokens_Content_CV  \
# 0     [data_scientist, brooklyn, ny, data_scientist,...
# 1     [data_scientist, brooklyn, ny, data_scientist,...
# 2     [data_scientist, brooklyn, ny, data_scientist,...
# 3     [data_scientist, brooklyn, ny, data_scientist,...
# 4     [data_scientist, brooklyn, ny, data_scientist,...
# ...                                                 ...
# 3126  [sourya, senior, java_ee, developer, working, ...
# 3127  [sourya, senior, java_ee, developer, working, ...
# 3128  [sourya, senior, java_ee, developer, working, ...
# 3129  [sourya, senior, java_ee, developer, working, ...
# 3130  [sourya, senior, java_ee, developer, working, ...
#
#                                               Job_Title  \
# 0                                        Data Scientist
# 1                                      Data Scientist 2
# 2                                        HCM Consultant
# 3                                      HCM Consultant 2
# 4                             Machine Learning Engineer
# ...                                                 ...
# 3126                           Test Lead / Test Manager
# 3127  Principal Application Analyst-Supply Chain Lawson
# 3128                            Messaging Administrator
# 3129             Java Architect - Denver, CO - Fulltime
# 3130                                IT Business Analyst
#
#                                   clean_Job_Description  \
# 0     master_degree stem field including_limited com...
# 1     reporting director data analytics senior data_...
# 2     oracle cloud hcm absence consultant responsibl...
# 3     peoplesoft oracle_eb implementation support hc...
# 4     leveraging_latest machine deep_learning techni...
# ...                                                 ...
# 3126  location_atlanta gajob title test lead manager...
# 3127  vanderhouwen_job like find please join talent ...
# 3128  genesis actively_seeking messaging administrat...
# 3129  client healthcare software industry seeking ja...
# 3130  genesis looking business analyst long_term con...
#
#                                  tokens_Job_Description  tfidf_cosine
# 0     [master_degree, stem, field, including_limited...      0.042817
# 1     [reporting, director, data, analytics, senior,...      0.111344
# 2     [oracle, cloud, hcm, absence, consultant, resp...      0.018021
# 3     [peoplesoft, oracle_eb, implementation, suppor...      0.013100
# 4     [leveraging_latest, machine, deep_learning, te...      0.050443
# ...                                                 ...           ...
# 3126  [location_atlanta, gajob, title, test, lead, m...      0.025742
# 3127  [vanderhouwen_job, like, find, please, join, t...      0.105683
# 3128  [genesis, actively_seeking, messaging, adminis...      0.063452
# 3129  [client, healthcare, software, industry, seeki...      0.080821
# 3130  [genesis, looking, business, analyst, long_ter...      0.067010
#
# [3131 rows x 7 columns]

# %%
df_compar_cand_jobs['Job_Title'].nunique()
# Out:
# 31

# %%
A
# Out:
# <3131x124141 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2112402 stored elements in Compressed Sparse Row format>

# %%
#Vocabulario:
feature_names = tfidf_vectorizer.get_feature_names()
len(feature_names)
# Out:
# 124141

# %%
doc = 0
feature_index = tfidf_matrix[doc,:].nonzero()[1]
tfidf_scores = zip(feature_index, [tfidf_matrix[doc, x] for x in feature_index])

Lets print them,

for w, s in [(feature_names[i], s) for (i, s) in tfidf_scores]:
  print w, s

# %%
#Vemos por ejemplo los valores para el Candidato 'MLEngineer_Bradly_Johnston':

is_Bradly_Johnston =  df_compar_cand_jobs['Candidate_Name']=='MLEngineer_Bradly_Johnston'
new_DF = df_compar_cand_jobs[is_Bradly_Johnston]
print(new_DF.shape)
new_DF.head(10)
# Out:
# (31, 7)
#                  Candidate_Name  \
# 124  MLEngineer_Bradly_Johnston
# 125  MLEngineer_Bradly_Johnston
# 126  MLEngineer_Bradly_Johnston
# 127  MLEngineer_Bradly_Johnston
# 128  MLEngineer_Bradly_Johnston
# 129  MLEngineer_Bradly_Johnston
# 130  MLEngineer_Bradly_Johnston
# 131  MLEngineer_Bradly_Johnston
# 132  MLEngineer_Bradly_Johnston
# 133  MLEngineer_Bradly_Johnston
#
#                                       clean_Content_CV  \
# 124  kasey vista detroit senior software_engineer m...
# 125  kasey vista detroit senior software_engineer m...
# 126  kasey vista detroit senior software_engineer m...
# 127  kasey vista detroit senior software_engineer m...
# 128  kasey vista detroit senior software_engineer m...
# 129  kasey vista detroit senior software_engineer m...
# 130  kasey vista detroit senior software_engineer m...
# 131  kasey vista detroit senior software_engineer m...
# 132  kasey vista detroit senior software_engineer m...
# 133  kasey vista detroit senior software_engineer m...
#
#                                      tokens_Content_CV  \
# 124  [kasey, vista, detroit, senior, software_engin...
# 125  [kasey, vista, detroit, senior, software_engin...
# 126  [kasey, vista, detroit, senior, software_engin...
# 127  [kasey, vista, detroit, senior, software_engin...
# 128  [kasey, vista, detroit, senior, software_engin...
# 129  [kasey, vista, detroit, senior, software_engin...
# 130  [kasey, vista, detroit, senior, software_engin...
# 131  [kasey, vista, detroit, senior, software_engin...
# 132  [kasey, vista, detroit, senior, software_engin...
# 133  [kasey, vista, detroit, senior, software_engin...
#
#                        Job_Title  \
# 124               Data Scientist
# 125             Data Scientist 2
# 126               HCM Consultant
# 127             HCM Consultant 2
# 128    Machine Learning Engineer
# 129  Machine Learning Engineer 2
# 130          Security Specialist
# 131        Security Specialist 2
# 132     Web Developer Full Stack
# 133   Web Developer Full Stack 2
#
#                                  clean_Job_Description  \
# 124  master_degree stem field including_limited com...
# 125  reporting director data analytics senior data_...
# 126  oracle cloud hcm absence consultant responsibl...
# 127  peoplesoft oracle_eb implementation support hc...
# 128  leveraging_latest machine deep_learning techni...
# 129  collaborate multidisciplinary_team gain_insigh...
# 130  fast_paced environment combine technical secur...
# 131  handling incoming_request assistance business ...
# 132  graduate_degree information technology similar...
# 133  enter existing codebases extend functionality ...
#
#                                 tokens_Job_Description  tfidf_cosine
# 124  [master_degree, stem, field, including_limited...      0.159509
# 125  [reporting, director, data, analytics, senior,...      0.313058
# 126  [oracle, cloud, hcm, absence, consultant, resp...      0.041684
# 127  [peoplesoft, oracle_eb, implementation, suppor...      0.039275
# 128  [leveraging_latest, machine, deep_learning, te...      0.246166
# 129  [collaborate, multidisciplinary_team, gain_ins...      0.325581
# 130  [fast_paced, environment, combine, technical, ...      0.038583
# 131  [handling, incoming_request, assistance, busin...      0.025728
# 132  [graduate_degree, information, technology, sim...      0.035656
# 133  [enter, existing, codebases, extend, functiona...      0.053284

# %% [markdown]
# ### 5.2- Word Embedding (Word2vec) & WMD.

# %% [markdown]
# #### Usamos un Word2vec entrenado con nuestro Corpus.

# %% [markdown]
# #### Unimos las columnas 'tokens_Job_Description' de 'df_Jobs_loaded' y 'tokens_Content_CV' de 'df_Candidatos_loaded' generando una lista de listas, la cual será nuestro Corpus que introduciremos a Word Embedding como entrenamiento:

# %%
corpus_token_jobs = df_Jobs_loaded['tokens_Job_Description']

# %%
corpus_token_jobs
# Out:
# 0        [master_degree, stem, field, including_limited...
# 1        [reporting, director, data, analytics, senior,...
# 2        [oracle, cloud, hcm, absence, consultant, resp...
# 3        [peoplesoft, oracle_eb, implementation, suppor...
# 4        [leveraging_latest, machine, deep_learning, te...
#                                ...
# 20588    [company, description, searching, talented, cr...
# 20589    [location_san, francisco, caterm, full_time, p...
# 20590    [take_pride, knowing, thousand, life, positive...
# 20591    [company, description, offer, youas, world_lea...
# 20592    [c_c, programmingdevelopment, win, programming...
# Name: tokens_Job_Description, Length: 20593, dtype: object

# %%
corpus_token_cvs = df_Candidatos_loaded['tokens_Content_CV']
#corpus_token_cvs.tolist()

# %%
corpus_token_cvs
# Out:
# 0      [data_scientist, brooklyn, ny, data_scientist,...
# 1      [nlp, data_scientist, brooklyn, ny, nlp, data_...
# 2      [hcm, technical, consultant, working, oracle, ...
# 3      [sap_hcm, consultant, com, qwikresume, marshvi...
# 4      [kasey, vista, detroit, senior, software_engin...
#                              ...
# 619    [technical, c_asp, net, mvc, html_cs, javascri...
# 620    [detail, detail, pune_maharashtra, university,...
# 621    [technology, asp_net, mvc, unit_testing, entit...
# 622    [technical, category, language, c_c, oop, dot_...
# 623    [technical, programming_c, net, web, technolog...
# Name: tokens_Content_CV, Length: 624, dtype: object

# %%
corpus_tokenizado_final = corpus_token_cvs.append(corpus_token_jobs) #Unimos las listas.
# Out:
# <ipython-input-24-6579b24b0175>:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   corpus_tokenizado_final = corpus_token_cvs.append(corpus_token_jobs) #Unimos las listas.

# %%
corpus_tokenizado_final
# Out:
# 0        [data_scientist, brooklyn, ny, data_scientist,...
# 1        [nlp, data_scientist, brooklyn, ny, nlp, data_...
# 2        [hcm, technical, consultant, working, oracle, ...
# 3        [sap_hcm, consultant, com, qwikresume, marshvi...
# 4        [kasey, vista, detroit, senior, software_engin...
#                                ...
# 20588    [company, description, searching, talented, cr...
# 20589    [location_san, francisco, caterm, full_time, p...
# 20590    [take_pride, knowing, thousand, life, positive...
# 20591    [company, description, offer, youas, world_lea...
# 20592    [c_c, programmingdevelopment, win, programming...
# Length: 21217, dtype: object

# %%
lista_corpus_tokenizado_final = corpus_tokenizado_final.tolist()
lista_corpus_tokenizado_final[0]
# Out:
# ['data_scientist',
#  'brooklyn',
#  'ny',
#  'data_scientist',
#  'grubhub',
#  'current',
#  'new_york',
#  'ny',
#  'implemented',
#  'various',
#  'time_series',
#  'forecasting',
#  'technique',
#  'predict',
#  'surge',
#  'customer',
#  'order',
#  'lower',
#  'average',
#  'customer',
#  'wait',
#  'time',
#  'minute',
#  'github',
#  'deployed',
#  'recommendation',
#  'engine',
#  'production',
#  'conditionally',
#  'recommend',
#  'menu',
#  'item',
#  'based',
#  'past',
#  'order',
#  'history',
#  'increase',
#  'average',
#  'order',
#  'size',
#  'designed',
#  'model',
#  'portland',
#  'pilot',
#  'program',
#  'increase',
#  'incentive',
#  'driver',
#  'peak',
#  'ordering',
#  'hour',
#  'resulting_increase',
#  'driver',
#  'availability',
#  'peak',
#  'ordering',
#  'time',
#  'statistic',
#  'rutgers',
#  'university',
#  'data_scientist',
#  'new',
#  'brunswick_nj',
#  'adobe',
#  'new_york',
#  'ny',
#  'worked',
#  'product',
#  'marketing',
#  'team',
#  'identify',
#  'customer',
#  'interaction',
#  'free',
#  'trial',
#  'maximize',
#  'likelihood',
#  'conversion',
#  'resulting',
#  'conversion_rate',
#  'increase',
#  'built',
#  'customer',
#  'attrition',
#  'random',
#  'forest',
#  'model',
#  'improved',
#  'monthly',
#  'python',
#  'numpy_panda',
#  'scikit_learn',
#  'retention',
#  'basis',
#  'point',
#  'customer',
#  'likely',
#  'attrit',
#  'kera',
#  'flask',
#  'servicing',
#  'relevant',
#  'product',
#  'feature',
#  'sql',
#  'mysql',
#  'postgres',
#  'worked_closely',
#  'product',
#  'team',
#  'build',
#  'production',
#  'git',
#  'recommendation',
#  'engine',
#  'python',
#  'improved',
#  'average',
#  'length',
#  'user',
#  'resulted',
#  'incremental',
#  'annual_revenue',
#  'time_series',
#  'forecasting',
#  'productionizing',
#  'model',
#  'recommendation',
#  'engine',
#  'data',
#  'analyst',
#  'customer',
#  'segmentation',
#  'adobe',
#  'new_york',
#  'ny',
#  'aws',
#  'worked',
#  'product',
#  'manager',
#  'perform',
#  'cohort',
#  'analysis',
#  'identiﬁed',
#  'opportunity',
#  'reduce',
#  'pricing',
#  'segment',
#  'user',
#  'boost',
#  'yearly',
#  'revenue',
#  'built',
#  'operational',
#  'reporting',
#  'tableau',
#  'ﬁnd',
#  'area',
#  'improvement',
#  'contractor',
#  'resulting',
#  'annual',
#  'incremental',
#  'revenue',
#  'implemented',
#  'long_term',
#  'pricing',
#  'experiment',
#  'improved',
#  'customer',
#  'lifetime',
#  'value']

# %% [markdown]
# #### Modelo word2vec:

# %%
#Ver imports:
    #gensim
    #Word2Vec
start_time = datetime.now()

#Mediante la siguiente línea de código entrenamos al modelo Word2Vec mediante nuestras 21217 listas de palabras 
#contenidas en “lista_corpus_tokenizado_final”:
model=gensim.models.Word2Vec(sentences=lista_corpus_tokenizado_final,
                             min_count=2,
                             alpha=0.025, 
                             epochs=5, 
                             vector_size=100, 
                             window=15, 
                             sg=1,
                             negative=10)
#En este caso no dividimos en train y test, ya que no vamos a predecir palabras en base a contextos, lo que 
#haremos es utilizar este word embedding para calcular WMD, entonces usamos TODAS las sentencias como entrenamiento. 
#Parametros función Word2Vec:
    #sentences:   #es el vector que contiene todas las palabras de nuestro corpus de texto de todos los documentos, 
                  #las cuales serán usadas para el entrenamiento de la red neuronal. 
    #min_count:   #Ignora todas las palabras cuando la frecuencia de cada palabra es menor a 'min_count'. El valor 
                  #por defecto es 5. Si queremos añadir todas las palabras en nuestro corpus colocaremos un valor de '1'.
    #window:      #Tamaño del "filtro" que se usa para analizar el contexto entre una palbras y las otras.
    #sg:          #Indica si utiliza el algoritmo de entrenamiento CBOW o skip gram. Por defecto es 0 (CBOW), nosotros 
                  #utilizaremos skip gram.
    #alpha:       #Learning rate, por defecto (0.025).
    #epochs       #Número de iteraciones sobre el corpus, por defecto (5).
    #vector_size: #Tamaño del embedding resultante, lo dejamos por defecto (100).
    #hs=0         #Desactivamos hierarchical Softmax para usar negative sampling. 
    #negative=10  #Especifica cuantas "noise words" van a ser usadas para el negative sampling (usualmente es entre 5-20).
                  #5 es el valor por defecto, pero decidimos colocar 10 para tener mayor cantidad de datos de entrenamiento, más ejemplos (ya que nuestro dataset no es muy grande).    
        
model.save("Word2vec_Model")  #Guardamos nuestro modelo.
wrds=list(model.wv.vectors)   #El modelo nos da un VOCABULARIO con palabras con las cuales podemos consultar. 
print(len(wrds))              #Me devuelve las palabras/tokens totales y ÚNICAS (sin repetidas) de nuestro Corpus (=Nuestro VOCABULARIO).

end_time = datetime.now()
print('Duration Word2vec training: {}'.format(end_time - start_time))
# Out:
# 60713
# Duration Word2vec training: 0:00:19.487795

# %%
#Para cargar el modelo nuevamente:
#model = gensim.models.Word2Vec.load("Word2vec_Model")

# %%
#Imprimimos las 10 primeras palabras de nuestro VOCABULARIO (saber que no estan en órden por la propia implementación de gensim):
for index, word in enumerate(model.wv.index_to_key):
    if index == 10:
        break
    print(f"word {index}/{len(model.wv.index_to_key)} is {word}")
# Out:
# word 0/60713 is business
# word 1/60713 is project
# word 2/60713 is system
# word 3/60713 is development
# word 4/60713 is team
# word 5/60713 is application
# word 6/60713 is management
# word 7/60713 is technology
# word 8/60713 is design
# word 9/60713 is client

# %%
###AGREGADO... esta aparece 3 veces, deberia estar: ProgrammingDevelopment

# %%
#Imprimimos el vector 'data_scientist' (de dimensión 1x100, ya que 100 es el tamaño del vector de embeddings que le indicamos al entrenar el modelo)
normed_vector = model.wv.get_vector("data_scientist")
print(normed_vector)

#Otra forma para imprimir estos vectores:
#wrds[0]  #Acá imprimiriamos el vector para "business" (arriba está en la posición 0)
# Out:
# [-1.0100532  -1.0739435  -0.2837995  -0.21934018 -0.39414248  0.431768
#   0.7870109   1.1987252   0.02807715  0.36723888 -0.06362996 -0.24838836
#   0.13970229 -0.4104615  -0.15942498 -0.14069991  0.4311964   0.25339454
#  -0.7163697  -1.1791078   0.02465013  0.48703074  0.27532187 -0.16741434
#  -0.7982925   0.3103815  -0.2682589  -0.341128    0.09525464 -0.16409445
#  -0.21894927 -0.7111297   0.8086186  -1.0402728  -0.1676163   0.10781587
#  -0.3996233   0.3140456  -1.3524671  -0.2275282  -0.14426762 -0.26552695
#  -1.5425543   0.18198712  1.0949311   0.03006735  0.04846608  0.01426211
#  -1.0429325  -0.26697767  0.18544249 -0.47435647  0.64723057 -0.43273878
#   0.07296617  0.07976893  0.04106973  1.2784706  -0.22689557  0.5165529
#   0.48510435  0.65974104  0.4472009  -0.08489984 -1.0182112   0.9372411
#  -0.00856188  1.4297451   0.6941317  -0.55708206 -0.30787155 -0.14141603
#  -0.00835913 -0.8819436   1.1272204   0.71299404  0.885767    0.41563436
#   0.46450695  0.5357916  -0.80906373  0.11209682 -0.7478496   1.3442876
#  -0.23815663 -0.01486344 -0.28759772 -0.3021132   0.7986508   0.87371784
#   0.27092153 -0.31795198  1.1332611  -0.4722241  -0.22277798  0.51489115
#  -0.0884189   0.10933927 -0.06706905  0.33318746]

# %%
df_compar_cand_jobs
# Out:
#                  Candidate_Name  \
# 0     DataScientist_Karla_Lewis
# 1     DataScientist_Karla_Lewis
# 2     DataScientist_Karla_Lewis
# 3     DataScientist_Karla_Lewis
# 4     DataScientist_Karla_Lewis
# ...                         ...
# 3126              Neha Mugghala
# 3127              Neha Mugghala
# 3128              Neha Mugghala
# 3129              Neha Mugghala
# 3130              Neha Mugghala
#
#                                        clean_Content_CV  \
# 0     data_scientist brooklyn ny data_scientist grub...
# 1     data_scientist brooklyn ny data_scientist grub...
# 2     data_scientist brooklyn ny data_scientist grub...
# 3     data_scientist brooklyn ny data_scientist grub...
# 4     data_scientist brooklyn ny data_scientist grub...
# ...                                                 ...
# 3126  sourya senior java_ee developer working variou...
# 3127  sourya senior java_ee developer working variou...
# 3128  sourya senior java_ee developer working variou...
# 3129  sourya senior java_ee developer working variou...
# 3130  sourya senior java_ee developer working variou...
#
#                                       tokens_Content_CV  \
# 0     [data_scientist, brooklyn, ny, data_scientist,...
# 1     [data_scientist, brooklyn, ny, data_scientist,...
# 2     [data_scientist, brooklyn, ny, data_scientist,...
# 3     [data_scientist, brooklyn, ny, data_scientist,...
# 4     [data_scientist, brooklyn, ny, data_scientist,...
# ...                                                 ...
# 3126  [sourya, senior, java_ee, developer, working, ...
# 3127  [sourya, senior, java_ee, developer, working, ...
# 3128  [sourya, senior, java_ee, developer, working, ...
# 3129  [sourya, senior, java_ee, developer, working, ...
# 3130  [sourya, senior, java_ee, developer, working, ...
#
#                                               Job_Title  \
# 0                                        Data Scientist
# 1                                      Data Scientist 2
# 2                                        HCM Consultant
# 3                                      HCM Consultant 2
# 4                             Machine Learning Engineer
# ...                                                 ...
# 3126                           Test Lead / Test Manager
# 3127  Principal Application Analyst-Supply Chain Lawson
# 3128                            Messaging Administrator
# 3129             Java Architect - Denver, CO - Fulltime
# 3130                                IT Business Analyst
#
#                                   clean_Job_Description  \
# 0     master_degree stem field including_limited com...
# 1     reporting director data analytics senior data_...
# 2     oracle cloud hcm absence consultant responsibl...
# 3     peoplesoft oracle_eb implementation support hc...
# 4     leveraging_latest machine deep_learning techni...
# ...                                                 ...
# 3126  location_atlanta gajob title test lead manager...
# 3127  vanderhouwen_job like find please join talent ...
# 3128  genesis actively_seeking messaging administrat...
# 3129  client healthcare software industry seeking ja...
# 3130  genesis looking business analyst long_term con...
#
#                                  tokens_Job_Description  tfidf_cosine
# 0     [master_degree, stem, field, including_limited...      0.042817
# 1     [reporting, director, data, analytics, senior,...      0.111344
# 2     [oracle, cloud, hcm, absence, consultant, resp...      0.018021
# 3     [peoplesoft, oracle_eb, implementation, suppor...      0.013100
# 4     [leveraging_latest, machine, deep_learning, te...      0.050443
# ...                                                 ...           ...
# 3126  [location_atlanta, gajob, title, test, lead, m...      0.025742
# 3127  [vanderhouwen_job, like, find, please, join, t...      0.105683
# 3128  [genesis, actively_seeking, messaging, adminis...      0.063452
# 3129  [client, healthcare, software, industry, seeki...      0.080821
# 3130  [genesis, looking, business, analyst, long_ter...      0.067010
#
# [3131 rows x 7 columns]

# %%
#De esta manera debería ser lo que usemos dentro de la función wmd():
sentence_obama = 'Obama speaks to the media in Illinois'.lower().split()
print(type(sentence_obama))
sentence_obama
# Out:
# <class 'list'>
# ['obama', 'speaks', 'to', 'the', 'media', 'in', 'illinois']

# %%
#Vemos que nuestra columna está en el formato CORRECTO:
primer_job_desc = df_compar_cand_jobs.loc[0,'tokens_Job_Description']
print(type(primer_job_desc))
primer_job_desc
# Out:
# <class 'list'>
# ['master_degree',
#  'stem',
#  'field',
#  'including_limited',
#  'computer_science',
#  'statistic_applied',
#  'mathematics',
#  'operation',
#  'research',
#  'engineering',
#  'economics',
#  'social',
#  'science',
#  'physic',
#  'chemistry',
#  'providing',
#  'advanced',
#  'analytics',
#  'within',
#  'business',
#  'setting',
#  'data',
#  'science',
#  'implementation',
#  'within',
#  'business',
#  'setting',
#  'working',
#  'raw',
#  'missing',
#  'data',
#  'understanding',
#  'programming',
#  'fundamental',
#  'understanding',
#  'statistic',
#  'excellent_communication',
#  'preferred',
#  'data_visualization',
#  'tool',
#  'time',
#  'series',
#  'working',
#  'knowledge',
#  'relational_database',
#  'standard',
#  'sql_query',
#  'method',
#  'proficiency_least',
#  'one',
#  'general',
#  'programming_language',
#  'python',
#  'java',
#  'c_c',
#  'working',
#  'big_data',
#  'within',
#  'hadoop',
#  'environment',
#  'working',
#  'r_sa',
#  'statistical',
#  'package',
#  'advanced',
#  'statistical',
#  'econometric',
#  'data_mining',
#  'tool',
#  'method',
#  'linear',
#  'model',
#  'linear_regression',
#  'generalized',
#  'linear_regression',
#  'logistic_regression',
#  'nonlinear',
#  'modeling_technique',
#  'knowledge',
#  'advanced',
#  'nonlinear',
#  'technique',
#  'including',
#  'smoothing',
#  'ensemble_method',
#  'leverage',
#  'knowledge',
#  'programming',
#  'mathematics',
#  'computer_science',
#  'transform_way',
#  'company',
#  'business',
#  'translate',
#  'business',
#  'opportunity',
#  'data',
#  'driven',
#  'machine_learning',
#  'big_data',
#  'modeling',
#  'solution',
#  'revamp',
#  'process',
#  'produce',
#  'data',
#  'product',
#  'develop',
#  'collect',
#  'data',
#  'ad_hoc',
#  'statistical_analysis',
#  'identify',
#  'method',
#  'allow',
#  'continuous',
#  'automated',
#  'statistical',
#  'testing',
#  'enhance',
#  'predictability',
#  'deployed',
#  'model',
#  'maintain',
#  'relationship',
#  'business',
#  'area',
#  'client',
#  'business_intelligence',
#  'technology',
#  'team',
#  'aligned',
#  'meet',
#  'team',
#  'objective',
#  'project',
#  'manager',
#  'develop',
#  'detailed',
#  'project',
#  'timeline',
#  'summarize',
#  'present',
#  'conclusion',
#  'solution',
#  'communicate',
#  'complex',
#  'analysis',
#  'clearly',
#  'audience']

# %%
model.wv.get_vector('machine_learning')
# Out:
# array([-0.99525577, -0.6077188 ,  0.49346033, -0.55763036, -0.9796547 ,
#        -0.68836665, -0.71350926, -1.4117522 ,  1.8915818 , -0.6506267 ,
#         0.42556623, -0.26373655, -1.1735786 ,  0.51572156,  1.8493272 ,
#        -0.7794592 ,  0.2914408 , -0.72422415, -2.4389746 , -0.6153202 ,
#        -1.5892342 ,  1.0106893 , -1.0484846 ,  2.2489483 , -0.21412507,
#         2.9172063 , -0.96349007, -1.3327242 ,  0.00416835,  1.3986703 ,
#         1.4242766 , -0.22011311,  2.223857  , -1.1588553 , -1.4619132 ,
#         0.1856661 , -1.7423491 ,  0.8147439 , -2.6550345 , -1.3177652 ,
#         0.27040812,  0.5305417 ,  0.9915678 ,  0.22363521,  1.6627038 ,
#        -2.082534  ,  0.45118788,  0.05226795, -0.7729668 , -0.7210281 ,
#        -1.7114677 , -0.26790208, -0.13104407, -1.8135256 , -0.37597892,
#        -0.50595236,  0.21065246,  0.22731315, -1.0537595 ,  0.47375342,
#         0.6429516 ,  0.2106793 , -0.45202067,  0.09661713, -0.5713031 ,
#         1.3932399 , -1.6853856 ,  3.1746583 , -1.5431623 ,  0.7986516 ,
#        -1.5669369 ,  0.1903241 , -0.6662915 , -1.8968294 ,  1.3839828 ,
#         2.233983  ,  1.9678819 ,  2.0298061 ,  1.2846667 ,  0.26421133,
#        -0.99659514,  1.0580146 ,  0.32030785,  2.739984  , -0.14339831,
#         1.092596  , -1.095313  ,  1.9392555 ,  0.09845804,  0.6467122 ,
#         0.2760214 , -0.48546174,  1.1419517 , -0.6304962 , -2.84526   ,
#         0.280099  ,  0.13373119,  0.01409199, -0.04472028,  0.31702626],
#       dtype=float32)

# %%
model.wv.wmdistance('deep_learning', 'machine_learning')  #Cálculo de wmd para 2 palabras.
# Out:
# 0.3127839378571345

# %%
#No vamos a utilizar esta 'funcionalidad', pero para saber:

#Gracias a nuestros words embeddings obtenidos por el entrenamiento en el modelo word2vec,
#ahora podemos realizar funciones como 'most_similar'....testeamos nuestro modelo: 
ModeloPrueba=model.wv.most_similar("machine_learning")     

#La función most_similar busca palabras que esten semánticamente
#cercas (que sean parecidas) a una palabra dada (En este caso 'machine_learning').

# %%
print(ModeloPrueba)
# Out:
# [('deep_learning', 0.8419713377952576), ('artificial_intelligence', 0.8369033336639404), ('predictive_analytics', 0.834757387638092), ('computational', 0.8211137652397156), ('algorithm', 0.8190171718597412), ('data_mining', 0.8028570413589478), ('nlp', 0.7969160079956055), ('predictive', 0.7912158966064453), ('predictive_modeling', 0.7865807414054871), ('ml', 0.773136556148529)]

# %%
#Función WMD que usaremos:
def WMD(tokens_CV_Candidate,tokens_Job_Desc):
    return (model.wv.wmdistance(tokens_CV_Candidate, tokens_Job_Desc))  #'wmdistance' return the word mover distance between two documents.

# %%
#Como prueba obtenemos el WMD comparando para la 1ra fila (entre las columnas tokens_Content_CV y tokens_Job_Description)
first_job_descr = df_compar_cand_jobs.loc[0,'tokens_Job_Description']
first_content_cv = df_compar_cand_jobs.loc[0,'tokens_Content_CV']

wmd_result = round(WMD(first_content_cv,first_job_descr),3)
print(wmd_result)
 
similarity_wdm = round((1/(1+wmd_result)),3)  
print(similarity_wdm)
# Out:
# 0.934
# 0.517

# %%
#Aplicamos WMD para TODO el DF... entre el contenido del CV y la descripcion del puesto; 
#y el resultado lo guardamos en las columna 'WMD'.

#df_compar_cand_jobs['WMD'] = df_compar_cand_jobs.apply(lambda row: round(WMD(row['tokens_Content_CV'],row['tokens_Job_Description']),3), axis=1)
#APlicando lo de  --> similarity = 1 / (1 + distance):
#(#similarity = 1 / (1 + distance) https://groups.google.com/g/gensim/c/-pRZnsOEaPQ)

start_time = datetime.now()

df_compar_cand_jobs['WMD'] = df_compar_cand_jobs.apply(lambda row: round((1/(1+(WMD(row['tokens_Content_CV'],row['tokens_Job_Description'])))),3), axis=1)

end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Duration: 7:00:27.420719

# %%
#Exportamos nuestro DF para guardar los resultados:
#df_compar_cand_jobs.to_pickle('DF_Exportado_Jobs_And_Candidates_tfidf_cosine_and_wmd')

# %%
#Importamos nuestro DF:
df_compar_cand_jobs_loaded = pd.read_pickle('DF_Exportado_Jobs_And_Candidates_tfidf_cosine_and_wmd')
df_compar_cand_jobs_loaded.shape
df_compar_cand_jobs_loaded
# Out:
#                  Candidate_Name  \
# 0     DataScientist_Karla_Lewis
# 1     DataScientist_Karla_Lewis
# 2     DataScientist_Karla_Lewis
# 3     DataScientist_Karla_Lewis
# 4     DataScientist_Karla_Lewis
# ...                         ...
# 3126              Neha Mugghala
# 3127              Neha Mugghala
# 3128              Neha Mugghala
# 3129              Neha Mugghala
# 3130              Neha Mugghala
#
#                                        clean_Content_CV  \
# 0     data_scientist brooklyn ny data_scientist grub...
# 1     data_scientist brooklyn ny data_scientist grub...
# 2     data_scientist brooklyn ny data_scientist grub...
# 3     data_scientist brooklyn ny data_scientist grub...
# 4     data_scientist brooklyn ny data_scientist grub...
# ...                                                 ...
# 3126  sourya senior java_ee developer working variou...
# 3127  sourya senior java_ee developer working variou...
# 3128  sourya senior java_ee developer working variou...
# 3129  sourya senior java_ee developer working variou...
# 3130  sourya senior java_ee developer working variou...
#
#                                       tokens_Content_CV  \
# 0     [data_scientist, brooklyn, ny, data_scientist,...
# 1     [data_scientist, brooklyn, ny, data_scientist,...
# 2     [data_scientist, brooklyn, ny, data_scientist,...
# 3     [data_scientist, brooklyn, ny, data_scientist,...
# 4     [data_scientist, brooklyn, ny, data_scientist,...
# ...                                                 ...
# 3126  [sourya, senior, java_ee, developer, working, ...
# 3127  [sourya, senior, java_ee, developer, working, ...
# 3128  [sourya, senior, java_ee, developer, working, ...
# 3129  [sourya, senior, java_ee, developer, working, ...
# 3130  [sourya, senior, java_ee, developer, working, ...
#
#                                               Job_Title  \
# 0                                        Data Scientist
# 1                                      Data Scientist 2
# 2                                        HCM Consultant
# 3                                      HCM Consultant 2
# 4                             Machine Learning Engineer
# ...                                                 ...
# 3126                           Test Lead / Test Manager
# 3127  Principal Application Analyst-Supply Chain Lawson
# 3128                            Messaging Administrator
# 3129             Java Architect - Denver, CO - Fulltime
# 3130                                IT Business Analyst
#
#                                   clean_Job_Description  \
# 0     master_degree stem field including_limited com...
# 1     reporting director data analytics senior data_...
# 2     oracle cloud hcm absence consultant responsibl...
# 3     peoplesoft oracle_eb implementation support hc...
# 4     leveraging_latest machine deep_learning techni...
# ...                                                 ...
# 3126  location_atlanta gajob title test lead manager...
# 3127  vanderhouwen_job like find please join talent ...
# 3128  genesis actively_seeking messaging administrat...
# 3129  client healthcare software industry seeking ja...
# 3130  genesis looking business analyst long_term con...
#
#                                  tokens_Job_Description  tfidf_cosine    WMD
# 0     [master_degree, stem, field, including_limited...      0.042817  0.517
# 1     [reporting, director, data, analytics, senior,...      0.111344  0.525
# 2     [oracle, cloud, hcm, absence, consultant, resp...      0.018021  0.501
# 3     [peoplesoft, oracle_eb, implementation, suppor...      0.013100  0.500
# 4     [leveraging_latest, machine, deep_learning, te...      0.050443  0.518
# ...                                                 ...           ...    ...
# 3126  [location_atlanta, gajob, title, test, lead, m...      0.025742  0.485
# 3127  [vanderhouwen_job, like, find, please, join, t...      0.105683  0.516
# 3128  [genesis, actively_seeking, messaging, adminis...      0.063452  0.512
# 3129  [client, healthcare, software, industry, seeki...      0.080821  0.507
# 3130  [genesis, looking, business, analyst, long_ter...      0.067010  0.505
#
# [3131 rows x 8 columns]

# %% [markdown]
# ### 6-Observación valores de Cosine Similarity y WMD.
#
# ##### Vamos a ver ejemplos de los valores de Cosine Similarity y WMD para el Candidate 'MLEngineer_Bradly_Johnston' y el Job 'Security Specialist 2'.

# %% [markdown]
# ##### Antes que nada redondeamos a 3 decimales la columna 'tfidf_cosine' para que no me la exprese en notación científica y para que tenga igual cantidad de decimales que WMD:

# %%
df_compar_cand_jobs_loaded['tfidf_cosine'] = df_compar_cand_jobs_loaded['tfidf_cosine'].round(3)
#pd.set_option('display.float_format', lambda x: '%.3f' % x)
df_compar_cand_jobs_loaded
# Out:
#                  Candidate_Name  \
# 0     DataScientist_Karla_Lewis
# 1     DataScientist_Karla_Lewis
# 2     DataScientist_Karla_Lewis
# 3     DataScientist_Karla_Lewis
# 4     DataScientist_Karla_Lewis
# ...                         ...
# 3126              Neha Mugghala
# 3127              Neha Mugghala
# 3128              Neha Mugghala
# 3129              Neha Mugghala
# 3130              Neha Mugghala
#
#                                        clean_Content_CV  \
# 0     data_scientist brooklyn ny data_scientist grub...
# 1     data_scientist brooklyn ny data_scientist grub...
# 2     data_scientist brooklyn ny data_scientist grub...
# 3     data_scientist brooklyn ny data_scientist grub...
# 4     data_scientist brooklyn ny data_scientist grub...
# ...                                                 ...
# 3126  sourya senior java_ee developer working variou...
# 3127  sourya senior java_ee developer working variou...
# 3128  sourya senior java_ee developer working variou...
# 3129  sourya senior java_ee developer working variou...
# 3130  sourya senior java_ee developer working variou...
#
#                                       tokens_Content_CV  \
# 0     [data_scientist, brooklyn, ny, data_scientist,...
# 1     [data_scientist, brooklyn, ny, data_scientist,...
# 2     [data_scientist, brooklyn, ny, data_scientist,...
# 3     [data_scientist, brooklyn, ny, data_scientist,...
# 4     [data_scientist, brooklyn, ny, data_scientist,...
# ...                                                 ...
# 3126  [sourya, senior, java_ee, developer, working, ...
# 3127  [sourya, senior, java_ee, developer, working, ...
# 3128  [sourya, senior, java_ee, developer, working, ...
# 3129  [sourya, senior, java_ee, developer, working, ...
# 3130  [sourya, senior, java_ee, developer, working, ...
#
#                                               Job_Title  \
# 0                                        Data Scientist
# 1                                      Data Scientist 2
# 2                                        HCM Consultant
# 3                                      HCM Consultant 2
# 4                             Machine Learning Engineer
# ...                                                 ...
# 3126                           Test Lead / Test Manager
# 3127  Principal Application Analyst-Supply Chain Lawson
# 3128                            Messaging Administrator
# 3129             Java Architect - Denver, CO - Fulltime
# 3130                                IT Business Analyst
#
#                                   clean_Job_Description  \
# 0     master_degree stem field including_limited com...
# 1     reporting director data analytics senior data_...
# 2     oracle cloud hcm absence consultant responsibl...
# 3     peoplesoft oracle_eb implementation support hc...
# 4     leveraging_latest machine deep_learning techni...
# ...                                                 ...
# 3126  location_atlanta gajob title test lead manager...
# 3127  vanderhouwen_job like find please join talent ...
# 3128  genesis actively_seeking messaging administrat...
# 3129  client healthcare software industry seeking ja...
# 3130  genesis looking business analyst long_term con...
#
#                                  tokens_Job_Description  tfidf_cosine    WMD
# 0     [master_degree, stem, field, including_limited...         0.043  0.517
# 1     [reporting, director, data, analytics, senior,...         0.111  0.525
# 2     [oracle, cloud, hcm, absence, consultant, resp...         0.018  0.501
# 3     [peoplesoft, oracle_eb, implementation, suppor...         0.013  0.500
# 4     [leveraging_latest, machine, deep_learning, te...         0.050  0.518
# ...                                                 ...           ...    ...
# 3126  [location_atlanta, gajob, title, test, lead, m...         0.026  0.485
# 3127  [vanderhouwen_job, like, find, please, join, t...         0.106  0.516
# 3128  [genesis, actively_seeking, messaging, adminis...         0.063  0.512
# 3129  [client, healthcare, software, industry, seeki...         0.081  0.507
# 3130  [genesis, looking, business, analyst, long_ter...         0.067  0.505
#
# [3131 rows x 8 columns]

# %% [markdown]
# ### 6.1-Candidate 'Bradly Johnston (ML Engineer)'

# %%
df_MLEngineer_Bradly_Johnston = df_compar_cand_jobs_loaded.loc[df_compar_cand_jobs_loaded['Candidate_Name'] == 'MLEngineer_Bradly_Johnston']
df_MLEngineer_Bradly_Johnston
print(df_MLEngineer_Bradly_Johnston.shape)
df_MLEngineer_Bradly_Johnston
# Out:
# (31, 8)
#                  Candidate_Name  \
# 124  MLEngineer_Bradly_Johnston
# 125  MLEngineer_Bradly_Johnston
# 126  MLEngineer_Bradly_Johnston
# 127  MLEngineer_Bradly_Johnston
# 128  MLEngineer_Bradly_Johnston
# 129  MLEngineer_Bradly_Johnston
# 130  MLEngineer_Bradly_Johnston
# 131  MLEngineer_Bradly_Johnston
# 132  MLEngineer_Bradly_Johnston
# 133  MLEngineer_Bradly_Johnston
# 134  MLEngineer_Bradly_Johnston
# 135  MLEngineer_Bradly_Johnston
# 136  MLEngineer_Bradly_Johnston
# 137  MLEngineer_Bradly_Johnston
# 138  MLEngineer_Bradly_Johnston
# 139  MLEngineer_Bradly_Johnston
# 140  MLEngineer_Bradly_Johnston
# 141  MLEngineer_Bradly_Johnston
# 142  MLEngineer_Bradly_Johnston
# 143  MLEngineer_Bradly_Johnston
# 144  MLEngineer_Bradly_Johnston
# 145  MLEngineer_Bradly_Johnston
# 146  MLEngineer_Bradly_Johnston
# 147  MLEngineer_Bradly_Johnston
# 148  MLEngineer_Bradly_Johnston
# 149  MLEngineer_Bradly_Johnston
# 150  MLEngineer_Bradly_Johnston
# 151  MLEngineer_Bradly_Johnston
# 152  MLEngineer_Bradly_Johnston
# 153  MLEngineer_Bradly_Johnston
# 154  MLEngineer_Bradly_Johnston
#
#                                       clean_Content_CV  \
# 124  kasey vista detroit senior software_engineer m...
# 125  kasey vista detroit senior software_engineer m...
# 126  kasey vista detroit senior software_engineer m...
# 127  kasey vista detroit senior software_engineer m...
# 128  kasey vista detroit senior software_engineer m...
# 129  kasey vista detroit senior software_engineer m...
# 130  kasey vista detroit senior software_engineer m...
# 131  kasey vista detroit senior software_engineer m...
# 132  kasey vista detroit senior software_engineer m...
# 133  kasey vista detroit senior software_engineer m...
# 134  kasey vista detroit senior software_engineer m...
# 135  kasey vista detroit senior software_engineer m...
# 136  kasey vista detroit senior software_engineer m...
# 137  kasey vista detroit senior software_engineer m...
# 138  kasey vista detroit senior software_engineer m...
# 139  kasey vista detroit senior software_engineer m...
# 140  kasey vista detroit senior software_engineer m...
# 141  kasey vista detroit senior software_engineer m...
# 142  kasey vista detroit senior software_engineer m...
# 143  kasey vista detroit senior software_engineer m...
# 144  kasey vista detroit senior software_engineer m...
# 145  kasey vista detroit senior software_engineer m...
# 146  kasey vista detroit senior software_engineer m...
# 147  kasey vista detroit senior software_engineer m...
# 148  kasey vista detroit senior software_engineer m...
# 149  kasey vista detroit senior software_engineer m...
# 150  kasey vista detroit senior software_engineer m...
# 151  kasey vista detroit senior software_engineer m...
# 152  kasey vista detroit senior software_engineer m...
# 153  kasey vista detroit senior software_engineer m...
# 154  kasey vista detroit senior software_engineer m...
#
#                                      tokens_Content_CV  \
# 124  [kasey, vista, detroit, senior, software_engin...
# 125  [kasey, vista, detroit, senior, software_engin...
# 126  [kasey, vista, detroit, senior, software_engin...
# 127  [kasey, vista, detroit, senior, software_engin...
# 128  [kasey, vista, detroit, senior, software_engin...
# 129  [kasey, vista, detroit, senior, software_engin...
# 130  [kasey, vista, detroit, senior, software_engin...
# 131  [kasey, vista, detroit, senior, software_engin...
# 132  [kasey, vista, detroit, senior, software_engin...
# 133  [kasey, vista, detroit, senior, software_engin...
# 134  [kasey, vista, detroit, senior, software_engin...
# 135  [kasey, vista, detroit, senior, software_engin...
# 136  [kasey, vista, detroit, senior, software_engin...
# 137  [kasey, vista, detroit, senior, software_engin...
# 138  [kasey, vista, detroit, senior, software_engin...
# 139  [kasey, vista, detroit, senior, software_engin...
# 140  [kasey, vista, detroit, senior, software_engin...
# 141  [kasey, vista, detroit, senior, software_engin...
# 142  [kasey, vista, detroit, senior, software_engin...
# 143  [kasey, vista, detroit, senior, software_engin...
# 144  [kasey, vista, detroit, senior, software_engin...
# 145  [kasey, vista, detroit, senior, software_engin...
# 146  [kasey, vista, detroit, senior, software_engin...
# 147  [kasey, vista, detroit, senior, software_engin...
# 148  [kasey, vista, detroit, senior, software_engin...
# 149  [kasey, vista, detroit, senior, software_engin...
# 150  [kasey, vista, detroit, senior, software_engin...
# 151  [kasey, vista, detroit, senior, software_engin...
# 152  [kasey, vista, detroit, senior, software_engin...
# 153  [kasey, vista, detroit, senior, software_engin...
# 154  [kasey, vista, detroit, senior, software_engin...
#
#                                              Job_Title  \
# 124                                     Data Scientist
# 125                                   Data Scientist 2
# 126                                     HCM Consultant
# 127                                   HCM Consultant 2
# 128                          Machine Learning Engineer
# 129                        Machine Learning Engineer 2
# 130                                Security Specialist
# 131                              Security Specialist 2
# 132                           Web Developer Full Stack
# 133                         Web Developer Full Stack 2
# 134                           AUTOMATION TEST ENGINEER
# 135                      Information Security Engineer
# 136                       Business Solutions Architect
# 137  Java Developer (mid level)- FT- GREAT culture,...
# 138                                    DevOps Engineer
# 139                                 SAP FICO Architect
# 140                                   Network Engineer
# 141  Sr. Web Application Developer (Cloud Team) - C...
# 142                                Front End Developer
# 143                       Application Support Engineer
# 144                         OpenStack Engineer - 12185
# 145      9001 Data Security Administrator - Unix & IAM
# 146                          Software Engineer Manager
# 147                        Sales Engineer - Los Angles
# 148                                    Project Manager
# 149                       Windows System Administrator
# 150                           Test Lead / Test Manager
# 151  Principal Application Analyst-Supply Chain Lawson
# 152                            Messaging Administrator
# 153             Java Architect - Denver, CO - Fulltime
# 154                                IT Business Analyst
#
#                                  clean_Job_Description  \
# 124  master_degree stem field including_limited com...
# 125  reporting director data analytics senior data_...
# 126  oracle cloud hcm absence consultant responsibl...
# 127  peoplesoft oracle_eb implementation support hc...
# 128  leveraging_latest machine deep_learning techni...
# 129  collaborate multidisciplinary_team gain_insigh...
# 130  fast_paced environment combine technical secur...
# 131  handling incoming_request assistance business ...
# 132  graduate_degree information technology similar...
# 133  enter existing codebases extend functionality ...
# 134  looking selenium engineer must solid java codi...
# 135  university chicago rapidly_growing security pr...
# 136  galaxe_solutionsevery day solution affect_peop...
# 137  java developerfull time direct hirebolingbrook...
# 138  midtown based high tech firm immediate innovat...
# 139  looking senior sap_fico architect join_u fullt...
# 140  network engineer description network engineer ...
# 141  bluebeam looking_talented sr web developer pas...
# 142  fulltime_position javascript developer financi...
# 143  summaryour_client leading_provider online vide...
# 144  description senior member team responsible pro...
# 145  must unix iam identity_access management scrip...
# 146  vanderhouwen_job like find please join talent ...
# 147  genesis currently_seeking sale engineer steel ...
# 148  vanderhouwen_job like find please join talent ...
# 149  window system administrator window system admi...
# 150  location_atlanta gajob title test lead manager...
# 151  vanderhouwen_job like find please join talent ...
# 152  genesis actively_seeking messaging administrat...
# 153  client healthcare software industry seeking ja...
# 154  genesis looking business analyst long_term con...
#
#                                 tokens_Job_Description  tfidf_cosine    WMD
# 124  [master_degree, stem, field, including_limited...         0.160  0.566
# 125  [reporting, director, data, analytics, senior,...         0.313  0.569
# 126  [oracle, cloud, hcm, absence, consultant, resp...         0.042  0.510
# 127  [peoplesoft, oracle_eb, implementation, suppor...         0.039  0.513
# 128  [leveraging_latest, machine, deep_learning, te...         0.246  0.572
# 129  [collaborate, multidisciplinary_team, gain_ins...         0.326  0.579
# 130  [fast_paced, environment, combine, technical, ...         0.039  0.533
# 131  [handling, incoming_request, assistance, busin...         0.026  0.510
# 132  [graduate_degree, information, technology, sim...         0.036  0.512
# 133  [enter, existing, codebases, extend, functiona...         0.053  0.536
# 134  [looking, selenium, engineer, must, solid, jav...         0.092  0.556
# 135  [university, chicago, rapidly_growing, securit...         0.036  0.506
# 136  [galaxe_solutionsevery, day, solution, affect_...         0.086  0.543
# 137  [java, developerfull, time, direct, hireboling...         0.046  0.528
# 138  [midtown, based, high, tech, firm, immediate, ...         0.025  0.505
# 139  [looking, senior, sap_fico, architect, join_u,...         0.013  0.476
# 140  [network, engineer, description, network, engi...         0.033  0.508
# 141  [bluebeam, looking_talented, sr, web, develope...         0.074  0.531
# 142  [fulltime_position, javascript, developer, fin...         0.078  0.538
# 143  [summaryour_client, leading_provider, online, ...         0.064  0.537
# 144  [description, senior, member, team, responsibl...         0.042  0.526
# 145  [must, unix, iam, identity_access, management,...         0.057  0.535
# 146  [vanderhouwen_job, like, find, please, join, t...         0.057  0.528
# 147  [genesis, currently_seeking, sale, engineer, s...         0.050  0.524
# 148  [vanderhouwen_job, like, find, please, join, t...         0.026  0.506
# 149  [window, system, administrator, window, system...         0.043  0.527
# 150  [location_atlanta, gajob, title, test, lead, m...         0.025  0.491
# 151  [vanderhouwen_job, like, find, please, join, t...         0.065  0.535
# 152  [genesis, actively_seeking, messaging, adminis...         0.036  0.514
# 153  [client, healthcare, software, industry, seeki...         0.043  0.522
# 154  [genesis, looking, business, analyst, long_ter...         0.067  0.526

# %%
#Ordenamos de mayor a menor de acuerdo a tfidf_cosine:
df_MLEngineer_Bradly_Johnston.sort_values(by=['tfidf_cosine'], ascending=False)
# Out:
#                  Candidate_Name  \
# 129  MLEngineer_Bradly_Johnston
# 125  MLEngineer_Bradly_Johnston
# 128  MLEngineer_Bradly_Johnston
# 124  MLEngineer_Bradly_Johnston
# 134  MLEngineer_Bradly_Johnston
# 136  MLEngineer_Bradly_Johnston
# 142  MLEngineer_Bradly_Johnston
# 141  MLEngineer_Bradly_Johnston
# 154  MLEngineer_Bradly_Johnston
# 151  MLEngineer_Bradly_Johnston
# 143  MLEngineer_Bradly_Johnston
# 146  MLEngineer_Bradly_Johnston
# 145  MLEngineer_Bradly_Johnston
# 133  MLEngineer_Bradly_Johnston
# 147  MLEngineer_Bradly_Johnston
# 137  MLEngineer_Bradly_Johnston
# 153  MLEngineer_Bradly_Johnston
# 149  MLEngineer_Bradly_Johnston
# 144  MLEngineer_Bradly_Johnston
# 126  MLEngineer_Bradly_Johnston
# 127  MLEngineer_Bradly_Johnston
# 130  MLEngineer_Bradly_Johnston
# 132  MLEngineer_Bradly_Johnston
# 152  MLEngineer_Bradly_Johnston
# 135  MLEngineer_Bradly_Johnston
# 140  MLEngineer_Bradly_Johnston
# 148  MLEngineer_Bradly_Johnston
# 131  MLEngineer_Bradly_Johnston
# 138  MLEngineer_Bradly_Johnston
# 150  MLEngineer_Bradly_Johnston
# 139  MLEngineer_Bradly_Johnston
#
#                                       clean_Content_CV  \
# 129  kasey vista detroit senior software_engineer m...
# 125  kasey vista detroit senior software_engineer m...
# 128  kasey vista detroit senior software_engineer m...
# 124  kasey vista detroit senior software_engineer m...
# 134  kasey vista detroit senior software_engineer m...
# 136  kasey vista detroit senior software_engineer m...
# 142  kasey vista detroit senior software_engineer m...
# 141  kasey vista detroit senior software_engineer m...
# 154  kasey vista detroit senior software_engineer m...
# 151  kasey vista detroit senior software_engineer m...
# 143  kasey vista detroit senior software_engineer m...
# 146  kasey vista detroit senior software_engineer m...
# 145  kasey vista detroit senior software_engineer m...
# 133  kasey vista detroit senior software_engineer m...
# 147  kasey vista detroit senior software_engineer m...
# 137  kasey vista detroit senior software_engineer m...
# 153  kasey vista detroit senior software_engineer m...
# 149  kasey vista detroit senior software_engineer m...
# 144  kasey vista detroit senior software_engineer m...
# 126  kasey vista detroit senior software_engineer m...
# 127  kasey vista detroit senior software_engineer m...
# 130  kasey vista detroit senior software_engineer m...
# 132  kasey vista detroit senior software_engineer m...
# 152  kasey vista detroit senior software_engineer m...
# 135  kasey vista detroit senior software_engineer m...
# 140  kasey vista detroit senior software_engineer m...
# 148  kasey vista detroit senior software_engineer m...
# 131  kasey vista detroit senior software_engineer m...
# 138  kasey vista detroit senior software_engineer m...
# 150  kasey vista detroit senior software_engineer m...
# 139  kasey vista detroit senior software_engineer m...
#
#                                      tokens_Content_CV  \
# 129  [kasey, vista, detroit, senior, software_engin...
# 125  [kasey, vista, detroit, senior, software_engin...
# 128  [kasey, vista, detroit, senior, software_engin...
# 124  [kasey, vista, detroit, senior, software_engin...
# 134  [kasey, vista, detroit, senior, software_engin...
# 136  [kasey, vista, detroit, senior, software_engin...
# 142  [kasey, vista, detroit, senior, software_engin...
# 141  [kasey, vista, detroit, senior, software_engin...
# 154  [kasey, vista, detroit, senior, software_engin...
# 151  [kasey, vista, detroit, senior, software_engin...
# 143  [kasey, vista, detroit, senior, software_engin...
# 146  [kasey, vista, detroit, senior, software_engin...
# 145  [kasey, vista, detroit, senior, software_engin...
# 133  [kasey, vista, detroit, senior, software_engin...
# 147  [kasey, vista, detroit, senior, software_engin...
# 137  [kasey, vista, detroit, senior, software_engin...
# 153  [kasey, vista, detroit, senior, software_engin...
# 149  [kasey, vista, detroit, senior, software_engin...
# 144  [kasey, vista, detroit, senior, software_engin...
# 126  [kasey, vista, detroit, senior, software_engin...
# 127  [kasey, vista, detroit, senior, software_engin...
# 130  [kasey, vista, detroit, senior, software_engin...
# 132  [kasey, vista, detroit, senior, software_engin...
# 152  [kasey, vista, detroit, senior, software_engin...
# 135  [kasey, vista, detroit, senior, software_engin...
# 140  [kasey, vista, detroit, senior, software_engin...
# 148  [kasey, vista, detroit, senior, software_engin...
# 131  [kasey, vista, detroit, senior, software_engin...
# 138  [kasey, vista, detroit, senior, software_engin...
# 150  [kasey, vista, detroit, senior, software_engin...
# 139  [kasey, vista, detroit, senior, software_engin...
#
#                                              Job_Title  \
# 129                        Machine Learning Engineer 2
# 125                                   Data Scientist 2
# 128                          Machine Learning Engineer
# 124                                     Data Scientist
# 134                           AUTOMATION TEST ENGINEER
# 136                       Business Solutions Architect
# 142                                Front End Developer
# 141  Sr. Web Application Developer (Cloud Team) - C...
# 154                                IT Business Analyst
# 151  Principal Application Analyst-Supply Chain Lawson
# 143                       Application Support Engineer
# 146                          Software Engineer Manager
# 145      9001 Data Security Administrator - Unix & IAM
# 133                         Web Developer Full Stack 2
# 147                        Sales Engineer - Los Angles
# 137  Java Developer (mid level)- FT- GREAT culture,...
# 153             Java Architect - Denver, CO - Fulltime
# 149                       Windows System Administrator
# 144                         OpenStack Engineer - 12185
# 126                                     HCM Consultant
# 127                                   HCM Consultant 2
# 130                                Security Specialist
# 132                           Web Developer Full Stack
# 152                            Messaging Administrator
# 135                      Information Security Engineer
# 140                                   Network Engineer
# 148                                    Project Manager
# 131                              Security Specialist 2
# 138                                    DevOps Engineer
# 150                           Test Lead / Test Manager
# 139                                 SAP FICO Architect
#
#                                  clean_Job_Description  \
# 129  collaborate multidisciplinary_team gain_insigh...
# 125  reporting director data analytics senior data_...
# 128  leveraging_latest machine deep_learning techni...
# 124  master_degree stem field including_limited com...
# 134  looking selenium engineer must solid java codi...
# 136  galaxe_solutionsevery day solution affect_peop...
# 142  fulltime_position javascript developer financi...
# 141  bluebeam looking_talented sr web developer pas...
# 154  genesis looking business analyst long_term con...
# 151  vanderhouwen_job like find please join talent ...
# 143  summaryour_client leading_provider online vide...
# 146  vanderhouwen_job like find please join talent ...
# 145  must unix iam identity_access management scrip...
# 133  enter existing codebases extend functionality ...
# 147  genesis currently_seeking sale engineer steel ...
# 137  java developerfull time direct hirebolingbrook...
# 153  client healthcare software industry seeking ja...
# 149  window system administrator window system admi...
# 144  description senior member team responsible pro...
# 126  oracle cloud hcm absence consultant responsibl...
# 127  peoplesoft oracle_eb implementation support hc...
# 130  fast_paced environment combine technical secur...
# 132  graduate_degree information technology similar...
# 152  genesis actively_seeking messaging administrat...
# 135  university chicago rapidly_growing security pr...
# 140  network engineer description network engineer ...
# 148  vanderhouwen_job like find please join talent ...
# 131  handling incoming_request assistance business ...
# 138  midtown based high tech firm immediate innovat...
# 150  location_atlanta gajob title test lead manager...
# 139  looking senior sap_fico architect join_u fullt...
#
#                                 tokens_Job_Description  tfidf_cosine    WMD
# 129  [collaborate, multidisciplinary_team, gain_ins...         0.326  0.579
# 125  [reporting, director, data, analytics, senior,...         0.313  0.569
# 128  [leveraging_latest, machine, deep_learning, te...         0.246  0.572
# 124  [master_degree, stem, field, including_limited...         0.160  0.566
# 134  [looking, selenium, engineer, must, solid, jav...         0.092  0.556
# 136  [galaxe_solutionsevery, day, solution, affect_...         0.086  0.543
# 142  [fulltime_position, javascript, developer, fin...         0.078  0.538
# 141  [bluebeam, looking_talented, sr, web, develope...         0.074  0.531
# 154  [genesis, looking, business, analyst, long_ter...         0.067  0.526
# 151  [vanderhouwen_job, like, find, please, join, t...         0.065  0.535
# 143  [summaryour_client, leading_provider, online, ...         0.064  0.537
# 146  [vanderhouwen_job, like, find, please, join, t...         0.057  0.528
# 145  [must, unix, iam, identity_access, management,...         0.057  0.535
# 133  [enter, existing, codebases, extend, functiona...         0.053  0.536
# 147  [genesis, currently_seeking, sale, engineer, s...         0.050  0.524
# 137  [java, developerfull, time, direct, hireboling...         0.046  0.528
# 153  [client, healthcare, software, industry, seeki...         0.043  0.522
# 149  [window, system, administrator, window, system...         0.043  0.527
# 144  [description, senior, member, team, responsibl...         0.042  0.526
# 126  [oracle, cloud, hcm, absence, consultant, resp...         0.042  0.510
# 127  [peoplesoft, oracle_eb, implementation, suppor...         0.039  0.513
# 130  [fast_paced, environment, combine, technical, ...         0.039  0.533
# 132  [graduate_degree, information, technology, sim...         0.036  0.512
# 152  [genesis, actively_seeking, messaging, adminis...         0.036  0.514
# 135  [university, chicago, rapidly_growing, securit...         0.036  0.506
# 140  [network, engineer, description, network, engi...         0.033  0.508
# 148  [vanderhouwen_job, like, find, please, join, t...         0.026  0.506
# 131  [handling, incoming_request, assistance, busin...         0.026  0.510
# 138  [midtown, based, high, tech, firm, immediate, ...         0.025  0.505
# 150  [location_atlanta, gajob, title, test, lead, m...         0.025  0.491
# 139  [looking, senior, sap_fico, architect, join_u,...         0.013  0.476

# %%
#Ordenamos de mayor a menor de acuerdo a WMD:
df_MLEngineer_Bradly_Johnston.sort_values(by=['WMD'], ascending=False)
# Out:
#                  Candidate_Name  \
# 129  MLEngineer_Bradly_Johnston
# 128  MLEngineer_Bradly_Johnston
# 125  MLEngineer_Bradly_Johnston
# 124  MLEngineer_Bradly_Johnston
# 134  MLEngineer_Bradly_Johnston
# 136  MLEngineer_Bradly_Johnston
# 142  MLEngineer_Bradly_Johnston
# 143  MLEngineer_Bradly_Johnston
# 133  MLEngineer_Bradly_Johnston
# 151  MLEngineer_Bradly_Johnston
# 145  MLEngineer_Bradly_Johnston
# 130  MLEngineer_Bradly_Johnston
# 141  MLEngineer_Bradly_Johnston
# 146  MLEngineer_Bradly_Johnston
# 137  MLEngineer_Bradly_Johnston
# 149  MLEngineer_Bradly_Johnston
# 144  MLEngineer_Bradly_Johnston
# 154  MLEngineer_Bradly_Johnston
# 147  MLEngineer_Bradly_Johnston
# 153  MLEngineer_Bradly_Johnston
# 152  MLEngineer_Bradly_Johnston
# 127  MLEngineer_Bradly_Johnston
# 132  MLEngineer_Bradly_Johnston
# 131  MLEngineer_Bradly_Johnston
# 126  MLEngineer_Bradly_Johnston
# 140  MLEngineer_Bradly_Johnston
# 135  MLEngineer_Bradly_Johnston
# 148  MLEngineer_Bradly_Johnston
# 138  MLEngineer_Bradly_Johnston
# 150  MLEngineer_Bradly_Johnston
# 139  MLEngineer_Bradly_Johnston
#
#                                       clean_Content_CV  \
# 129  kasey vista detroit senior software_engineer m...
# 128  kasey vista detroit senior software_engineer m...
# 125  kasey vista detroit senior software_engineer m...
# 124  kasey vista detroit senior software_engineer m...
# 134  kasey vista detroit senior software_engineer m...
# 136  kasey vista detroit senior software_engineer m...
# 142  kasey vista detroit senior software_engineer m...
# 143  kasey vista detroit senior software_engineer m...
# 133  kasey vista detroit senior software_engineer m...
# 151  kasey vista detroit senior software_engineer m...
# 145  kasey vista detroit senior software_engineer m...
# 130  kasey vista detroit senior software_engineer m...
# 141  kasey vista detroit senior software_engineer m...
# 146  kasey vista detroit senior software_engineer m...
# 137  kasey vista detroit senior software_engineer m...
# 149  kasey vista detroit senior software_engineer m...
# 144  kasey vista detroit senior software_engineer m...
# 154  kasey vista detroit senior software_engineer m...
# 147  kasey vista detroit senior software_engineer m...
# 153  kasey vista detroit senior software_engineer m...
# 152  kasey vista detroit senior software_engineer m...
# 127  kasey vista detroit senior software_engineer m...
# 132  kasey vista detroit senior software_engineer m...
# 131  kasey vista detroit senior software_engineer m...
# 126  kasey vista detroit senior software_engineer m...
# 140  kasey vista detroit senior software_engineer m...
# 135  kasey vista detroit senior software_engineer m...
# 148  kasey vista detroit senior software_engineer m...
# 138  kasey vista detroit senior software_engineer m...
# 150  kasey vista detroit senior software_engineer m...
# 139  kasey vista detroit senior software_engineer m...
#
#                                      tokens_Content_CV  \
# 129  [kasey, vista, detroit, senior, software_engin...
# 128  [kasey, vista, detroit, senior, software_engin...
# 125  [kasey, vista, detroit, senior, software_engin...
# 124  [kasey, vista, detroit, senior, software_engin...
# 134  [kasey, vista, detroit, senior, software_engin...
# 136  [kasey, vista, detroit, senior, software_engin...
# 142  [kasey, vista, detroit, senior, software_engin...
# 143  [kasey, vista, detroit, senior, software_engin...
# 133  [kasey, vista, detroit, senior, software_engin...
# 151  [kasey, vista, detroit, senior, software_engin...
# 145  [kasey, vista, detroit, senior, software_engin...
# 130  [kasey, vista, detroit, senior, software_engin...
# 141  [kasey, vista, detroit, senior, software_engin...
# 146  [kasey, vista, detroit, senior, software_engin...
# 137  [kasey, vista, detroit, senior, software_engin...
# 149  [kasey, vista, detroit, senior, software_engin...
# 144  [kasey, vista, detroit, senior, software_engin...
# 154  [kasey, vista, detroit, senior, software_engin...
# 147  [kasey, vista, detroit, senior, software_engin...
# 153  [kasey, vista, detroit, senior, software_engin...
# 152  [kasey, vista, detroit, senior, software_engin...
# 127  [kasey, vista, detroit, senior, software_engin...
# 132  [kasey, vista, detroit, senior, software_engin...
# 131  [kasey, vista, detroit, senior, software_engin...
# 126  [kasey, vista, detroit, senior, software_engin...
# 140  [kasey, vista, detroit, senior, software_engin...
# 135  [kasey, vista, detroit, senior, software_engin...
# 148  [kasey, vista, detroit, senior, software_engin...
# 138  [kasey, vista, detroit, senior, software_engin...
# 150  [kasey, vista, detroit, senior, software_engin...
# 139  [kasey, vista, detroit, senior, software_engin...
#
#                                              Job_Title  \
# 129                        Machine Learning Engineer 2
# 128                          Machine Learning Engineer
# 125                                   Data Scientist 2
# 124                                     Data Scientist
# 134                           AUTOMATION TEST ENGINEER
# 136                       Business Solutions Architect
# 142                                Front End Developer
# 143                       Application Support Engineer
# 133                         Web Developer Full Stack 2
# 151  Principal Application Analyst-Supply Chain Lawson
# 145      9001 Data Security Administrator - Unix & IAM
# 130                                Security Specialist
# 141  Sr. Web Application Developer (Cloud Team) - C...
# 146                          Software Engineer Manager
# 137  Java Developer (mid level)- FT- GREAT culture,...
# 149                       Windows System Administrator
# 144                         OpenStack Engineer - 12185
# 154                                IT Business Analyst
# 147                        Sales Engineer - Los Angles
# 153             Java Architect - Denver, CO - Fulltime
# 152                            Messaging Administrator
# 127                                   HCM Consultant 2
# 132                           Web Developer Full Stack
# 131                              Security Specialist 2
# 126                                     HCM Consultant
# 140                                   Network Engineer
# 135                      Information Security Engineer
# 148                                    Project Manager
# 138                                    DevOps Engineer
# 150                           Test Lead / Test Manager
# 139                                 SAP FICO Architect
#
#                                  clean_Job_Description  \
# 129  collaborate multidisciplinary_team gain_insigh...
# 128  leveraging_latest machine deep_learning techni...
# 125  reporting director data analytics senior data_...
# 124  master_degree stem field including_limited com...
# 134  looking selenium engineer must solid java codi...
# 136  galaxe_solutionsevery day solution affect_peop...
# 142  fulltime_position javascript developer financi...
# 143  summaryour_client leading_provider online vide...
# 133  enter existing codebases extend functionality ...
# 151  vanderhouwen_job like find please join talent ...
# 145  must unix iam identity_access management scrip...
# 130  fast_paced environment combine technical secur...
# 141  bluebeam looking_talented sr web developer pas...
# 146  vanderhouwen_job like find please join talent ...
# 137  java developerfull time direct hirebolingbrook...
# 149  window system administrator window system admi...
# 144  description senior member team responsible pro...
# 154  genesis looking business analyst long_term con...
# 147  genesis currently_seeking sale engineer steel ...
# 153  client healthcare software industry seeking ja...
# 152  genesis actively_seeking messaging administrat...
# 127  peoplesoft oracle_eb implementation support hc...
# 132  graduate_degree information technology similar...
# 131  handling incoming_request assistance business ...
# 126  oracle cloud hcm absence consultant responsibl...
# 140  network engineer description network engineer ...
# 135  university chicago rapidly_growing security pr...
# 148  vanderhouwen_job like find please join talent ...
# 138  midtown based high tech firm immediate innovat...
# 150  location_atlanta gajob title test lead manager...
# 139  looking senior sap_fico architect join_u fullt...
#
#                                 tokens_Job_Description  tfidf_cosine    WMD
# 129  [collaborate, multidisciplinary_team, gain_ins...         0.326  0.579
# 128  [leveraging_latest, machine, deep_learning, te...         0.246  0.572
# 125  [reporting, director, data, analytics, senior,...         0.313  0.569
# 124  [master_degree, stem, field, including_limited...         0.160  0.566
# 134  [looking, selenium, engineer, must, solid, jav...         0.092  0.556
# 136  [galaxe_solutionsevery, day, solution, affect_...         0.086  0.543
# 142  [fulltime_position, javascript, developer, fin...         0.078  0.538
# 143  [summaryour_client, leading_provider, online, ...         0.064  0.537
# 133  [enter, existing, codebases, extend, functiona...         0.053  0.536
# 151  [vanderhouwen_job, like, find, please, join, t...         0.065  0.535
# 145  [must, unix, iam, identity_access, management,...         0.057  0.535
# 130  [fast_paced, environment, combine, technical, ...         0.039  0.533
# 141  [bluebeam, looking_talented, sr, web, develope...         0.074  0.531
# 146  [vanderhouwen_job, like, find, please, join, t...         0.057  0.528
# 137  [java, developerfull, time, direct, hireboling...         0.046  0.528
# 149  [window, system, administrator, window, system...         0.043  0.527
# 144  [description, senior, member, team, responsibl...         0.042  0.526
# 154  [genesis, looking, business, analyst, long_ter...         0.067  0.526
# 147  [genesis, currently_seeking, sale, engineer, s...         0.050  0.524
# 153  [client, healthcare, software, industry, seeki...         0.043  0.522
# 152  [genesis, actively_seeking, messaging, adminis...         0.036  0.514
# 127  [peoplesoft, oracle_eb, implementation, suppor...         0.039  0.513
# 132  [graduate_degree, information, technology, sim...         0.036  0.512
# 131  [handling, incoming_request, assistance, busin...         0.026  0.510
# 126  [oracle, cloud, hcm, absence, consultant, resp...         0.042  0.510
# 140  [network, engineer, description, network, engi...         0.033  0.508
# 135  [university, chicago, rapidly_growing, securit...         0.036  0.506
# 148  [vanderhouwen_job, like, find, please, join, t...         0.026  0.506
# 138  [midtown, based, high, tech, firm, immediate, ...         0.025  0.505
# 150  [location_atlanta, gajob, title, test, lead, m...         0.025  0.491
# 139  [looking, senior, sap_fico, architect, join_u,...         0.013  0.476

# %% [markdown]
# Observamos altos valores de similitud para ambas métricas para los puestos 'Machine Learning Engineer 2', 'Machine Learning Engineer', 'Data Scientist', 'Data Scientist 2' (algo esperable).
# Y tambien observamos bajos valores para puestos como 'SAP FICO Architect', 'Test Lead / Test Manager', 'DevOps Engineer', 'Project Manager' (algo esperble).

# %% [markdown]
# ### 6.2-Job 'Security Specialist 2'.

# %%
df_Security_Specialist_2 = df_compar_cand_jobs_loaded.loc[df_compar_cand_jobs_loaded['Job_Title'] == 'Security Specialist 2']
df_Security_Specialist_2
print(df_Security_Specialist_2.shape)
df_Security_Specialist_2
# Out:
# (101, 8)
#                   Candidate_Name  \
# 7      DataScientist_Karla_Lewis
# 38     DataScientist_Rahul_Malik
# 69          HCM_Federico_Calonge
# 100             HCM_Robert_Smith
# 131   MLEngineer_Bradly_Johnston
# ...                          ...
# 2983                Naveen Arora
# 3014        Naveen Kumar Bandela
# 3045             Naveen.S_Resume
# 3076             Navneeth Resume
# 3107               Neha Mugghala
#
#                                        clean_Content_CV  \
# 7     data_scientist brooklyn ny data_scientist grub...
# 38    nlp data_scientist brooklyn ny nlp data_scient...
# 69    hcm technical consultant working oracle tool p...
# 100   sap_hcm consultant com qwikresume marshville r...
# 131   kasey vista detroit senior software_engineer m...
# ...                                                 ...
# 2983  naveen arora current location_chicago il visa ...
# 3014  naveen kumar bandela java full_stack developer...
# 3045  naveen looking contribute design analysis deve...
# 3076  navneet gupta project program_manager pmp pmp_...
# 3107  sourya senior java_ee developer working variou...
#
#                                       tokens_Content_CV  \
# 7     [data_scientist, brooklyn, ny, data_scientist,...
# 38    [nlp, data_scientist, brooklyn, ny, nlp, data_...
# 69    [hcm, technical, consultant, working, oracle, ...
# 100   [sap_hcm, consultant, com, qwikresume, marshvi...
# 131   [kasey, vista, detroit, senior, software_engin...
# ...                                                 ...
# 2983  [naveen, arora, current, location_chicago, il,...
# 3014  [naveen, kumar, bandela, java, full_stack, dev...
# 3045  [naveen, looking, contribute, design, analysis...
# 3076  [navneet, gupta, project, program_manager, pmp...
# 3107  [sourya, senior, java_ee, developer, working, ...
#
#                   Job_Title  \
# 7     Security Specialist 2
# 38    Security Specialist 2
# 69    Security Specialist 2
# 100   Security Specialist 2
# 131   Security Specialist 2
# ...                     ...
# 2983  Security Specialist 2
# 3014  Security Specialist 2
# 3045  Security Specialist 2
# 3076  Security Specialist 2
# 3107  Security Specialist 2
#
#                                   clean_Job_Description  \
# 7     handling incoming_request assistance business ...
# 38    handling incoming_request assistance business ...
# 69    handling incoming_request assistance business ...
# 100   handling incoming_request assistance business ...
# 131   handling incoming_request assistance business ...
# ...                                                 ...
# 2983  handling incoming_request assistance business ...
# 3014  handling incoming_request assistance business ...
# 3045  handling incoming_request assistance business ...
# 3076  handling incoming_request assistance business ...
# 3107  handling incoming_request assistance business ...
#
#                                  tokens_Job_Description  tfidf_cosine    WMD
# 7     [handling, incoming_request, assistance, busin...         0.010  0.492
# 38    [handling, incoming_request, assistance, busin...         0.012  0.491
# 69    [handling, incoming_request, assistance, busin...         0.023  0.503
# 100   [handling, incoming_request, assistance, busin...         0.011  0.498
# 131   [handling, incoming_request, assistance, busin...         0.026  0.510
# ...                                                 ...           ...    ...
# 2983  [handling, incoming_request, assistance, busin...         0.055  0.513
# 3014  [handling, incoming_request, assistance, busin...         0.029  0.498
# 3045  [handling, incoming_request, assistance, busin...         0.047  0.503
# 3076  [handling, incoming_request, assistance, busin...         0.092  0.521
# 3107  [handling, incoming_request, assistance, busin...         0.041  0.501
#
# [101 rows x 8 columns]

# %%
#Ordenamos de mayor a menor de acuerdo a tfidf_cosine:
df_Security_Specialist_2.sort_values(by=['tfidf_cosine'], ascending=False)
# Out:
#                       Candidate_Name  \
# 224   SecuritySpecialist_Denis Banik
# 193   SecuritySpecialist_Ahmed Wayne
# 1433            Deepika Chintalapati
# 3076                 Navneeth Resume
# 1464                      Deepika DC
# ...                              ...
# 1123         Balakrishna Sudabathula
# 1154         Bapuji Hadoop developer
# 38         DataScientist_Rahul_Malik
# 100                 HCM_Robert_Smith
# 7          DataScientist_Karla_Lewis
#
#                                        clean_Content_CV  \
# 224   detail_oriented result_driven security analyst...
# 193   abu_dhabi uae egyptian dynamic sr infrastructu...
# 1433  deepika around sr project_manager oracle_datab...
# 3076  navneet gupta project program_manager pmp pmp_...
# 1464  deepika deepika experienced project_manager or...
# ...                                                 ...
# 1123  name balakrishna sudabathula software_developm...
# 1154  bapuji sr hadoop_developer including big_data ...
# 38    nlp data_scientist brooklyn ny nlp data_scient...
# 100   sap_hcm consultant com qwikresume marshville r...
# 7     data_scientist brooklyn ny data_scientist grub...
#
#                                       tokens_Content_CV  \
# 224   [detail_oriented, result_driven, security, ana...
# 193   [abu_dhabi, uae, egyptian, dynamic, sr, infras...
# 1433  [deepika, around, sr, project_manager, oracle_...
# 3076  [navneet, gupta, project, program_manager, pmp...
# 1464  [deepika, deepika, experienced, project_manage...
# ...                                                 ...
# 1123  [name, balakrishna, sudabathula, software_deve...
# 1154  [bapuji, sr, hadoop_developer, including, big_...
# 38    [nlp, data_scientist, brooklyn, ny, nlp, data_...
# 100   [sap_hcm, consultant, com, qwikresume, marshvi...
# 7     [data_scientist, brooklyn, ny, data_scientist,...
#
#                   Job_Title  \
# 224   Security Specialist 2
# 193   Security Specialist 2
# 1433  Security Specialist 2
# 3076  Security Specialist 2
# 1464  Security Specialist 2
# ...                     ...
# 1123  Security Specialist 2
# 1154  Security Specialist 2
# 38    Security Specialist 2
# 100   Security Specialist 2
# 7     Security Specialist 2
#
#                                   clean_Job_Description  \
# 224   handling incoming_request assistance business ...
# 193   handling incoming_request assistance business ...
# 1433  handling incoming_request assistance business ...
# 3076  handling incoming_request assistance business ...
# 1464  handling incoming_request assistance business ...
# ...                                                 ...
# 1123  handling incoming_request assistance business ...
# 1154  handling incoming_request assistance business ...
# 38    handling incoming_request assistance business ...
# 100   handling incoming_request assistance business ...
# 7     handling incoming_request assistance business ...
#
#                                  tokens_Job_Description  tfidf_cosine    WMD
# 224   [handling, incoming_request, assistance, busin...         0.131  0.526
# 193   [handling, incoming_request, assistance, busin...         0.110  0.532
# 1433  [handling, incoming_request, assistance, busin...         0.102  0.524
# 3076  [handling, incoming_request, assistance, busin...         0.092  0.521
# 1464  [handling, incoming_request, assistance, busin...         0.082  0.514
# ...                                                 ...           ...    ...
# 1123  [handling, incoming_request, assistance, busin...         0.019  0.497
# 1154  [handling, incoming_request, assistance, busin...         0.017  0.495
# 38    [handling, incoming_request, assistance, busin...         0.012  0.491
# 100   [handling, incoming_request, assistance, busin...         0.011  0.498
# 7     [handling, incoming_request, assistance, busin...         0.010  0.492
#
# [101 rows x 8 columns]

# %%
#Ordenamos de mayor a menor de acuerdo a WMD:
df_Security_Specialist_2.sort_values(by=['WMD'], ascending=False)
# Out:
#                       Candidate_Name  \
# 193   SecuritySpecialist_Ahmed Wayne
# 224   SecuritySpecialist_Denis Banik
# 1433            Deepika Chintalapati
# 3076                 Navneeth Resume
# 2828       Murali_Project Manager QA
# ...                              ...
# 1960                 Jayadattaperi N
# 7          DataScientist_Karla_Lewis
# 2053                     KIRAN KUMAR
# 38         DataScientist_Rahul_Malik
# 2797                       Mounika_P
#
#                                        clean_Content_CV  \
# 193   abu_dhabi uae egyptian dynamic sr infrastructu...
# 224   detail_oriented result_driven security analyst...
# 1433  deepika around sr project_manager oracle_datab...
# 3076  navneet gupta project program_manager pmp pmp_...
# 2828  muralidhar chandrashekar st_louis mo currently...
# ...                                                 ...
# 1960  jayadattaperi looking contract c_c c role arou...
# 7     data_scientist brooklyn ny data_scientist grub...
# 2053  kiran kumar mobile design ooa_ood development ...
# 38    nlp data_scientist brooklyn ny nlp data_scient...
# 2797  mounika front_end developer wellington managem...
#
#                                       tokens_Content_CV  \
# 193   [abu_dhabi, uae, egyptian, dynamic, sr, infras...
# 224   [detail_oriented, result_driven, security, ana...
# 1433  [deepika, around, sr, project_manager, oracle_...
# 3076  [navneet, gupta, project, program_manager, pmp...
# 2828  [muralidhar, chandrashekar, st_louis, mo, curr...
# ...                                                 ...
# 1960  [jayadattaperi, looking, contract, c_c, c, rol...
# 7     [data_scientist, brooklyn, ny, data_scientist,...
# 2053  [kiran, kumar, mobile, design, ooa_ood, develo...
# 38    [nlp, data_scientist, brooklyn, ny, nlp, data_...
# 2797  [mounika, front_end, developer, wellington, ma...
#
#                   Job_Title  \
# 193   Security Specialist 2
# 224   Security Specialist 2
# 1433  Security Specialist 2
# 3076  Security Specialist 2
# 2828  Security Specialist 2
# ...                     ...
# 1960  Security Specialist 2
# 7     Security Specialist 2
# 2053  Security Specialist 2
# 38    Security Specialist 2
# 2797  Security Specialist 2
#
#                                   clean_Job_Description  \
# 193   handling incoming_request assistance business ...
# 224   handling incoming_request assistance business ...
# 1433  handling incoming_request assistance business ...
# 3076  handling incoming_request assistance business ...
# 2828  handling incoming_request assistance business ...
# ...                                                 ...
# 1960  handling incoming_request assistance business ...
# 7     handling incoming_request assistance business ...
# 2053  handling incoming_request assistance business ...
# 38    handling incoming_request assistance business ...
# 2797  handling incoming_request assistance business ...
#
#                                  tokens_Job_Description  tfidf_cosine    WMD
# 193   [handling, incoming_request, assistance, busin...         0.110  0.532
# 224   [handling, incoming_request, assistance, busin...         0.131  0.526
# 1433  [handling, incoming_request, assistance, busin...         0.102  0.524
# 3076  [handling, incoming_request, assistance, busin...         0.092  0.521
# 2828  [handling, incoming_request, assistance, busin...         0.067  0.520
# ...                                                 ...           ...    ...
# 1960  [handling, incoming_request, assistance, busin...         0.031  0.493
# 7     [handling, incoming_request, assistance, busin...         0.010  0.492
# 2053  [handling, incoming_request, assistance, busin...         0.029  0.491
# 38    [handling, incoming_request, assistance, busin...         0.012  0.491
# 2797  [handling, incoming_request, assistance, busin...         0.023  0.490
#
# [101 rows x 8 columns]

# %% [markdown]
# Observamos que los 2 Candidatos que tienen los mayores valores de similitud para ambas métricas son 'SecuritySpecialist_Denis Banik' y 'SecuritySpecialist_Ahmed Wayne' (algo esperable).

# %% [markdown]
# ### 7-Export del DF para usarlo en el siguiente Jupyter Notebook.

# %%
#Mostramos como se ve finalmente:
df_compar_cand_jobs_loaded
# Out:
#                  Candidate_Name  \
# 0     DataScientist_Karla_Lewis
# 1     DataScientist_Karla_Lewis
# 2     DataScientist_Karla_Lewis
# 3     DataScientist_Karla_Lewis
# 4     DataScientist_Karla_Lewis
# ...                         ...
# 3126              Neha Mugghala
# 3127              Neha Mugghala
# 3128              Neha Mugghala
# 3129              Neha Mugghala
# 3130              Neha Mugghala
#
#                                        clean_Content_CV  \
# 0     data_scientist brooklyn ny data_scientist grub...
# 1     data_scientist brooklyn ny data_scientist grub...
# 2     data_scientist brooklyn ny data_scientist grub...
# 3     data_scientist brooklyn ny data_scientist grub...
# 4     data_scientist brooklyn ny data_scientist grub...
# ...                                                 ...
# 3126  sourya senior java_ee developer working variou...
# 3127  sourya senior java_ee developer working variou...
# 3128  sourya senior java_ee developer working variou...
# 3129  sourya senior java_ee developer working variou...
# 3130  sourya senior java_ee developer working variou...
#
#                                       tokens_Content_CV  \
# 0     [data_scientist, brooklyn, ny, data_scientist,...
# 1     [data_scientist, brooklyn, ny, data_scientist,...
# 2     [data_scientist, brooklyn, ny, data_scientist,...
# 3     [data_scientist, brooklyn, ny, data_scientist,...
# 4     [data_scientist, brooklyn, ny, data_scientist,...
# ...                                                 ...
# 3126  [sourya, senior, java_ee, developer, working, ...
# 3127  [sourya, senior, java_ee, developer, working, ...
# 3128  [sourya, senior, java_ee, developer, working, ...
# 3129  [sourya, senior, java_ee, developer, working, ...
# 3130  [sourya, senior, java_ee, developer, working, ...
#
#                                               Job_Title  \
# 0                                        Data Scientist
# 1                                      Data Scientist 2
# 2                                        HCM Consultant
# 3                                      HCM Consultant 2
# 4                             Machine Learning Engineer
# ...                                                 ...
# 3126                           Test Lead / Test Manager
# 3127  Principal Application Analyst-Supply Chain Lawson
# 3128                            Messaging Administrator
# 3129             Java Architect - Denver, CO - Fulltime
# 3130                                IT Business Analyst
#
#                                   clean_Job_Description  \
# 0     master_degree stem field including_limited com...
# 1     reporting director data analytics senior data_...
# 2     oracle cloud hcm absence consultant responsibl...
# 3     peoplesoft oracle_eb implementation support hc...
# 4     leveraging_latest machine deep_learning techni...
# ...                                                 ...
# 3126  location_atlanta gajob title test lead manager...
# 3127  vanderhouwen_job like find please join talent ...
# 3128  genesis actively_seeking messaging administrat...
# 3129  client healthcare software industry seeking ja...
# 3130  genesis looking business analyst long_term con...
#
#                                  tokens_Job_Description  tfidf_cosine    WMD
# 0     [master_degree, stem, field, including_limited...         0.043  0.517
# 1     [reporting, director, data, analytics, senior,...         0.111  0.525
# 2     [oracle, cloud, hcm, absence, consultant, resp...         0.018  0.501
# 3     [peoplesoft, oracle_eb, implementation, suppor...         0.013  0.500
# 4     [leveraging_latest, machine, deep_learning, te...         0.050  0.518
# ...                                                 ...           ...    ...
# 3126  [location_atlanta, gajob, title, test, lead, m...         0.026  0.485
# 3127  [vanderhouwen_job, like, find, please, join, t...         0.106  0.516
# 3128  [genesis, actively_seeking, messaging, adminis...         0.063  0.512
# 3129  [client, healthcare, software, industry, seeki...         0.081  0.507
# 3130  [genesis, looking, business, analyst, long_ter...         0.067  0.505
#
# [3131 rows x 8 columns]

# %%
#Ahora si, exportamos nuestro DF:
#df_compar_cand_jobs_loaded.to_pickle('DF_Exportado_Jobs_And_Candidates_tfidf_cosine_and_wmd')
