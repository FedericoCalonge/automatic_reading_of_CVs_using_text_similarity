# %% [markdown]
# ### About
# Aplicaremos las técnicas de 'WMD' y 'Cosine Similarity' para medir distancias y obtener similitudes entre textos.
# Previamente a aplicar Cosine Similarity usaremos TF-IDF para...  **COMPLETAR**
# Y, previamente a aplicar WMD usaremos Word Embedding para... **COMPLETAR**
#
# Las comparaciones que realizaremos serán entre el contenido de los CVs de los Candidatos y las cualificaciones requeridas para los mismos, encontradas dentro de las descripciones de los Puestos.
#
# Como datasets utilizaremos:
# * **(COMPLETAR CON EL NÚMERO FINAL)** CVs en pdf. Ubicación PDFs: "Archivos 2-Especificos/Ejemplo1_Dataset_CVs_And_Job_Desc/EN/PDFs_CVs".
# * **(COMPLETAR CON EL NÚMERO FINAL)** descripciones de trabajo, las cuales corresponden a:
#
# Ubicación CVs: **COMPLETAR**. hoola
# Ubicación Descripciones Puestos: **COMPLETAR**.

# %% [markdown]
# ## Índice:
#
# * 1-Armado de Datasets y Limpieza de datos.
#     * 1.1-Impotando librerías necesarias.
#     * 1.2-Funciones necesarias para la Limpieza de datos. (*)
#     * 1.3-Armado y Limpieza de Dataset Puestos.
#     * 1.4-Armado y Limpieza de Dataset CVs.
#
#
# * 2-Realizando Comparaciones y obteniendo Similitudes.
#      * 2.1- TF-IDF & Cosine Similarity.
#      * 2.2- Word Embedding (Word2vec) & WMD.
#
#
# * 3-Exportamos el CSV con los resultados para utilizarlo en el Notebook "2-KMEANS_&_KNN".
#
# (*) El procedimiento para la Limpieza de los CVs y los Puestos será el siguiente:
# 1. Convertimos todo a minúscula.
# 2. Eliminamos datos no relevantes para nuestros análisis (mails y páginas web).
# 3. Eliminamos signos de puntuación y caracterés especiales (incluyendo números).
# 4. Eliminamos stop words.
# 5. Eliminamos common words no relevantes para nuestros análisis.
# 6. Aplicamos Lematización y Tokenización.

# %% [markdown]
# ## 1-Armado de Datasets y Limpieza de datos.

# %% [markdown]
# ### 1.1-Importando librerias necesarias.

# %%
from gensim.models import KeyedVectors
import matplotlib.pyplot as  plt
from collections import Counter
import pandas as pd
import numpy as np
import random
import string
import math
import re
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
# Out:
# /home/fedricio/anaconda3/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/fedricio/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### 1.2-Funciones necesarias para la Limpieza de datos.

# %%
import regex as re                        #Usado en la función remove_punctuation_and_special_characters.
from nltk.stem import WordNetLemmatizer   #Usado para lematización.
nltk.download('wordnet')
from nltk.tokenize import word_tokenize   #Usado para tokenizar.

#Definimos nuestras stop words desde nltk:
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
            
def lower_text(DF,clean_column):
    #Pasamos todo a minúscula.
    DF[clean_column] = DF[clean_column].apply(lambda x: x.lower() if isinstance(x,str) else x)

def delete_emails_and_web_pages(DF,clean_column):
    #Macheamos páginas con www, http o https:
    DF[clean_column] = DF[clean_column].apply(lambda x: re.sub('(www|http:|https:)+[^\s]+[\w]',' ', x) if isinstance(x,str) else x) 
    #Macheamos e-mails:
    DF[clean_column] = DF[clean_column].apply(lambda x: re.sub('\S*@\S*\s?',' ', x) if isinstance(x,str) else x)
        #Explicación macheo:
            #\S* : secuencia de caracteres que NO son espacios. 
            #@ : el @
            #\S* : otra secuencia de caracteres que NO son espacios.
            #\s? : Y eventualmente un espacio, si acá hay uno. El '?' es necesario para
            #machear una dirección de correo al final de la linea. Entonces, si acá es espacio, siempre macheará.
            #Ver demo: https://regex101.com/r/J0ohIf/1

def delete_common_words(DF,clean_column):
    #Creamos previamente un txt donde colocamos palabras comunes que NO son necesarias 
    #para nuestro análisis y macheo (meses y sus abreviaciones, categorías de un cv -education, work experience, etc.)
    #y eliminamos estas palabras de nuestra columna.

    with open('common_words.txt') as f2:
        content = f2.read()
        
    tokens_common_words = word_tokenize(content)  #tokenizo las common words
    DF[clean_column] = DF[clean_column].apply(lambda x: ' '.join([item for item in x.split() if item not in tokens_common_words]))

def delete_candidate_name(DF,clean_column):
    with open('candidate_names.txt') as f2:
        content = f2.read()
        
    tokens_common_words = word_tokenize(content)
    DF[clean_column] = DF[clean_column].apply(lambda x: ' '.join([item for item in x.split() if item not in tokens_common_words]))

def remove_stop_words(DF,clean_column):
    DF[clean_column] = DF[clean_column].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

def remove_punctuation_and_special_characters(DF,clean_column):
    DF[clean_column] = DF[clean_column].apply(lambda x: re.sub('[\W+]|(\d+)',' ', x) if isinstance(x,str) else x)
    #Macheamos cualquier non-word [\W+]  ; y  los números (\d+)
    
def tokenize_and_lemmatization(text_column):
    #Tokenizar es el proceso de parsear Strings de texto en diferentes secciones ("tokens"). 
    #Para esto usamos la función "word_tokenize". 
    #Diferencia lematizar vs derivar (stemming): https://qastack.mx/programming/1787110/what-is-the-difference-between-lemmatization-vs-stemming
    tokens = word_tokenize(text_column) #Tokenizamos.
    wordnet_lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [wordnet_lemmatizer.lemmatize(tok).lower() for tok in tokens] # Stem words.
    return list(lemmatized_tokens)

def cleaning_DF(DF,column_to_clean,flag_candidate): #Si es un candidato (flag_candidate=True) entonces eliminamos todas las apariciones del Nombre en el CV.
    clean_column='clean_'+column_to_clean
    DF[clean_column]=DF[column_to_clean]            #Copiamos el contenido de 'column_to_clean' en 'clean_column' para utilizarla en las funciones posteriores.
    lower_text(DF,clean_column)
    delete_emails_and_web_pages(DF,clean_column)
    remove_punctuation_and_special_characters(DF,clean_column)
    remove_stop_words(DF,clean_column)
    delete_common_words(DF,clean_column)
    if(flag_candidate==True):                       #Si es un candidato...
        delete_candidate_name(DF,clean_column)
    
def tokenize_and_lemmatize(DF,column_to_clean):
    clean_column='clean_'+column_to_clean
    tokens_column='tokens_'+column_to_clean
    DF[tokens_column] = DF[clean_column].apply(tokenize_and_lemmatization)  #tokenize_and_lemmatization devuelve tokens.
    DF[clean_column] = DF[tokens_column].apply(' '.join)                    #destokenizamos para obtener nuevamente nuestro texto (luego de aplicar lematización) y colocarlo en DF[clean_column].
# Out:
# [nltk_data] Downloading package wordnet to /home/fedricio/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### 1.3-Armado y Limpieza de Dataset Puestos.

# %% [markdown]
# ## 1-Jobs_CSV

# %%
df_Jobs = pd.read_csv("../Datasets_CVs_And_Job_Descriptions/EN/Job_Descr/1-Jobs_CSV/Positions_Qualif.csv")
df_Jobs = df_Jobs.rename(columns={'job_title': 'Job_Title', 'job_description':'Job_Description'})
df_Jobs = df_Jobs.sort_values('Job_Title', ascending=True)
df_Jobs = df_Jobs.reset_index(drop=True)
df_Jobs
# Out:
#                      Job_Title  \
# 0               Data Scientist
# 1             Data Scientist 2
# 2               HCM Consultant
# 3             HCM Consultant 2
# 4    Machine Learning Engineer
# 5  Machine Learning Engineer 2
# 6          Security Specialist
# 7        Security Specialist 2
# 8     Web Developer Full Stack
# 9   Web Developer Full Stack 2
#
#                                      Job_Description
# 0  Master’s degree or above in a STEM field, incl...
# 1  \nReporting to the Director, Data & Analytics,...
# 2  \nThe Oracle Cloud HCM Absence Consultant will...
# 3  4+ years of experience in PeopleSoft or Oracle...
# 4  Leveraging the latest machine and deep learnin...
# 5  Collaborate with a multidisciplinary team to g...
# 6  Work in a fast-paced environment that combine ...
# 7  \n    Handling incoming requests for assistanc...
# 8  \n\n    Graduate Degree in Information Technol...
# 9  \n· Enter existing website codebases and exten...

# %% [markdown]
# ## 2-csv_dice_com-job_us_sample

# %%
path_jobs_2='../Datasets_CVs_And_Job_Descriptions/EN/Job_Descr/'
df_Jobs_2 = pd.read_csv(path_jobs_2+'/2-csv_dice_com-job_us_sample.csv', usecols= ['jobdescription','jobtitle'])
df_Jobs_2 = df_Jobs_2.rename(columns={'jobtitle': 'Job_Title', 'jobdescription':'Job_Description'})
df_Jobs_2 = df_Jobs_2.reset_index(drop=True)
df_Jobs_2
# Out:
#                                          Job_Description  \
# 0      Looking for Selenium engineers...must have sol...
# 1      The University of Chicago has a rapidly growin...
# 2      GalaxE.SolutionsEvery day, our solutions affec...
# 3      Java DeveloperFull-time/direct-hireBolingbrook...
# 4      Midtown based high tech firm has an immediate ...
# ...                                                  ...
# 21995   Company Description We are searching for a ta...
# 21996   CONTACT - priya@omegasolutioninc.com / 408-45...
# 21997  Do you take pride in your work knowing that th...
# 21998  Company Description What We Can Offer YouAs th...
# 21999  Experience in C/C++ ProgrammingDevelopment exp...
#
#                                                Job_Title
# 0                               AUTOMATION TEST ENGINEER
# 1                          Information Security Engineer
# 2                           Business Solutions Architect
# 3      Java Developer (mid level)- FT- GREAT culture,...
# 4                                        DevOps Engineer
# ...                                                  ...
# 21995                                       Web Designer
# 21996  Senior Front End Web Developer - Full Time at ...
# 21997                                         QA Analyst
# 21998                               Tech Lead-Full Stack
# 21999                                   C/C++ Programmer
#
# [22000 rows x 2 columns]

# %%
#Eliminamos los duplicados.
df_Jobs_2 = df_Jobs_2.drop_duplicates(subset=None, keep='first', inplace=False)
df_Jobs_2 = df_Jobs_2.reset_index(drop=True)
df_Jobs_2
# Out:
#                                          Job_Description  \
# 0      Looking for Selenium engineers...must have sol...
# 1      The University of Chicago has a rapidly growin...
# 2      GalaxE.SolutionsEvery day, our solutions affec...
# 3      Java DeveloperFull-time/direct-hireBolingbrook...
# 4      Midtown based high tech firm has an immediate ...
# ...                                                  ...
# 20578   Company Description We are searching for a ta...
# 20579   CONTACT - priya@omegasolutioninc.com / 408-45...
# 20580  Do you take pride in your work knowing that th...
# 20581  Company Description What We Can Offer YouAs th...
# 20582  Experience in C/C++ ProgrammingDevelopment exp...
#
#                                                Job_Title
# 0                               AUTOMATION TEST ENGINEER
# 1                          Information Security Engineer
# 2                           Business Solutions Architect
# 3      Java Developer (mid level)- FT- GREAT culture,...
# 4                                        DevOps Engineer
# ...                                                  ...
# 20578                                       Web Designer
# 20579  Senior Front End Web Developer - Full Time at ...
# 20580                                         QA Analyst
# 20581                               Tech Lead-Full Stack
# 20582                                   C/C++ Programmer
#
# [20583 rows x 2 columns]

# %% [markdown]
# ## Unimos los datasets:

# %%
df_Jobs = df_Jobs.append(df_Jobs_2, ignore_index=True)
df_Jobs
# Out:
#                                                Job_Title  \
# 0                                         Data Scientist
# 1                                       Data Scientist 2
# 2                                         HCM Consultant
# 3                                       HCM Consultant 2
# 4                              Machine Learning Engineer
# ...                                                  ...
# 20588                                       Web Designer
# 20589  Senior Front End Web Developer - Full Time at ...
# 20590                                         QA Analyst
# 20591                               Tech Lead-Full Stack
# 20592                                   C/C++ Programmer
#
#                                          Job_Description
# 0      Master’s degree or above in a STEM field, incl...
# 1      \nReporting to the Director, Data & Analytics,...
# 2      \nThe Oracle Cloud HCM Absence Consultant will...
# 3      4+ years of experience in PeopleSoft or Oracle...
# 4      Leveraging the latest machine and deep learnin...
# ...                                                  ...
# 20588   Company Description We are searching for a ta...
# 20589   CONTACT - priya@omegasolutioninc.com / 408-45...
# 20590  Do you take pride in your work knowing that th...
# 20591  Company Description What We Can Offer YouAs th...
# 20592  Experience in C/C++ ProgrammingDevelopment exp...
#
# [20593 rows x 2 columns]

# %% [markdown]
# ## 3-csv_monster_com-job_sample

# %% [markdown]
# #### Limpieza de datos del DF de Puestos.

# %%
cleaning_DF(df_Jobs,'Job_Description',False)
tokenize_and_lemmatize(df_Jobs,'Job_Description')

# %%
#Tomamos el job_description de la posición 5 como ejemplo (Machine Learning Engineer 2'):

print(df_Jobs['Job_Description'].iloc[5])  
#non-expert  debería mantenerse.
#deberia juntar el Computer Science
print("#######################################################")
print(df_Jobs['clean_Job_Description'].iloc[5]) 
print("#######################################################")
print(df_Jobs['tokens_Job_Description'].iloc[5]) 
print("#######################################################")
# Out:
# Do you take pride in your work knowing that thousands of lives are positively impacted? Are you interested in being part of an award-winning Health Plan? Do you thrive in a mission-driven and fast-growing environment where the frontier of healthcare is constantly being pushed? Then, let's talk! We're looking for smart thinkers who enjoy challenges and want to help us shape the future of healthcare.The San Francisco Health Plan is an award winning managed care health plan designed by and for the people of San Francisco. Our mission is to provide affordable, high quality health care to San Francisco residents and support our safety net of clinics and providers.We are ambitious in our pursuits, passionate about our mission, and creative in our execution. We thrive on our culture of serving with respect, striving to excel, and teamwork.What makes SFHP different? Our people do. Every day, we are doing things to transform our city and the lives of over 130,000 people in the city! There hasn't been a more exciting time to join SFHP as we continue to grow and become a model for healthcare reform in the state and nation. We are one of the best places to work if your goal is to work in public health or managed care.Please visit us at www.sfhp.org.THE EXCITING CHALLENGEThe QA Analyst reviews software specifications and business requirements with software developers/business analysts and project managers in order to create test plans, cases and scripts to assure that applications are appropriately tested before they are implemented in the production environment. The QA Analyst will also work with the development team to assess requirements and provide QA testing estimates.ESSENTIAL DUTIES & RESPONSIBILITIES• Develop test plans and test cases for projects as assigned. • Design and execute test suites. Testing involves application (system integration testing & regression), functional, system, network, data and assist in user acceptance testing. • Work with developers and the Senior Manager of QA & Release Management to develop, maintain and execute quality assurance testing procedures and methodology.• Works closely with Development, QA and Business groups to understand the data needs for the creation of reusable data sets to support testing (Unit, functional, integration, UAT, regression, performance, etc.) • Perform backend testing using SQL queries to verify database transactions. • Setup database and test installation scripts to verify that database requirements are met (besides confirming that certain database objects, stored procedures, tables, views etc. are created) • Identify and track defects while effectively coordinating efforts with developers or responsible parties to ensure defect resolution. Provide analysis and data for use in debugging. • Support Project Managers and Business Systems Analysts with SIT related issues before releasing to end users for UAT (User Acceptance Testing). • Participate in planning and execution of tasks related to the evaluation of new testing methodologies and tools (system upgrades, Third-Party solutions, and integration with other Enterprise Systems).• Use judgment and creativity to design testing approach to meet requirements/specifications as provided by business analysts and software development managers. • Maintain current industry knowledge of testing concepts, best practices and procedures.• Follow internal procedures for change management, incident management, and escalation. • Develop test plans to check application infrastructure and application performance. Report on findings and make recommendations for improvement to developers, PM/BSAs, SFHP management and other ITS team members.• Other duties as assigned.CORE COMPETENCIES / KNOWLEDGE & SKILL REQUIREMENTSTechnical Knowledge, Planning & Execution:• In-depth experience in Software Quality Assurance & Testing. • Excellent understanding of SDLC, ALM and various software testing models and methodologies. • Ability to write test cases/sce ...
# #######################################################
# take pride knowing thousand life positively impacted interested part award winning health plan thrive mission driven fast growing environment frontier healthcare constantly pushed let talk looking smart thinker enjoy challenge want help u shape future healthcare san francisco health plan award winning managed care health plan designed people san francisco mission provide affordable high quality health care san francisco resident support safety net clinic provider ambitious pursuit passionate mission creative execution thrive culture serving respect striving excel teamwork make sfhp different people every day thing transform life people exciting time join sfhp continue grow become model healthcare reform nation one best place goal public health managed care please visit u exciting challengethe qa analyst review software specification business requirement software developer business analyst project manager order create test plan case script assure application appropriately tested implemented production environment qa analyst development team ass requirement provide qa testing estimate essential duty responsibility develop test plan test case project assigned design execute test suite testing involves application system integration testing regression functional system network data assist user acceptance testing developer senior manager qa release management develop maintain execute quality assurance testing procedure methodology work closely development qa business group understand data need creation reusable data set support testing unit functional integration uat regression performance perform backend testing using sql query verify database transaction setup database test installation script verify database requirement met besides confirming certain database object stored procedure table view created identify track defect effectively coordinating effort developer responsible party ensure defect resolution provide analysis data use debugging support project manager business system analyst sit related issue releasing end user uat user acceptance testing participate planning execution related evaluation new testing methodology tool system upgrade third party solution integration enterprise system use judgment creativity design testing approach meet requirement specification provided business analyst software development manager maintain current industry knowledge testing concept best practice procedure follow internal procedure change management incident management escalation develop test plan check application infrastructure application performance report finding make recommendation improvement developer pm bsas sfhp management team member duty assigned core competency knowledge skill requirementstechnical knowledge planning execution depth software quality assurance testing excellent understanding sdlc alm various software testing model methodology write test case scenario based business requirement tight deadline microsoft sql server window based application server sql tool redgate team foundation server visual studio testing web based application data warehouse infrastructure net environment good understanding xml html application written c asp net team foundation server source control tool configuration management tool managing uat sit staging environment detail oriented organized independent persistent quality commitment working structured testing environment demonstrated knowledge automated testing tool demonstrate solid understanding project initiative ensure delivery project requirement ii administration higher preferred sql server configuration sql higher preferred net framework preferredbusiness engagement collaboration communication solid communication communicate timely accurate status appropriate level stake holder establish relationship collaboratively cross functional team drive towards operational excellence defect free software ensure drive success deliver result metric apply posse depth knowledge industry discip ...
# #######################################################
# ['take', 'pride', 'knowing', 'thousand', 'life', 'positively', 'impacted', 'interested', 'part', 'award', 'winning', 'health', 'plan', 'thrive', 'mission', 'driven', 'fast', 'growing', 'environment', 'frontier', 'healthcare', 'constantly', 'pushed', 'let', 'talk', 'looking', 'smart', 'thinker', 'enjoy', 'challenge', 'want', 'help', 'u', 'shape', 'future', 'healthcare', 'san', 'francisco', 'health', 'plan', 'award', 'winning', 'managed', 'care', 'health', 'plan', 'designed', 'people', 'san', 'francisco', 'mission', 'provide', 'affordable', 'high', 'quality', 'health', 'care', 'san', 'francisco', 'resident', 'support', 'safety', 'net', 'clinic', 'provider', 'ambitious', 'pursuit', 'passionate', 'mission', 'creative', 'execution', 'thrive', 'culture', 'serving', 'respect', 'striving', 'excel', 'teamwork', 'make', 'sfhp', 'different', 'people', 'every', 'day', 'thing', 'transform', 'life', 'people', 'exciting', 'time', 'join', 'sfhp', 'continue', 'grow', 'become', 'model', 'healthcare', 'reform', 'nation', 'one', 'best', 'place', 'goal', 'public', 'health', 'managed', 'care', 'please', 'visit', 'u', 'exciting', 'challengethe', 'qa', 'analyst', 'review', 'software', 'specification', 'business', 'requirement', 'software', 'developer', 'business', 'analyst', 'project', 'manager', 'order', 'create', 'test', 'plan', 'case', 'script', 'assure', 'application', 'appropriately', 'tested', 'implemented', 'production', 'environment', 'qa', 'analyst', 'development', 'team', 'ass', 'requirement', 'provide', 'qa', 'testing', 'estimate', 'essential', 'duty', 'responsibility', 'develop', 'test', 'plan', 'test', 'case', 'project', 'assigned', 'design', 'execute', 'test', 'suite', 'testing', 'involves', 'application', 'system', 'integration', 'testing', 'regression', 'functional', 'system', 'network', 'data', 'assist', 'user', 'acceptance', 'testing', 'developer', 'senior', 'manager', 'qa', 'release', 'management', 'develop', 'maintain', 'execute', 'quality', 'assurance', 'testing', 'procedure', 'methodology', 'work', 'closely', 'development', 'qa', 'business', 'group', 'understand', 'data', 'need', 'creation', 'reusable', 'data', 'set', 'support', 'testing', 'unit', 'functional', 'integration', 'uat', 'regression', 'performance', 'perform', 'backend', 'testing', 'using', 'sql', 'query', 'verify', 'database', 'transaction', 'setup', 'database', 'test', 'installation', 'script', 'verify', 'database', 'requirement', 'met', 'besides', 'confirming', 'certain', 'database', 'object', 'stored', 'procedure', 'table', 'view', 'created', 'identify', 'track', 'defect', 'effectively', 'coordinating', 'effort', 'developer', 'responsible', 'party', 'ensure', 'defect', 'resolution', 'provide', 'analysis', 'data', 'use', 'debugging', 'support', 'project', 'manager', 'business', 'system', 'analyst', 'sit', 'related', 'issue', 'releasing', 'end', 'user', 'uat', 'user', 'acceptance', 'testing', 'participate', 'planning', 'execution', 'related', 'evaluation', 'new', 'testing', 'methodology', 'tool', 'system', 'upgrade', 'third', 'party', 'solution', 'integration', 'enterprise', 'system', 'use', 'judgment', 'creativity', 'design', 'testing', 'approach', 'meet', 'requirement', 'specification', 'provided', 'business', 'analyst', 'software', 'development', 'manager', 'maintain', 'current', 'industry', 'knowledge', 'testing', 'concept', 'best', 'practice', 'procedure', 'follow', 'internal', 'procedure', 'change', 'management', 'incident', 'management', 'escalation', 'develop', 'test', 'plan', 'check', 'application', 'infrastructure', 'application', 'performance', 'report', 'finding', 'make', 'recommendation', 'improvement', 'developer', 'pm', 'bsas', 'sfhp', 'management', 'team', 'member', 'duty', 'assigned', 'core', 'competency', 'knowledge', 'skill', 'requirementstechnical', 'knowledge', 'planning', 'execution', 'depth', 'software', 'quality', 'assurance', 'testing', 'excellent', 'understanding', 'sdlc', 'alm', 'various', 'software', 'testing', 'model', 'methodology', 'w ...
# #######################################################

# %%
df_Jobs
# Out:
#                                                Job_Title  \
# 0                                         Data Scientist
# 1                                       Data Scientist 2
# 2                                         HCM Consultant
# 3                                       HCM Consultant 2
# 4                              Machine Learning Engineer
# ...                                                  ...
# 20588                                       Web Designer
# 20589  Senior Front End Web Developer - Full Time at ...
# 20590                                         QA Analyst
# 20591                               Tech Lead-Full Stack
# 20592                                   C/C++ Programmer
#
#                                          Job_Description  \
# 0      Master’s degree or above in a STEM field, incl...
# 1      \nReporting to the Director, Data & Analytics,...
# 2      \nThe Oracle Cloud HCM Absence Consultant will...
# 3      4+ years of experience in PeopleSoft or Oracle...
# 4      Leveraging the latest machine and deep learnin...
# ...                                                  ...
# 20588   Company Description We are searching for a ta...
# 20589   CONTACT - priya@omegasolutioninc.com / 408-45...
# 20590  Do you take pride in your work knowing that th...
# 20591  Company Description What We Can Offer YouAs th...
# 20592  Experience in C/C++ ProgrammingDevelopment exp...
#
#                                    clean_Job_Description  \
# 0      master degree stem field including limited com...
# 1      reporting director data analytics senior data ...
# 2      oracle cloud hcm absence consultant responsibl...
# 3      peoplesoft oracle eb implementation support hc...
# 4      leveraging latest machine deep learning techni...
# ...                                                  ...
# 20588  company description searching talented creativ...
# 20589  location san francisco caterm full time perman...
# 20590  take pride knowing thousand life positively im...
# 20591  company description offer youas world leading ...
# 20592  c c programmingdevelopment win programming win...
#
#                                   tokens_Job_Description
# 0      [master, degree, stem, field, including, limit...
# 1      [reporting, director, data, analytics, senior,...
# 2      [oracle, cloud, hcm, absence, consultant, resp...
# 3      [peoplesoft, oracle, eb, implementation, suppo...
# 4      [leveraging, latest, machine, deep, learning, ...
# ...                                                  ...
# 20588  [company, description, searching, talented, cr...
# 20589  [location, san, francisco, caterm, full, time,...
# 20590  [take, pride, knowing, thousand, life, positiv...
# 20591  [company, description, offer, youas, world, le...
# 20592  [c, c, programmingdevelopment, win, programmin...
#
# [20593 rows x 4 columns]

# %% [markdown]
# ### Obtenemos los bi-grams y los guardamos en la columna 'tokens_Job_Description'

# %%
lista_vocab_jobs = df_Jobs['tokens_Job_Description'].tolist()
lista_vocab_jobs #lista de lista de tokens.
lista_vocab_jobs[9]  #la ultima lista es la 9
# Out:
# ['enter',
#  'existing',
#  'codebases',
#  'extend',
#  'functionality',
#  'scoped',
#  'feature',
#  'maintaining',
#  'efficient',
#  'quality',
#  'driven',
#  'timeline',
#  'implement',
#  'context',
#  'switching',
#  'technology',
#  'platform',
#  'server',
#  'stack',
#  'assist',
#  'site',
#  'maintenance',
#  'development',
#  'quickly',
#  'learn',
#  'understand',
#  'implement',
#  'new',
#  'old',
#  'technology',
#  'best',
#  'leverage',
#  'particular',
#  'project',
#  'effectively',
#  'deploy',
#  'code',
#  'production',
#  'environment',
#  'ensure',
#  'high',
#  'quality',
#  'service',
#  'communicate',
#  'technical',
#  'issue',
#  'risk',
#  'clearly',
#  'ensure',
#  'necessary',
#  'action',
#  'taken',
#  'timely',
#  'manner',
#  'communicating',
#  'technical',
#  'accumum',
#  'professionally',
#  'clearly',
#  'non',
#  'technical',
#  'team',
#  'member',
#  'client',
#  'excellent',
#  'english',
#  'communication',
#  'proficient',
#  'php',
#  'familiar',
#  'basic',
#  'computer',
#  'science',
#  'concept',
#  'proficient',
#  'frontend',
#  'technology',
#  'html',
#  'javascript',
#  'cs',
#  'webpack',
#  'proficient',
#  'sql',
#  'database',
#  'relational',
#  'data',
#  'concept',
#  'proficient',
#  'git',
#  'version',
#  'control',
#  'system',
#  'knowledge',
#  'frontend',
#  'tooling',
#  'e',
#  'g',
#  'foundation',
#  'tailwind',
#  'cs',
#  'bootstrap',
#  'knowledge',
#  'build',
#  'process',
#  'dependency',
#  'management',
#  'e',
#  'g',
#  'npm',
#  'webpack',
#  'composer',
#  'basic',
#  'web',
#  'server',
#  'usage',
#  'configuration',
#  'content',
#  'management',
#  'system',
#  'usage',
#  'templating',
#  'cloud',
#  'provider',
#  'aws',
#  'digital',
#  'ocean',
#  'familiarity',
#  'reactive',
#  'web',
#  'tooling',
#  'e',
#  'g',
#  'vue',
#  'react',
#  'svelte',
#  'familiarity',
#  'advanced',
#  'javascript',
#  'concept',
#  'babel',
#  'typescript',
#  'e',
#  'webpack',
#  'php',
#  'framework',
#  'library',
#  'laravel',
#  'codeigniter',
#  'yii',
#  'server',
#  'infrastructure',
#  'apache',
#  'nginx',
#  'aws',
#  'ec',
#  'docker',
#  'basic',
#  'understanding',
#  'algorithm',
#  'efficiency',
#  'technical',
#  'debt',
#  'contribution',
#  'open',
#  'source',
#  'project',
#  'github',
#  'html',
#  'cs',
#  'javascript',
#  'required',
#  'wordpress',
#  'required',
#  'php',
#  'required',
#  'seo',
#  'required',
#  'language',
#  'english',
#  'required']

# %%
len(lista_vocab_jobs)
# Out:
# 20593

# %%
import gensim
from gensim.models.phrases import Phraser, Phrases
import string
import re

#Lo que hacemos acá es unir palabras bigramas como: machine_learning, big_Data deep_learning (Que antes estaban separadas 
#pero que enrealidad van juntas; asi, objeto Phraser detecta esto y te lo devuelve como 1 sola palabra).
#Los bigramas son construidos usando phrases (frases).
    
#Los bigrams los creamos asi:
# Creamos frases relevantes desde nuestra lista de oraciones: 
phrases_jobs = Phrases(lista_vocab_jobs)
# Usamos el objeto Phraser ahora para transformar las oraciones:
bigram_jobs = Phraser(phrases_jobs)
# Aplicamos el Phraser para transformar nuestras oraciones a algo más simple (una lista):
all_sentences_jobs = list(bigram_jobs[lista_vocab_jobs])

#Imprimimos todo nuestro vocabulario:
all_sentences_jobs  #Lista de listas con nuestro vocabulario actualizado con bigramas.
all_sentences_jobs[4] #la ultima
#for t in all_sentences:
    #lista_nueva.append(t)
# Out:
# ['leveraging_latest',
#  'machine',
#  'deep_learning',
#  'technique',
#  'challenge',
#  'current',
#  'practice',
#  'across',
#  'business',
#  'unit',
#  'enhancing',
#  'internal',
#  'collaboration',
#  'business',
#  'unit',
#  'alignment',
#  'people',
#  'process',
#  'technology',
#  'business',
#  'goal',
#  'proposing',
#  'best_practice',
#  'optimize',
#  'business',
#  'unit',
#  'cloud',
#  'presence',
#  'performance',
#  'security',
#  'cost',
#  'develop',
#  'new',
#  'spec',
#  'documentation',
#  'partake',
#  'development',
#  'technical',
#  'procedure',
#  'user',
#  'support',
#  'guide',
#  'carry',
#  'debugging_troubleshooting',
#  'modification',
#  'unit_testing',
#  'custom',
#  'solution',
#  'built',
#  'organization',
#  'platform',
#  'managing',
#  'code',
#  'artifact',
#  'including',
#  'model',
#  'algorithm',
#  'template',
#  'tool',
#  'policy',
#  'guideline',
#  'measuring',
#  'performance',
#  'comparing',
#  'result',
#  'similar',
#  'effort',
#  'across',
#  'organization',
#  'industry',
#  'working',
#  'different',
#  'business',
#  'organization',
#  'across',
#  'company',
#  'understand',
#  'need',
#  'help',
#  'identify',
#  'new',
#  'opportunity',
#  'mentoring_coaching',
#  'training',
#  'managing',
#  'fellow',
#  'data',
#  'master_degree',
#  'computer_science',
#  'software',
#  'engineering',
#  'applied_mathematics',
#  'statistic',
#  'business',
#  'analytics',
#  'agribusiness',
#  'accounting_finance',
#  'economics',
#  'equivalent',
#  'proficient',
#  'machine_learning',
#  'particularly',
#  'deep_learning',
#  'knowledge',
#  'cloud',
#  'environment',
#  'aws_gcp',
#  'bi',
#  'tool',
#  'computer',
#  'vision',
#  'based',
#  'project',
#  'highly_proficient',
#  'python',
#  'sql',
#  'solid',
#  'technical',
#  'hand',
#  'machine_learning',
#  'regression',
#  'classification',
#  'clustering',
#  'dimensionality',
#  'reduction',
#  'deep_learning',
#  'cnn',
#  'rnn',
#  'lstm',
#  'gan',
#  'time',
#  'series',
#  'data',
#  'anomaly_detection',
#  'statistical',
#  'algorithm',
#  'data_mining',
#  'data',
#  'engineering',
#  'knowledge',
#  'kera',
#  'tensorflow',
#  'pytorch',
#  'cloud_computing',
#  'infrastructure',
#  'aws_azure',
#  'gcp',
#  'strong',
#  'use',
#  'logic',
#  'excellent',
#  'problem_solving',
#  'independently',
#  'flexible',
#  'thrive_fast',
#  'paced',
#  'highly',
#  'dynamic_environment',
#  'demonstrated',
#  'agile',
#  'rapid',
#  'development',
#  'method',
#  'passion',
#  'innovation',
#  'attitude',
#  'agricultural',
#  'industry',
#  'project',
#  'edge',
#  'plus']

# %%
len(all_sentences_jobs)
# Out:
# 20593

# %%
#Actualizamos columna 'tokens_Job_Description' de nuestro DF con los bigramas:
df_Jobs['tokens_Job_Description'] = all_sentences_jobs

# %%
df_Jobs
# Out:
#                                                Job_Title  \
# 0                                         Data Scientist
# 1                                       Data Scientist 2
# 2                                         HCM Consultant
# 3                                       HCM Consultant 2
# 4                              Machine Learning Engineer
# ...                                                  ...
# 20588                                       Web Designer
# 20589  Senior Front End Web Developer - Full Time at ...
# 20590                                         QA Analyst
# 20591                               Tech Lead-Full Stack
# 20592                                   C/C++ Programmer
#
#                                          Job_Description  \
# 0      Master’s degree or above in a STEM field, incl...
# 1      \nReporting to the Director, Data & Analytics,...
# 2      \nThe Oracle Cloud HCM Absence Consultant will...
# 3      4+ years of experience in PeopleSoft or Oracle...
# 4      Leveraging the latest machine and deep learnin...
# ...                                                  ...
# 20588   Company Description We are searching for a ta...
# 20589   CONTACT - priya@omegasolutioninc.com / 408-45...
# 20590  Do you take pride in your work knowing that th...
# 20591  Company Description What We Can Offer YouAs th...
# 20592  Experience in C/C++ ProgrammingDevelopment exp...
#
#                                    clean_Job_Description  \
# 0      master degree stem field including limited com...
# 1      reporting director data analytics senior data ...
# 2      oracle cloud hcm absence consultant responsibl...
# 3      peoplesoft oracle eb implementation support hc...
# 4      leveraging latest machine deep learning techni...
# ...                                                  ...
# 20588  company description searching talented creativ...
# 20589  location san francisco caterm full time perman...
# 20590  take pride knowing thousand life positively im...
# 20591  company description offer youas world leading ...
# 20592  c c programmingdevelopment win programming win...
#
#                                   tokens_Job_Description
# 0      [master_degree, stem, field, including_limited...
# 1      [reporting, director, data, analytics, senior,...
# 2      [oracle, cloud, hcm, absence, consultant, resp...
# 3      [peoplesoft, oracle_eb, implementation, suppor...
# 4      [leveraging_latest, machine, deep_learning, te...
# ...                                                  ...
# 20588  [company, description, searching, talented, cr...
# 20589  [location_san, francisco, caterm, full_time, p...
# 20590  [take_pride, knowing, thousand, life, positive...
# 20591  [company, description, offer, youas, world_lea...
# 20592  [c_c, programmingdevelopment, win, programming...
#
# [20593 rows x 4 columns]

# %% [markdown]
# ### 1.4-Armado y Limpieza de Dataset CVs.

# %% [markdown]
# ## 1-CVs_PDF_1

# %% [markdown]
# #### PDF a texto usando pdfplumber.

# %%
import pdfplumber
import os
import collections
from os import listdir
from os.path import isfile, join

#Leemos los CVs almacenados en nuestra carpeta y los extraemos uno por uno convirtiendolos a texto
#mediante la libreria pdfplumber:
pathCVs='../Datasets_CVs_And_Job_Descriptions/EN/CVs/1-CVs_PDF_1'
onlyfiles = [os.path.join(pathCVs, f) for f in os.listdir(pathCVs) if os.path.isfile(os.path.join(pathCVs, f))]
print("Cantidad de CVs extraidos:", len(onlyfiles))

#Funcion para extraer las palabras del CV:

def pdfextract(PDF_file):
    single_page_text = ""
    all_text = ""
    pdf = pdfplumber.open(PDF_file)
    for pdf_page in pdf.pages:
        single_page_text = pdf_page.extract_text()
        all_text = all_text + '\n' + single_page_text
    pdf.close()
    #return(all_text)        
    return(all_text.encode('utf-8'))

def extract_text(file):
    text = pdfextract(file).decode('utf-8')
    #text = pdfextract(file)
    return text
# Out:
# Cantidad de CVs extraidos: 10

# %%
#Obtenemos todas las palabras del CV SIN preprocesamiento:
df_Candidates=pd.DataFrame(columns = ['Candidate_Name','Content_CV'])
i=0
while i < len(onlyfiles):
    file=onlyfiles[i]
    base = os.path.basename(file)         #Data_Scientist_Karla_Lewis.pdf
    filename = os.path.splitext(base)[0]  #Data_Scientist_Karla_Lewis
    dat=extract_text(file)
    data = [{'Candidate_Name':filename, 'Content_CV':dat}]
    df_Candidates=df_Candidates.append(data, ignore_index=True)
    i+=1

df_Candidates = df_Candidates.sort_values('Candidate_Name', ascending=True)
df_Candidates = df_Candidates.reset_index(drop=True)
df_Candidates
# Out:
#                    Candidate_Name  \
# 0       DataScientist_Karla_Lewis
# 1       DataScientist_Rahul_Malik
# 2            HCM_Federico_Calonge
# 3                HCM_Robert_Smith
# 4      MLEngineer_Bradly_Johnston
# 5       MLEngineer_Jonathon_Price
# 6  SecuritySpecialist_Ahmed Wayne
# 7  SecuritySpecialist_Denis Banik
# 8            WebDev_Alec_Dionisio
# 9            WebDev_Karen_Higgins
#
#                                           Content_CV
# 0  \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 1  \nRAHUL MALIK\nNLP Data Scientist\nCONTACT WOR...
# 2  \n                                            ...
# 3  \nSap Hcm Consultant Phone: (123) 456 78 99\nE...
# 4  \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
# 5  \nJonathon Price \n4587 Terry Groves, Boston\n...
# 6  \nAhmed Wayne\nAddress: Abu Dhabi, UAE\nNation...
# 7  \nDenis Banik\nEmail address: hello@kickresume...
# 8  \nChestertown, MD 4107083942\nhi@alecdionis.io...
# 9  \nKaren Higgins \n        We b Developer \n \n...

# %% [markdown]
# ## 2-CVs_PDF_2

# %%
#Leemos los CVs almacenados en nuestra carpeta y los extraemos uno por uno convirtiendolos a texto
#mediante la libreria pdfplumber:
pathCVs_2='../Datasets_CVs_And_Job_Descriptions/EN/CVs/2-CVs_PDF_2'
onlyfiles = [os.path.join(pathCVs_2, f) for f in os.listdir(pathCVs_2) if os.path.isfile(os.path.join(pathCVs_2, f))]
print("Cantidad de CVs extraidos:", len(onlyfiles))
# Out:
# Cantidad de CVs extraidos: 228

# %%
#Obtenemos todas las palabras del CV SIN preprocesamiento:
df_Candidates_2=pd.DataFrame(columns = ['Candidate_Name','Content_CV'])
i=0
while i < len(onlyfiles):
    file=onlyfiles[i]
    base = os.path.basename(file)
    filename = os.path.splitext(base)[0]
    dat=extract_text(file)
    data = [{'Candidate_Name':filename, 'Content_CV':dat}]
    df_Candidates_2=df_Candidates_2.append(data, ignore_index=True)
    i+=1

df_Candidates_2 = df_Candidates_2.sort_values('Candidate_Name', ascending=True)
df_Candidates_2 = df_Candidates_2.reset_index(drop=True)
df_Candidates_2
# Out:
#                    Candidate_Name  \
# 0    Abiral_Pandey_Fullstack_Java
# 1                Achyuth Resume_8
# 2             Adelina_Erimia_PMP1
# 3               Adhi Gopalam - SM
# 4                       AjayKumar
# ..                            ...
# 223                  sanjay kumar
# 224                    srinivas b
# 225                    vema reddy
# 226                        venu b
# 227                    vikas java
#
#                                             Content_CV
# 0    \nName: Abiral Pandey \nEmail: abiral.pandey88...
# 1    \nAchyuth \n540-999-8048 \nachyuth.java88@gmai...
# 2    \nAdelina Erimia, PMP, Six Sigma Green Belt, S...
# 3    \n \n \nAdhi Gopalam \nadhigopalam@gmail.com \...
# 4    \nAjay Kumar (CSM)               Email/Skype: ...
# ..                                                 ...
# 223  \nSanjay \nEmail: sanjay.j0828@gmail.com \nCon...
# 224  \n \nSrinivas \nSrinivasjava04@gmail.com \n315...
# 225  \n                                            ...
# 226  \nVENU    \nvenu6773@gmail.com \n(414) 436-567...
# 227  \n \nVikas \nSr. Java/J2EE Developer \nEmail: ...
#
# [228 rows x 2 columns]

# %% [markdown]
# ## 3-CVs_CSV_1

# %%
pathCV_CSV='../Datasets_CVs_And_Job_Descriptions/EN/CVs/3-CVs_CSV_1'
df_csvs_2 = pd.read_csv(pathCV_CSV+'/Resume_DataSet.csv', usecols= ['Resume_str','Category'])
df_csvs_2
# Out:
#                                              Resume_str  Category
# 0              HR ADMINISTRATOR/MARKETING ASSOCIATE\...        HR
# 1              HR SPECIALIST, US HR OPERATIONS      ...        HR
# 2              HR DIRECTOR       Summary      Over 2...        HR
# 3              HR SPECIALIST       Summary    Dedica...        HR
# 4              HR MANAGER         Skill Highlights  ...        HR
# ...                                                 ...       ...
# 2479           RANK: SGT/E-5 NON- COMMISSIONED OFFIC...  AVIATION
# 2480           GOVERNMENT RELATIONS, COMMUNICATIONS ...  AVIATION
# 2481           GEEK SQUAD AGENT         Professional...  AVIATION
# 2482           PROGRAM DIRECTOR / OFFICE MANAGER    ...  AVIATION
# 2483           STOREKEEPER II       Professional Sum...  AVIATION
#
# [2484 rows x 2 columns]

# %%
#Vemos los diferentes tipos de categorias que tiene para extraer solo las del rubro de IT:
for val in df_csvs_2['Category'].unique():
    print(val)
# Out:
# HR
# DESIGNER
# INFORMATION-TECHNOLOGY
# TEACHER
# ADVOCATE
# BUSINESS-DEVELOPMENT
# HEALTHCARE
# FITNESS
# AGRICULTURE
# BPO
# SALES
# CONSULTANT
# DIGITAL-MEDIA
# AUTOMOBILE
# CHEF
# FINANCE
# APPAREL
# ENGINEERING
# ACCOUNTANT
# CONSTRUCTION
# PUBLIC-RELATIONS
# BANKING
# ARTS
# AVIATION

# %%
#Armamos 2 listas para incluir en nuestro DF final, en la primera vamos a incluir a todos. 
#Y en la 2da únicamente filtraremos a los consultores que son del rubro de it.

IT_Jobs_list = ['INFORMATION-TECHNOLOGY','BUSINESS-DEVELOPMENT']
Consultant = ['CONSULTANT']

filtered_df_csvs_2 = df_csvs_2[df_csvs_2['Category'].isin(IT_Jobs_list)]
filtered_df_csvs_2 = filtered_df_csvs_2.reset_index(drop=True)
filtered_df_csvs_2

#filtered_df_csvs_2['Resume_str'].iloc[90]   #Si queremos ver a un Resume_str de uno en particular.
# Out:
#                                             Resume_str                Category
# 0             INFORMATION TECHNOLOGY         Summar...  INFORMATION-TECHNOLOGY
# 1             INFORMATION TECHNOLOGY SPECIALIST\tGS...  INFORMATION-TECHNOLOGY
# 2             INFORMATION TECHNOLOGY SUPERVISOR    ...  INFORMATION-TECHNOLOGY
# 3             INFORMATION TECHNOLOGY INSTRUCTOR    ...  INFORMATION-TECHNOLOGY
# 4             INFORMATION TECHNOLOGY MANAGER/ANALYS...  INFORMATION-TECHNOLOGY
# ..                                                 ...                     ...
# 235           BUSINESS DEVELOPMENT INTERN       Sum...    BUSINESS-DEVELOPMENT
# 236           DIRECTOR, BUSINESS DEVELOPMENT       ...    BUSINESS-DEVELOPMENT
# 237           BUSINESS DEVELOPMENT MANAGER       Su...    BUSINESS-DEVELOPMENT
# 238           BUSINESS DEVELOPMENT REPRESENTATIVE  ...    BUSINESS-DEVELOPMENT
# 239           BUSINESS DEVELOPMENT MANAGER       Pr...    BUSINESS-DEVELOPMENT
#
# [240 rows x 2 columns]

# %%
df_consultants = df_csvs_2[df_csvs_2['Category'].isin(Consultant)]
df_consultants = df_consultants.reset_index(drop=True)
df_consultants
# Out:
#                                             Resume_str    Category
# 0             CONSULTANT       Summary      Human R...  CONSULTANT
# 1             IT CONSULTANT           Summary      ...  CONSULTANT
# 2               CONSULTANT         Professional Sum...  CONSULTANT
# 3             CONSULTANT       Professional Summary...  CONSULTANT
# 4             CONSULTANT         Summary     \nPC T...  CONSULTANT
# ..                                                 ...         ...
# 110           BUSINESS CONSULTANT       Professiona...  CONSULTANT
# 111           CONSULTANT ACCOUNT       Summary    T...  CONSULTANT
# 112           PRINCIPAL CONSULTANT       Summary   ...  CONSULTANT
# 113           LEASING CONSULTANT       Summary    T...  CONSULTANT
# 114           MARKETING CONSULTANT           Summar...  CONSULTANT
#
# [115 rows x 2 columns]

# %%
#Filtro los Consultores que tengan "it" en su descripción (antes lo pasé a minúscula para que no haya problema
#de macheo). De esta manera filtraremos los Consultores que no esten relacionados al rubro de it. 
df_consultants_it = df_consultants[df_consultants['Resume_str'].str.lower().str.contains(fr'\bit\b', regex=True)]
df_consultants_it = df_consultants_it.reset_index(drop=True)
df_consultants_it.shape  #Vemos que dejó solo 50 filas.
# Out:
# (50, 2)

# %%
#Por último acoplamos "df_consultants_it" a "filtered_df_csvs_2":
filtered_df_csvs_2 = filtered_df_csvs_2.append(df_consultants_it, ignore_index=True)
filtered_df_csvs_2
#df_consultants_it = df_consultants_it.reset_index(drop=True)
# Out:
#                                             Resume_str                Category
# 0             INFORMATION TECHNOLOGY         Summar...  INFORMATION-TECHNOLOGY
# 1             INFORMATION TECHNOLOGY SPECIALIST\tGS...  INFORMATION-TECHNOLOGY
# 2             INFORMATION TECHNOLOGY SUPERVISOR    ...  INFORMATION-TECHNOLOGY
# 3             INFORMATION TECHNOLOGY INSTRUCTOR    ...  INFORMATION-TECHNOLOGY
# 4             INFORMATION TECHNOLOGY MANAGER/ANALYS...  INFORMATION-TECHNOLOGY
# ..                                                 ...                     ...
# 285           CONSULTANT TO OWNER           Educati...              CONSULTANT
# 286         Pavithra  Shetty           Summary     ...              CONSULTANT
# 287           BUSINESS CONSULTANT       Professiona...              CONSULTANT
# 288           PRINCIPAL CONSULTANT       Summary   ...              CONSULTANT
# 289           MARKETING CONSULTANT           Summar...              CONSULTANT
#
# [290 rows x 2 columns]

# %% [markdown]
# #### Eliminamos duplicados (observamos que no los hay igualmente):

# %%
non_duplicate_csvs_2 = filtered_df_csvs_2.drop_duplicates(subset=None, keep='first', inplace=False)

# %%
non_duplicate_csvs_2
# Out:
#                                             Resume_str                Category
# 0             INFORMATION TECHNOLOGY         Summar...  INFORMATION-TECHNOLOGY
# 1             INFORMATION TECHNOLOGY SPECIALIST\tGS...  INFORMATION-TECHNOLOGY
# 2             INFORMATION TECHNOLOGY SUPERVISOR    ...  INFORMATION-TECHNOLOGY
# 3             INFORMATION TECHNOLOGY INSTRUCTOR    ...  INFORMATION-TECHNOLOGY
# 4             INFORMATION TECHNOLOGY MANAGER/ANALYS...  INFORMATION-TECHNOLOGY
# ..                                                 ...                     ...
# 285           CONSULTANT TO OWNER           Educati...              CONSULTANT
# 286         Pavithra  Shetty           Summary     ...              CONSULTANT
# 287           BUSINESS CONSULTANT       Professiona...              CONSULTANT
# 288           PRINCIPAL CONSULTANT       Summary   ...              CONSULTANT
# 289           MARKETING CONSULTANT           Summar...              CONSULTANT
#
# [290 rows x 2 columns]

# %% [markdown]
# ## 4-CVs_CSV_2

# %%
pathCV_CSV='../Datasets_CVs_And_Job_Descriptions/EN/CVs/4-CVs_CSV_2'
df_csvs = pd.read_csv(pathCV_CSV+'/UpdatedResumeDataSet.csv', usecols= ['Category','Resume'])
df_csvs
# Out:
#          Category                                             Resume
# 0    Data Science  Skills * Programming Languages: Python (pandas...
# 1    Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2    Data Science  Areas of Interest Deep Learning, Control Syste...
# 3    Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4    Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
# ..            ...                                                ...
# 957       Testing  Computer Skills: â¢ Proficient in MS office (...
# 958       Testing  â Willingness to accept the challenges. â ...
# 959       Testing  PERSONAL SKILLS â¢ Quick learner, â¢ Eagerne...
# 960       Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 961       Testing  Skill Set OS Windows XP/7/8/8.1/10 Database MY...
#
# [962 rows x 2 columns]

# %%
#Vemos los diferentes tipos de categorias que tiene para extraer solo las del rubro de IT:
for val in df_csvs['Category'].unique():
    print(val)
# Out:
# Data Science
# HR
# Advocate
# Arts
# Web Designing
# Mechanical Engineer
# Sales
# Health and fitness
# Civil Engineer
# Java Developer
# Business Analyst
# SAP Developer
# Automation Testing
# Electrical Engineering
# Operations Manager
# Python Developer
# DevOps Engineer
# Network Security Engineer
# PMO
# Database
# Hadoop
# ETL Developer
# DotNet Developer
# Blockchain
# Testing

# %%
IT_Jobs_list = ['Data Science','Web Designing','Java Developer', 'Business Analyst', 'SAP Developer', 'Automation Testing', 'Python Developer', 'DevOps Engineer', 'Network Security Engineer', 'PMO', 'Database', 'Hadoop', 'ETL Developer', 'DotNet Developer', 'Blockchain Testing']

filtered_df_csvs = df_csvs[df_csvs['Category'].isin(IT_Jobs_list)]
filtered_df_csvs = filtered_df_csvs.reset_index(drop=True)
filtered_df_csvs
# Out:
#              Category                                             Resume
# 0        Data Science  Skills * Programming Languages: Python (pandas...
# 1        Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2        Data Science  Areas of Interest Deep Learning, Control Syste...
# 3        Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4        Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
# ..                ...                                                ...
# 543  DotNet Developer  Technical Skills â¢ Languages: C#, ASP .NET M...
# 544  DotNet Developer  Education Details \r\nJanuary 2014  Education ...
# 545  DotNet Developer  Technologies ASP.NET, MVC 3.0/4.0/5.0, Unit Te...
# 546  DotNet Developer  Technical Skills CATEGORY SKILLS Language C, C...
# 547  DotNet Developer  TECHNICAL SKILLS â Programming Languages: C#...
#
# [548 rows x 2 columns]

# %% [markdown]
# #### Eliminamos duplicados, observamos que solo nos quedan 97 filas.

# %%
non_duplicate_csvs = filtered_df_csvs.drop_duplicates(subset=None, keep='first', inplace=False)
non_duplicate_csvs = non_duplicate_csvs.reset_index(drop=True)

# %%
non_duplicate_csvs
# Out:
#             Category                                             Resume
# 0       Data Science  Skills * Programming Languages: Python (pandas...
# 1       Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2       Data Science  Areas of Interest Deep Learning, Control Syste...
# 3       Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4       Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
# ..               ...                                                ...
# 92  DotNet Developer  Technical Skills â¢ Languages: C#, ASP .NET M...
# 93  DotNet Developer  Education Details \r\nJanuary 2014  Education ...
# 94  DotNet Developer  Technologies ASP.NET, MVC 3.0/4.0/5.0, Unit Te...
# 95  DotNet Developer  Technical Skills CATEGORY SKILLS Language C, C...
# 96  DotNet Developer  TECHNICAL SKILLS â Programming Languages: C#...
#
# [97 rows x 2 columns]

# %% [markdown]
# # Unimos los 4 datasets (2 pdfs y 2 csvs) obteniendo nuestro 'df_candidatos_final'

# %%
#Renonmbramos las columnas de los DFs de csvs ('non_duplicate_csvs_2' y 'non_duplicate_csvs') 
#para que queden iguales a los DFs de pdfs (df_Candidates, df_Candidates_2):
non_duplicate_csvs.rename(columns={'Category': 'Candidate_Name', 'Resume': 'Content_CV'}, inplace=True)
non_duplicate_csvs_2.rename(columns={'Category': 'Candidate_Name', 'Resume_str': 'Content_CV'}, inplace=True)

#Ahora unimos non_duplicate_csvs y non_duplicate_csvs_2 (los CSVs):
df_csvs = non_duplicate_csvs.append(non_duplicate_csvs_2, ignore_index=True)

#Luego modificamos la columna 'Category' de los DFs de csvs para que tenga el índice + Category:
df_csvs['Candidate_Name'] = df_csvs.index.astype(str)  + "-" + df_csvs['Candidate_Name'].astype(str)   

#Unimos df_Candidates y df_Candidates_2 (los PDFs):
df_pdfs = df_Candidates.append(df_Candidates_2, ignore_index=True)

#Y ahora por último unimos los DFs 'non_duplicate_csvs_2' y 'non_duplicate_csvs' a 'df_Candidates_2' y 'df_Candidates':
df_candidatos_final = df_pdfs.append(df_csvs, ignore_index=True)

# %%
df_candidatos_final
# Out:
#                  Candidate_Name  \
# 0     DataScientist_Karla_Lewis
# 1     DataScientist_Rahul_Malik
# 2          HCM_Federico_Calonge
# 3              HCM_Robert_Smith
# 4    MLEngineer_Bradly_Johnston
# ..                          ...
# 620              382-CONSULTANT
# 621              383-CONSULTANT
# 622              384-CONSULTANT
# 623              385-CONSULTANT
# 624              386-CONSULTANT
#
#                                             Content_CV
# 0    \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 1    \nRAHUL MALIK\nNLP Data Scientist\nCONTACT WOR...
# 2    \n                                            ...
# 3    \nSap Hcm Consultant Phone: (123) 456 78 99\nE...
# 4    \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
# ..                                                 ...
# 620           CONSULTANT TO OWNER           Educati...
# 621         Pavithra  Shetty           Summary     ...
# 622           BUSINESS CONSULTANT       Professiona...
# 623           PRINCIPAL CONSULTANT       Summary   ...
# 624           MARKETING CONSULTANT           Summar...
#
# [625 rows x 2 columns]

# %% [markdown]
# #### Tenemos un total de 625 filas/CVs.

# %%
df_candidatos_final['Content_CV'].iloc[624]
# Out:
# "         MARKETING CONSULTANT           Summary     Value Creator, Marketing Executive: \xa0Versatile strategic leader with over 15 years in corporate marketing, business development, and account management for Fortune 1000, niche, and start-up companies. Success in healthcare, technology, automotive, retail, and consumer-packaged goods. Proven ability to grow revenues and brand loyalty in B2C and B2B markets with innovative campaigns and targeted marketing programs.\xa0 Contributor to team leader with experience over million-dollar budgets. Entrepreneur mindset creative and analytical skills for measurable impact. BBA in Marketing and MBA in Management.      Skills          Strategic Planning  Forecasting, Budgets, & P & L  Brand & Product Management  Channel Strategies  Lead Generation  Account Management  Complex Selling  Software & Technology  Manufacturing   Sourcing  Sales Enablement      Business Competitive Analysis  Market Research  New Product Development  Packaging  Creative/Design  Content & Communications  Social Media & Digital   Events   Project Management, Vendor Management  CRM & Automation Apps  Call Center & Telemarketing            Experience      Marketing Consultant    May 2011   to   Current     Company Name   －   City  ,   State      Marketing services and consulting working with diverse companies in healthcare and technology.  Client roles \nvary as Consultant, Contractor, and Employee in marketing leadership and managing all areas of the marketing function and \nresources.  Experience focuses in corporate, startups and individuals seeking to thrive including:.          Marketing Director/Consultant    April 2015   to   December 2016     Company Name   －   City  ,   State      Increased profits by 60% in one year through restructure of business line.  A B2B technology & healthcare solutions provider and VAR for GE Imaging reporting to matrix executive leadership Oversaw marketing for three divisions to support revenue pipeline across diverse vertical markets.   Key\nfocus in targeting independent hospitals, clinics, physicians with bundled implementation, software, and managed IT.  Develop marketing function and oversee telemarketing team campaigns.  Lead facilitator of GE Imaging IT marketing plan including demand generation, brand development, and marketing communication initiatives; utilizing Salesforce, Autotask, WordPress, and Project management practices.  Developed content for digital and traditional including presentations, customer stories, video, blog, emails, and website.  Managed multiple events across vertical markets in business and healthcare supporting reseller channel strategies and new brand and product packaging, establishing launch programs, brand standards, calendar, and action plans.          Sr. Director, Marketing    June 2014   to   December 2015     Company Name   －   City  ,   State     A B2B healthcare informatics solutions for Employers and Payers; reporting to President/Cofounder (company sold) Developed brand and UX experience for two new technology platforms: functionality, design, and positioning: $6M target.   Oversee communications, brand standards, and proposals for consulting services, and diagnostic reports coordinating team.  Created weekly blog strategy: establish calendar, targets, and authors to drive leads, SEO, and content.  Manage public relations including media, press releases, and distribution to target industry contacts.  Initiated email campaigns, webinars, and social media entry to build brand via targeted campaigns for lead generation and other content including whitepapers.  Initiated CRM evaluation and selection to build-out system for contacts, leads tracking, and email integration.  Developed rebranding plan to establish primary and secondary brands for current and new products including competitive analysis, positioning, market research, testing, naming, product roadmap, segmentation, and identity creation.  Developed 2015 marketing plan, calend ...

# %% [markdown]
# ## Exportamos el DF como CSV

# %%
#Exportamos el csv:
df_candidatos_final.to_csv('DF_Exportado_625_CVs.csv',index = False)

# %%
#Si lo queremos importar:
df_candidatos_f = pd.read_csv('DF_Exportado_625_CVs.csv')
df_candidatos_f.shape
# Out:
# (625, 2)

# %% [markdown]
# #### Limpieza de datos del DF de Candidatos.

# %%
cleaning_DF(df_candidatos_f,'Content_CV',True)
tokenize_and_lemmatize(df_candidatos_f,'Content_CV')

# %%
df_candidatos_f
# Out:
#                  Candidate_Name  \
# 0     DataScientist_Karla_Lewis
# 1     DataScientist_Rahul_Malik
# 2          HCM_Federico_Calonge
# 3              HCM_Robert_Smith
# 4    MLEngineer_Bradly_Johnston
# ..                          ...
# 620              382-CONSULTANT
# 621              383-CONSULTANT
# 622              384-CONSULTANT
# 623              385-CONSULTANT
# 624              386-CONSULTANT
#
#                                             Content_CV  \
# 0    \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 1    \nRAHUL MALIK\nNLP Data Scientist\nCONTACT WOR...
# 2    \n                                            ...
# 3    \nSap Hcm Consultant Phone: (123) 456 78 99\nE...
# 4    \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
# ..                                                 ...
# 620           CONSULTANT TO OWNER           Educati...
# 621         Pavithra  Shetty           Summary     ...
# 622           BUSINESS CONSULTANT       Professiona...
# 623           PRINCIPAL CONSULTANT       Summary   ...
# 624           MARKETING CONSULTANT           Summar...
#
#                                       clean_Content_CV  \
# 0    data scientist brooklyn ny data scientist grub...
# 1    nlp data scientist brooklyn ny nlp data scient...
# 2    hcm technical consultant working oracle tool p...
# 3    sap hcm consultant com qwikresume marshville r...
# 4    kasey vista detroit senior software engineer m...
# ..                                                 ...
# 620  consultant owner florida international univers...
# 621  pavithra shetty customer oriented principal co...
# 622  business consultant business sale operation po...
# 623  principal consultant supply chain logistics ma...
# 624  marketing consultant value creator marketing e...
#
#                                      tokens_Content_CV
# 0    [data, scientist, brooklyn, ny, data, scientis...
# 1    [nlp, data, scientist, brooklyn, ny, nlp, data...
# 2    [hcm, technical, consultant, working, oracle, ...
# 3    [sap, hcm, consultant, com, qwikresume, marshv...
# 4    [kasey, vista, detroit, senior, software, engi...
# ..                                                 ...
# 620  [consultant, owner, florida, international, un...
# 621  [pavithra, shetty, customer, oriented, princip...
# 622  [business, consultant, business, sale, operati...
# 623  [principal, consultant, supply, chain, logisti...
# 624  [marketing, consultant, value, creator, market...
#
# [625 rows x 4 columns]

# %%
#Vemos los tokens generados para el candidato HCM_Federico_Calonge:
df_candidatos_f.iloc[2]['tokens_Content_CV']
# Out:
# ['hcm',
#  'technical',
#  'consultant',
#  'working',
#  'oracle',
#  'tool',
#  'participated',
#  'erp',
#  'cloud',
#  'project',
#  'performing',
#  'reporting',
#  'working',
#  'module',
#  'ap',
#  'ar',
#  'gl',
#  'participating',
#  'hcm',
#  'cloud',
#  'project',
#  'performing',
#  'reporting',
#  'extraction',
#  'integration',
#  'working',
#  'module',
#  'core',
#  'recruitment',
#  'member',
#  'artificial',
#  'intelligence',
#  'ai',
#  'committee',
#  'oracle',
#  'strong',
#  'interest',
#  'data',
#  'science',
#  'machine',
#  'learning',
#  'last',
#  'computer',
#  'engineering',
#  'degree',
#  'studying',
#  'th',
#  'english',
#  'personal',
#  'academic',
#  'programming',
#  'project',
#  'oracle',
#  'hcm',
#  'cloud',
#  'core',
#  'recruitment',
#  'oracle',
#  'erp',
#  'cloud',
#  'account',
#  'receivable',
#  'ar',
#  'account',
#  'payable',
#  'ap',
#  'general',
#  'ledger',
#  'gl',
#  'main',
#  'reporting',
#  'sql',
#  'bi',
#  'publisher',
#  'intermediate',
#  'advanced',
#  'point',
#  'technical',
#  'documentation',
#  'extraction',
#  'api',
#  'rest',
#  'hcm',
#  'extract',
#  'web',
#  'service',
#  'soap',
#  'basic',
#  'intermediate',
#  'integration',
#  'hdl',
#  'basic',
#  'intermediate',
#  'extra',
#  'data',
#  'analysis',
#  'implementation',
#  'machine',
#  'learning',
#  'algorithm',
#  'python',
#  'intermediate',
#  'oracle',
#  'consultant',
#  'oracle',
#  'hcm',
#  'implementation',
#  'technical',
#  'consultant',
#  'report',
#  'core',
#  'assembling',
#  'do',
#  'pinos',
#  'cr',
#  'technical',
#  'documentation',
#  'extraction',
#  'web',
#  'service',
#  'soap',
#  'hcm',
#  'extract',
#  'absence',
#  'time',
#  'extraction',
#  'rest',
#  'api',
#  'integration',
#  'hdl',
#  'oracle',
#  'hcm',
#  'implementation',
#  'technical',
#  'consultant',
#  'report',
#  'core',
#  'personal',
#  'usta',
#  'col',
#  'data',
#  'recruitment',
#  'selection',
#  'candidate',
#  'feedback',
#  'oracle',
#  'hcm',
#  'implementation',
#  'technical',
#  'consultant',
#  'bank',
#  'reconciliation',
#  'report',
#  'consorcio',
#  'chi',
#  'oracle',
#  'hcm',
#  'implementation',
#  'technical',
#  'consultant',
#  'daily',
#  'book',
#  'purchase',
#  'book',
#  'sky',
#  'airline',
#  'chi',
#  'report',
#  'taking',
#  'account',
#  'tax',
#  'withholding',
#  'applied',
#  'national',
#  'university',
#  'avellaneda',
#  'undav',
#  'computer',
#  'engineering',
#  'orientation',
#  'distributed',
#  'system',
#  'progress',
#  'approved',
#  'subject',
#  'thesis',
#  'progress',
#  'oriented',
#  'machine',
#  'learning',
#  'applied',
#  'human',
#  'resource',
#  'spanish',
#  'native',
#  'english',
#  'intermediate',
#  'advanced',
#  'th',
#  'cambridge',
#  'institute',
#  'approved',
#  'oracle',
#  'consultant']

# %% [markdown]
# ### Obtenemos los bi-grams y los guardamos en la columna 'tokens_Content_CV'

# %%
lista_vocab = df_candidatos_f['tokens_Content_CV'].tolist()
#lista_vocab #lista de lista de tokens.
lista_vocab[624]   #la última es 624.
# Out:
# ['marketing',
#  'consultant',
#  'value',
#  'creator',
#  'marketing',
#  'executive',
#  'versatile',
#  'strategic',
#  'leader',
#  'corporate',
#  'marketing',
#  'business',
#  'development',
#  'account',
#  'management',
#  'fortune',
#  'niche',
#  'start',
#  'company',
#  'success',
#  'healthcare',
#  'technology',
#  'automotive',
#  'retail',
#  'consumer',
#  'packaged',
#  'good',
#  'proven',
#  'grow',
#  'revenue',
#  'brand',
#  'loyalty',
#  'b',
#  'c',
#  'b',
#  'b',
#  'market',
#  'innovative',
#  'campaign',
#  'targeted',
#  'marketing',
#  'program',
#  'contributor',
#  'team',
#  'leader',
#  'million',
#  'dollar',
#  'budget',
#  'entrepreneur',
#  'mindset',
#  'creative',
#  'analytical',
#  'measurable',
#  'impact',
#  'bba',
#  'marketing',
#  'mba',
#  'management',
#  'strategic',
#  'planning',
#  'forecasting',
#  'budget',
#  'p',
#  'l',
#  'brand',
#  'product',
#  'management',
#  'channel',
#  'strategy',
#  'lead',
#  'generation',
#  'account',
#  'management',
#  'complex',
#  'selling',
#  'software',
#  'technology',
#  'manufacturing',
#  'sourcing',
#  'sale',
#  'enablement',
#  'business',
#  'competitive',
#  'analysis',
#  'market',
#  'research',
#  'new',
#  'product',
#  'development',
#  'packaging',
#  'creative',
#  'design',
#  'content',
#  'communication',
#  'social',
#  'medium',
#  'digital',
#  'event',
#  'project',
#  'management',
#  'vendor',
#  'management',
#  'crm',
#  'automation',
#  'apps',
#  'call',
#  'center',
#  'telemarketing',
#  'marketing',
#  'consultant',
#  'current',
#  'company',
#  'name',
#  'marketing',
#  'service',
#  'consulting',
#  'working',
#  'diverse',
#  'company',
#  'healthcare',
#  'technology',
#  'client',
#  'role',
#  'vary',
#  'consultant',
#  'contractor',
#  'employee',
#  'marketing',
#  'leadership',
#  'managing',
#  'area',
#  'marketing',
#  'function',
#  'resource',
#  'focus',
#  'corporate',
#  'startup',
#  'individual',
#  'seeking',
#  'thrive',
#  'including',
#  'marketing',
#  'director',
#  'consultant',
#  'company',
#  'name',
#  'increased',
#  'profit',
#  'one',
#  'restructure',
#  'business',
#  'line',
#  'b',
#  'b',
#  'technology',
#  'healthcare',
#  'solution',
#  'provider',
#  'var',
#  'ge',
#  'imaging',
#  'reporting',
#  'matrix',
#  'executive',
#  'leadership',
#  'oversaw',
#  'marketing',
#  'three',
#  'division',
#  'support',
#  'revenue',
#  'pipeline',
#  'across',
#  'diverse',
#  'vertical',
#  'market',
#  'key',
#  'focus',
#  'targeting',
#  'independent',
#  'hospital',
#  'clinic',
#  'physician',
#  'bundled',
#  'implementation',
#  'software',
#  'managed',
#  'develop',
#  'marketing',
#  'function',
#  'oversee',
#  'telemarketing',
#  'team',
#  'campaign',
#  'lead',
#  'facilitator',
#  'ge',
#  'imaging',
#  'marketing',
#  'plan',
#  'including',
#  'demand',
#  'generation',
#  'brand',
#  'development',
#  'marketing',
#  'communication',
#  'initiative',
#  'utilizing',
#  'salesforce',
#  'autotask',
#  'wordpress',
#  'project',
#  'management',
#  'practice',
#  'developed',
#  'content',
#  'digital',
#  'traditional',
#  'including',
#  'presentation',
#  'customer',
#  'story',
#  'video',
#  'blog',
#  'email',
#  'managed',
#  'multiple',
#  'event',
#  'across',
#  'vertical',
#  'market',
#  'business',
#  'healthcare',
#  'supporting',
#  'reseller',
#  'channel',
#  'strategy',
#  'new',
#  'brand',
#  'product',
#  'packaging',
#  'establishing',
#  'launch',
#  'program',
#  'brand',
#  'standard',
#  'calendar',
#  'action',
#  'plan',
#  'sr',
#  'director',
#  'marketing',
#  'company',
#  'name',
#  'b',
#  'b',
#  'healthcare',
#  'informatics',
#  'solution',
#  'employer',
#  'payer',
#  'reporting',
#  'president',
#  'cofounder',
#  'company',
#  'sold',
#  'developed',
#  'brand',
#  'ux',
#  'two',
#  'new',
#  'technology',
#  'platform',
#  'functionality',
#  'design',
#  'positioning',
#  'target',
#  'oversee',
#  'communication',
#  'brand',
#  'standard',
#  'proposal',
#  'consulting',
#  'service',
#  'diagnostic',
#  'report',
#  'coordinating',
#  'team',
#  'created',
#  'weekly',
#  'blog',
#  'strategy',
#  'establish',
#  'calendar',
#  'target',
#  'author',
#  'drive',
#  'lead',
#  'seo',
#  'content',
#  'manage',
#  'public',
#  'relation',
#  'including',
#  'medium',
#  'press',
#  'release',
#  'distribution',
#  'target',
#  'industry',
#  'contact',
#  'initiated',
#  'campaign',
#  'webinars',
#  'social',
#  'medium',
#  'entry',
#  'build',
#  'brand',
#  'via',
#  'targeted',
#  'campaign',
#  'lead',
#  'generation',
#  'content',
#  'including',
#  'whitepapers',
#  'initiated',
#  'crm',
#  'evaluation',
#  'selection',
#  'build',
#  'system',
#  'contact',
#  'lead',
#  'tracking',
#  'integration',
#  'developed',
#  'rebranding',
#  'plan',
#  'establish',
#  'primary',
#  'secondary',
#  'brand',
#  'current',
#  'new',
#  'product',
#  'including',
#  'competitive',
#  'analysis',
#  'positioning',
#  'market',
#  'research',
#  'testing',
#  'naming',
#  'product',
#  'roadmap',
#  'segmentation',
#  'identity',
#  'creation',
#  'developed',
#  'marketing',
#  'plan',
#  'calendar',
#  'budget',
#  'generate',
#  'organic',
#  'growth',
#  'across',
#  'largest',
#  'plan',
#  'sponsor',
#  'manage',
#  'branded',
#  'event',
#  'including',
#  'sponsorship',
#  'exhibit',
#  'working',
#  'national',
#  'regional',
#  'industry',
#  'group',
#  'ahip',
#  'amcp',
#  'world',
#  'salgba',
#  'national',
#  'industry',
#  'organization',
#  'reaching',
#  'health',
#  'plan',
#  'sponsor',
#  'developed',
#  'new',
#  'brand',
#  'strategy',
#  'w',
#  'engagement',
#  'tool',
#  'content',
#  'rebranding',
#  'launching',
#  'week',
#  'marketing',
#  'director',
#  'consultant',
#  'company',
#  'name',
#  'national',
#  'leader',
#  'hospital',
#  'revenue',
#  'cycle',
#  'solution',
#  'reported',
#  'president',
#  'company',
#  'wide',
#  'cost',
#  'reduction',
#  'launched',
#  'new',
#  'brand',
#  'solution',
#  'identify',
#  'creation',
#  'brand',
#  'standard',
#  'outbound',
#  'message',
#  'event',
#  'website',
#  'campaign',
#  'market',
#  'transition',
#  'customer',
#  'base',
#  'build',
#  'new',
#  'revenue',
#  'yr',
#  'developed',
#  'annual',
#  'marketing',
#  'plan',
#  'budget',
#  'hospital',
#  'market',
#  'pr',
#  'new',
#  'event',
#  'sponsorship',
#  'working',
#  'hfma',
#  'aaham',
#  'naham',
#  'local',
#  'regional',
#  'national',
#  'level',
#  'managed',
#  'vendor',
#  'reduce',
#  'spend',
#  'k',
#  'led',
#  'market',
#  'position',
#  'generate',
#  'qualified',
#  'funnel',
#  'revenue',
#  'tracking',
#  'organic',
#  'sale',
#  'referral',
#  'injected',
#  'culture',
#  'optimism',
#  'brand',
#  'revamp',
#  'peer',
#  'review',
#  'award',
#  'external',
#  'focus',
#  'communication',
#  'creative',
#  'tool',
#  'rebuilt',
#  'corporate',
#  'patient',
#  'facing',
#  'website',
#  'facebook',
#  'tracking',
#  'metric',
#  'content',
#  'seo',
#  'sem',
#  'manage',
#  'mra',
#  'voice',
#  'offset',
#  'competitor',
#  'inroad',
#  'revamped',
#  'patient',
#  'communication',
#  'present',
#  'positioning',
#  'patient',
#  'advocacy',
#  'letter',
#  'portal',
#  'call',
#  'center',
#  'po',
#  'developed',
#  'first',
#  'annual',
#  'customer',
#  'satisfaction',
#  'survey',
#  'achieving',
#  'participation',
#  'delivery',
#  'hospital',
#  'leader',
#  'director',
#  'marketing',
#  'executive',
#  'team',
#  'member',
#  'company',
#  'name',
#  'b',
#  'b',
#  'healthcare',
#  'rcm',
#  'start',
#  'physician',
#  'medical',
#  'group',
#  'company',
#  'folded',
#  'two',
#  'reported',
#  'ceo',
#  'targeted',
#  'physician',
#  'state',
#  'specialty',
#  'converting',
#  'customer',
#  'ehr',
#  'license',
#  'revenue',
#  'cycle',
#  'management',
#  'service',
#  'developed',
#  'new',
#  'software',
#  'launch',
#  'revenue',
#  'cycle',
#  'including',
#  'brand',
#  'strategy',
#  'digital',
#  'promotion',
#  'user',
#  'event',
#  'pr',
#  'yr',
#  'facilitated',
#  'trade',
#  'show',
#  'event',
#  'per',
#  'supporting',
#  'national',
#  'regional',
#  'community',
#  'initiative',
#  'rebranded',
#  'practice',
#  'management',
#  'software',
#  'service',
#  'transitioning',
#  'independent',
#  'practice',
#  'new',
#  'solution',
#  'established',
#  'new',
#  'u',
#  'lead',
#  'gen',
#  'team',
#  'u',
#  'including',
#  'crm',
#  'market',
#  'data',
#  'reporting',
#  'talent',
#  'revenue',
#  'pipeline',
#  'launched',
#  'new',
#  'design',
#  'related',
#  'communication',
#  'strategy',
#  'developed',
#  'advertising',
#  'trade',
#  'event',
#  'public',
#  'relation',
#  'built',
#  'social',
#  'medium',
#  'strategy',
#  'including',
#  'key',
#  'site',
#  'blog',
#  'ad',
#  'word',
#  'ppc',
#  'seo',
#  'content',
#  'development',
#  'build',
#  'lead',
#  'traffic',
#  'established',
#  'marketing',
#  'intelligence',
#  'function',
#  'across',
#  'physician',
#  'defined',
#  'key',
#  'target',
#  'specialty',
#  'campaign',
#  'analyzed',
#  'engagement',
#  'pipeline',
#  'market',
#  'trend',
#  'using',
#  'crm',
#  'research',
#  'satisfaction',
#  'study',
#  'managed',
#  'team',
#  'including',
#  'lead',
#  'gen',
#  'specialist',
#  'outsourced',
#  'vendor',
#  'member',
#  'executive',
#  'team',
#  'director',
#  'marketing',
#  'executive',
#  'team',
#  'member',
#  'company',
#  'name',
#  'aftermarket',
#  'auto',
#  'part',
#  'distributor',
#  'retailer',
#  'b',
#  'b',
#  'b',
#  'b',
#  'c',
#  'reported',
#  'general',
#  'manager',
#  'corporate',
#  'vp',
#  'recruited',
#  'new',
#  'startup',
#  'sale',
#  'increase',
#  'managed',
#  'trade',
#  'association',
#  'event',
#  'across',
#  'north',
#  'america',
#  'relaunched',
#  'brand',
#  'new',
#  'positioning',
#  'strategy',
#  'leveraging',
#  'market',
#  'research',
#  'equity',
#  'entirely',
#  'new',
#  'ad',
#  'campaign',
#  'e',
#  'marketing',
#  'vehicle',
#  'stabilized',
#  'sale',
#  'managed',
#  'customer',
#  'relationship',
#  'working',
#  'national',
#  'retailer',
#  'traditional',
#  'distribution',
#  'channel',
#  'service',
#  'diy',
#  'difm',
#  'market',
#  'supporting',
#  'store',
#  'location',
#  'north',
#  'america',
#  'created',
#  'unique',
#  'marketing',
#  'support',
#  'u',
#  'canada',
#  'initiated',
#  'business',
#  'review',
#  'strategic',
#  'plan',
#  'largest',
#  'retail',
#  'customer',
#  'location',
#  'market',
#  'test',
#  'licensing',
#  'evaluation',
#  'new',
#  'product',
#  'expansion',
#  'worth',
#  'sale',
#  'grew',
#  'business',
#  'versus',
#  'managed',
#  'contributed',
#  'executive',
#  'staff',
#  'member',
#  'reestablished',
#  'market',
#  'sale',
#  'focus',
#  'channel',
#  'strategy',
#  'momentum',
#  'new',
#  'sale',
#  'organization',
#  'annual',
#  'budget',
#  'spend',
#  'branded',
#  'customer',
#  'promotion',
#  'program',
#  'channel',
#  'marketing',
#  'manager',
#  'company',
#  'name',
#  'retail',
#  'business',
#  'b',
#  'fki',
#  'industry',
#  'fki',
#  'sold',
#  'melrose',
#  'liquidated',
#  'reported',
#  'vp',
#  'marketing',
#  'company',
#  'divested',
#  'strategically',
#  'managed',
#  'customer',
#  'merchandising',
#  'line',
#  'product',
#  'promotion',
#  'program',
#  'retail',
#  'national',
#  'account',
#  'created',
#  'new',
#  'brand',
#  'designer',
#  'collection',
#  'program',
#  'retailer',
#  'e',
#  'tailor',
#  'new',
#  'product',
#  'packaging',
#  'promotion',
#  'internet',
#  'advertising',
#  'merchandising',
#  'led',
#  'project',
#  'management',
#  'china',
#  'sourcing',
#  'store',
#  'rollout',
#  'created',
#  'new',
#  'hickory',
#  'hardware',
#  'brand',
#  'customer',
#  'program',
#  'including',
#  'innovative',
#  'merchandising',
#  'lifestyle',
#  'graphic',
#  'messaging',
#  'consumer',
#  'tool',
#  'packaging',
#  'upgrade',
#  'menards',
#  'home',
#  'depot',
#  'lowe',
#  'ch',
#  'briggs',
#  'established',
#  'new',
#  'corporate',
#  'new',
#  'product',
#  'development',
#  'process',
#  'tracking',
#  'reduced',
#  'npd',
#  'schedule',
#  'established',
#  'led',
#  'lowe',
#  'marketing',
#  'team',
#  'hiring',
#  'resource',
#  'setting',
#  'process',
#  'leading',
#  'monthly',
#  'service',
#  'product',
#  'marketing',
#  'program',
#  'top',
#  'customer',
#  'annually',
#  'managed',
#  'agency',
#  'vendor',
#  'upgrade',
#  'quality',
#  'marketing',
#  'strategy',
#  'branding',
#  'graphic',
#  'messaging',
#  'communication',
#  'achieved',
#  'first',
#  'consumer',
#  'ad',
#  'campaign',
#  'including',
#  'consumer',
#  'print',
#  'hgtv',
#  'sponsorship',
#  'line',
#  'market',
#  'place',
#  'conducted',
#  'market',
#  'research',
#  'project',
#  'among',
#  'pro',
#  'diy',
#  'consumer',
#  'establish',
#  'branding',
#  'message',
#  'channel',
#  'differentiation',
#  'strategy',
#  'various',
#  'product',
#  'resulting',
#  'packaging',
#  'promotion',
#  'new',
#  'web',
#  'strategy',
#  'sr',
#  'marketing',
#  'manager',
#  'consultant',
#  'company',
#  'name',
#  'start',
#  'b',
#  'b',
#  'company',
#  'speed',
#  'clinical',
#  'trial',
#  'enrollment',
#  'reporting',
#  'coo',
#  'consulting',
#  'area',
#  'small',
#  'business',
#  'created',
#  'start',
#  'marketing',
#  'led',
#  'implementation',
#  'brand',
#  'sale',
#  'channel',
#  'partner',
#  'marketing',
#  'pipeline',
#  'generated',
#  'k',
#  'closed',
#  'contract',
#  'first',
#  'six',
#  'month',
#  'pipeline',
#  'targeting',
#  'pharma',
#  'research',
#  'physician',
#  'strategic',
#  'market',
#  'manager',
#  'company',
#  'name',
#  'annual',
#  'sale',
#  'b',
#  'b',
#  'technology',
#  'service',
#  'data',
#  ...]

# %%
len(lista_vocab)
# Out:
# 625

# %%
import gensim
from gensim.models.phrases import Phraser, Phrases
import string
import re

#Lo que hacemos acá es unir palabras bigramas como: machine_learning, big_Data deep_learning (Que antes estaban separadas 
#pero que enrealidad van juntas; asi, objeto Phraser detecta esto y te lo devuelve como 1 sola palabra).
#Los bigramas son construidos usando phrases (frases).
    
#Los bigrams los creamos asi:
# Creamos frases relevantes desde nuestra lista de oraciones: 
phrases = Phrases(lista_vocab)
# Usamos el objeto Phraser ahora para transformar las oraciones:
bigram = Phraser(phrases)
# Aplicamos el Phraser para transformar nuestras oraciones a algo más simple (una lista):
all_sentences = list(bigram[lista_vocab])

#Imprimimos todo nuestro vocabulario:
all_sentences  #Lista de listas con nuestro vocabulario actualizado con bigramas. Son 625 listas en total.
all_sentences[624]   #la última es 624.
#for t in all_sentences:
    #lista_nueva.append(t)
# Out:
# ['marketing',
#  'consultant',
#  'value',
#  'creator',
#  'marketing',
#  'executive',
#  'versatile',
#  'strategic',
#  'leader',
#  'corporate',
#  'marketing',
#  'business',
#  'development',
#  'account',
#  'management',
#  'fortune',
#  'niche',
#  'start',
#  'company',
#  'success',
#  'healthcare',
#  'technology',
#  'automotive',
#  'retail',
#  'consumer',
#  'packaged',
#  'good',
#  'proven',
#  'grow',
#  'revenue',
#  'brand',
#  'loyalty',
#  'b_c',
#  'b_b',
#  'market',
#  'innovative',
#  'campaign',
#  'targeted',
#  'marketing',
#  'program',
#  'contributor',
#  'team',
#  'leader',
#  'million_dollar',
#  'budget',
#  'entrepreneur',
#  'mindset',
#  'creative',
#  'analytical',
#  'measurable',
#  'impact',
#  'bba',
#  'marketing',
#  'mba',
#  'management',
#  'strategic_planning',
#  'forecasting',
#  'budget',
#  'p_l',
#  'brand',
#  'product',
#  'management',
#  'channel',
#  'strategy',
#  'lead_generation',
#  'account',
#  'management',
#  'complex',
#  'selling',
#  'software',
#  'technology',
#  'manufacturing',
#  'sourcing',
#  'sale',
#  'enablement',
#  'business',
#  'competitive_analysis',
#  'market_research',
#  'new',
#  'product',
#  'development',
#  'packaging',
#  'creative',
#  'design',
#  'content',
#  'communication',
#  'social_medium',
#  'digital',
#  'event',
#  'project',
#  'management',
#  'vendor',
#  'management',
#  'crm',
#  'automation',
#  'apps',
#  'call_center',
#  'telemarketing',
#  'marketing',
#  'consultant_current',
#  'company_name',
#  'marketing',
#  'service',
#  'consulting',
#  'working',
#  'diverse',
#  'company',
#  'healthcare',
#  'technology',
#  'client',
#  'role',
#  'vary',
#  'consultant',
#  'contractor',
#  'employee',
#  'marketing',
#  'leadership',
#  'managing',
#  'area',
#  'marketing',
#  'function',
#  'resource',
#  'focus',
#  'corporate',
#  'startup',
#  'individual',
#  'seeking',
#  'thrive',
#  'including',
#  'marketing',
#  'director',
#  'consultant_company',
#  'name',
#  'increased_profit',
#  'one',
#  'restructure',
#  'business',
#  'line',
#  'b_b',
#  'technology',
#  'healthcare',
#  'solution',
#  'provider',
#  'var',
#  'ge',
#  'imaging',
#  'reporting',
#  'matrix',
#  'executive_leadership',
#  'oversaw',
#  'marketing',
#  'three',
#  'division',
#  'support',
#  'revenue',
#  'pipeline',
#  'across',
#  'diverse',
#  'vertical',
#  'market',
#  'key',
#  'focus',
#  'targeting',
#  'independent',
#  'hospital_clinic',
#  'physician',
#  'bundled',
#  'implementation',
#  'software',
#  'managed',
#  'develop',
#  'marketing',
#  'function',
#  'oversee',
#  'telemarketing',
#  'team',
#  'campaign',
#  'lead',
#  'facilitator',
#  'ge',
#  'imaging',
#  'marketing',
#  'plan',
#  'including',
#  'demand',
#  'generation',
#  'brand',
#  'development',
#  'marketing',
#  'communication',
#  'initiative',
#  'utilizing',
#  'salesforce',
#  'autotask',
#  'wordpress',
#  'project',
#  'management',
#  'practice',
#  'developed',
#  'content',
#  'digital',
#  'traditional',
#  'including',
#  'presentation',
#  'customer',
#  'story',
#  'video',
#  'blog',
#  'email',
#  'managed',
#  'multiple',
#  'event',
#  'across',
#  'vertical',
#  'market',
#  'business',
#  'healthcare',
#  'supporting',
#  'reseller',
#  'channel',
#  'strategy',
#  'new',
#  'brand',
#  'product',
#  'packaging',
#  'establishing',
#  'launch',
#  'program',
#  'brand',
#  'standard',
#  'calendar',
#  'action',
#  'plan',
#  'sr',
#  'director',
#  'marketing',
#  'company_name',
#  'b_b',
#  'healthcare',
#  'informatics',
#  'solution',
#  'employer',
#  'payer',
#  'reporting',
#  'president',
#  'cofounder',
#  'company',
#  'sold',
#  'developed',
#  'brand',
#  'ux',
#  'two',
#  'new',
#  'technology',
#  'platform',
#  'functionality',
#  'design',
#  'positioning',
#  'target',
#  'oversee',
#  'communication',
#  'brand',
#  'standard',
#  'proposal',
#  'consulting',
#  'service',
#  'diagnostic',
#  'report',
#  'coordinating',
#  'team',
#  'created',
#  'weekly',
#  'blog',
#  'strategy',
#  'establish',
#  'calendar',
#  'target',
#  'author',
#  'drive',
#  'lead',
#  'seo',
#  'content',
#  'manage',
#  'public_relation',
#  'including',
#  'medium',
#  'press',
#  'release',
#  'distribution',
#  'target',
#  'industry',
#  'contact',
#  'initiated',
#  'campaign',
#  'webinars',
#  'social_medium',
#  'entry',
#  'build',
#  'brand',
#  'via',
#  'targeted',
#  'campaign',
#  'lead_generation',
#  'content',
#  'including',
#  'whitepapers',
#  'initiated',
#  'crm',
#  'evaluation',
#  'selection',
#  'build',
#  'system',
#  'contact',
#  'lead',
#  'tracking',
#  'integration',
#  'developed',
#  'rebranding',
#  'plan',
#  'establish',
#  'primary_secondary',
#  'brand',
#  'current',
#  'new',
#  'product',
#  'including',
#  'competitive_analysis',
#  'positioning',
#  'market_research',
#  'testing',
#  'naming',
#  'product_roadmap',
#  'segmentation',
#  'identity',
#  'creation',
#  'developed',
#  'marketing',
#  'plan',
#  'calendar',
#  'budget',
#  'generate',
#  'organic',
#  'growth',
#  'across',
#  'largest',
#  'plan',
#  'sponsor',
#  'manage',
#  'branded',
#  'event',
#  'including',
#  'sponsorship',
#  'exhibit',
#  'working',
#  'national',
#  'regional',
#  'industry',
#  'group',
#  'ahip',
#  'amcp',
#  'world',
#  'salgba',
#  'national',
#  'industry',
#  'organization',
#  'reaching',
#  'health_plan',
#  'sponsor',
#  'developed',
#  'new',
#  'brand',
#  'strategy',
#  'w',
#  'engagement',
#  'tool',
#  'content',
#  'rebranding',
#  'launching',
#  'week',
#  'marketing',
#  'director',
#  'consultant_company',
#  'name',
#  'national',
#  'leader',
#  'hospital',
#  'revenue',
#  'cycle',
#  'solution',
#  'reported',
#  'president',
#  'company_wide',
#  'cost_reduction',
#  'launched',
#  'new',
#  'brand',
#  'solution',
#  'identify',
#  'creation',
#  'brand',
#  'standard',
#  'outbound_message',
#  'event',
#  'website',
#  'campaign',
#  'market',
#  'transition',
#  'customer_base',
#  'build',
#  'new',
#  'revenue',
#  'yr',
#  'developed',
#  'annual',
#  'marketing',
#  'plan',
#  'budget',
#  'hospital',
#  'market',
#  'pr',
#  'new',
#  'event',
#  'sponsorship',
#  'working',
#  'hfma',
#  'aaham',
#  'naham',
#  'local',
#  'regional',
#  'national',
#  'level',
#  'managed',
#  'vendor',
#  'reduce',
#  'spend',
#  'k',
#  'led',
#  'market',
#  'position',
#  'generate',
#  'qualified',
#  'funnel',
#  'revenue',
#  'tracking',
#  'organic',
#  'sale',
#  'referral',
#  'injected',
#  'culture',
#  'optimism',
#  'brand',
#  'revamp',
#  'peer_review',
#  'award',
#  'external',
#  'focus',
#  'communication',
#  'creative',
#  'tool',
#  'rebuilt',
#  'corporate',
#  'patient',
#  'facing',
#  'website',
#  'facebook',
#  'tracking',
#  'metric',
#  'content',
#  'seo_sem',
#  'manage',
#  'mra',
#  'voice',
#  'offset',
#  'competitor',
#  'inroad',
#  'revamped',
#  'patient',
#  'communication',
#  'present',
#  'positioning',
#  'patient',
#  'advocacy',
#  'letter',
#  'portal',
#  'call_center',
#  'po',
#  'developed',
#  'first',
#  'annual',
#  'customer_satisfaction',
#  'survey',
#  'achieving',
#  'participation',
#  'delivery',
#  'hospital',
#  'leader',
#  'director',
#  'marketing',
#  'executive',
#  'team_member',
#  'company_name',
#  'b_b',
#  'healthcare',
#  'rcm',
#  'start',
#  'physician',
#  'medical',
#  'group',
#  'company',
#  'folded',
#  'two',
#  'reported',
#  'ceo',
#  'targeted',
#  'physician',
#  'state',
#  'specialty',
#  'converting',
#  'customer',
#  'ehr',
#  'license',
#  'revenue',
#  'cycle',
#  'management',
#  'service',
#  'developed',
#  'new',
#  'software',
#  'launch',
#  'revenue',
#  'cycle',
#  'including',
#  'brand',
#  'strategy',
#  'digital',
#  'promotion',
#  'user',
#  'event',
#  'pr',
#  'yr',
#  'facilitated',
#  'trade_show',
#  'event',
#  'per',
#  'supporting',
#  'national',
#  'regional',
#  'community',
#  'initiative',
#  'rebranded',
#  'practice',
#  'management',
#  'software',
#  'service',
#  'transitioning',
#  'independent',
#  'practice',
#  'new',
#  'solution',
#  'established',
#  'new',
#  'u',
#  'lead',
#  'gen',
#  'team',
#  'u',
#  'including',
#  'crm',
#  'market',
#  'data',
#  'reporting',
#  'talent',
#  'revenue',
#  'pipeline',
#  'launched',
#  'new',
#  'design',
#  'related',
#  'communication',
#  'strategy',
#  'developed',
#  'advertising',
#  'trade',
#  'event',
#  'public_relation',
#  'built',
#  'social_medium',
#  'strategy',
#  'including',
#  'key',
#  'site',
#  'blog',
#  'ad',
#  'word',
#  'ppc',
#  'seo',
#  'content',
#  'development',
#  'build',
#  'lead',
#  'traffic',
#  'established',
#  'marketing',
#  'intelligence',
#  'function',
#  'across',
#  'physician',
#  'defined',
#  'key',
#  'target',
#  'specialty',
#  'campaign',
#  'analyzed',
#  'engagement',
#  'pipeline',
#  'market_trend',
#  'using',
#  'crm',
#  'research',
#  'satisfaction',
#  'study',
#  'managed',
#  'team',
#  'including',
#  'lead',
#  'gen',
#  'specialist',
#  'outsourced',
#  'vendor',
#  'member',
#  'executive',
#  'team',
#  'director',
#  'marketing',
#  'executive',
#  'team_member',
#  'company_name',
#  'aftermarket',
#  'auto',
#  'part',
#  'distributor',
#  'retailer',
#  'b_b',
#  'b_b',
#  'c',
#  'reported',
#  'general_manager',
#  'corporate',
#  'vp',
#  'recruited',
#  'new',
#  'startup',
#  'sale',
#  'increase',
#  'managed',
#  'trade_association',
#  'event',
#  'across',
#  'north_america',
#  'relaunched',
#  'brand',
#  'new',
#  'positioning',
#  'strategy',
#  'leveraging',
#  'market_research',
#  'equity',
#  'entirely',
#  'new',
#  'ad',
#  'campaign',
#  'e',
#  'marketing',
#  'vehicle',
#  'stabilized',
#  'sale',
#  'managed',
#  'customer_relationship',
#  'working',
#  'national',
#  'retailer',
#  'traditional',
#  'distribution_channel',
#  'service',
#  'diy',
#  'difm',
#  'market',
#  'supporting',
#  'store',
#  'location',
#  'north_america',
#  'created',
#  'unique',
#  'marketing',
#  'support',
#  'u',
#  'canada',
#  'initiated',
#  'business',
#  'review',
#  'strategic',
#  'plan',
#  'largest',
#  'retail',
#  'customer',
#  'location',
#  'market',
#  'test',
#  'licensing',
#  'evaluation',
#  'new',
#  'product',
#  'expansion',
#  'worth',
#  'sale',
#  'grew',
#  'business',
#  'versus',
#  'managed',
#  'contributed',
#  'executive',
#  'staff_member',
#  'reestablished',
#  'market',
#  'sale',
#  'focus',
#  'channel',
#  'strategy',
#  'momentum',
#  'new',
#  'sale',
#  'organization',
#  'annual_budget',
#  'spend',
#  'branded',
#  'customer',
#  'promotion',
#  'program',
#  'channel',
#  'marketing',
#  'manager_company',
#  'name',
#  'retail',
#  'business',
#  'b',
#  'fki',
#  'industry',
#  'fki',
#  'sold',
#  'melrose',
#  'liquidated',
#  'reported',
#  'vp',
#  'marketing',
#  'company',
#  'divested',
#  'strategically',
#  'managed',
#  'customer',
#  'merchandising',
#  'line',
#  'product',
#  'promotion',
#  'program',
#  'retail',
#  'national_account',
#  'created',
#  'new',
#  'brand',
#  'designer',
#  'collection',
#  'program',
#  'retailer',
#  'e',
#  'tailor',
#  'new',
#  'product',
#  'packaging',
#  'promotion',
#  'internet',
#  'advertising',
#  'merchandising',
#  'led',
#  'project',
#  'management',
#  'china',
#  'sourcing',
#  'store',
#  'rollout',
#  'created',
#  'new',
#  'hickory',
#  'hardware',
#  'brand',
#  'customer',
#  'program',
#  'including',
#  'innovative',
#  'merchandising',
#  'lifestyle',
#  'graphic',
#  'messaging',
#  'consumer',
#  'tool',
#  'packaging',
#  'upgrade',
#  'menards',
#  'home_depot',
#  'lowe',
#  'ch',
#  'briggs',
#  'established',
#  'new',
#  'corporate',
#  'new',
#  'product',
#  'development',
#  'process',
#  'tracking',
#  'reduced',
#  'npd',
#  'schedule',
#  'established',
#  'led',
#  'lowe',
#  'marketing',
#  'team',
#  'hiring',
#  'resource',
#  'setting',
#  'process',
#  'leading',
#  'monthly',
#  'service',
#  'product',
#  'marketing',
#  'program',
#  'top',
#  'customer',
#  'annually',
#  'managed',
#  'agency',
#  'vendor',
#  'upgrade',
#  'quality',
#  'marketing_strategy',
#  'branding',
#  'graphic',
#  'messaging',
#  'communication',
#  'achieved',
#  'first',
#  'consumer',
#  'ad',
#  'campaign',
#  'including',
#  'consumer',
#  'print',
#  'hgtv',
#  'sponsorship',
#  'line',
#  'market_place',
#  'conducted',
#  'market_research',
#  'project',
#  'among',
#  'pro',
#  'diy',
#  'consumer',
#  'establish',
#  'branding',
#  'message',
#  'channel',
#  'differentiation',
#  'strategy',
#  'various',
#  'product',
#  'resulting',
#  'packaging',
#  'promotion',
#  'new',
#  'web',
#  'strategy',
#  'sr',
#  'marketing',
#  'manager',
#  'consultant_company',
#  'name',
#  'start',
#  'b_b',
#  'company',
#  'speed',
#  'clinical_trial',
#  'enrollment',
#  'reporting',
#  'coo',
#  'consulting',
#  'area',
#  'small_business',
#  'created',
#  'start',
#  'marketing',
#  'led',
#  'implementation',
#  'brand',
#  'sale',
#  'channel_partner',
#  'marketing',
#  'pipeline',
#  'generated_k',
#  'closed',
#  'contract',
#  'first',
#  'six_month',
#  'pipeline',
#  'targeting',
#  'pharma',
#  'research',
#  'physician',
#  'strategic',
#  'market',
#  'manager_company',
#  'name',
#  'annual_sale',
#  'b_b',
#  'technology',
#  'service',
#  'data',
#  'software',
#  'division',
#  'reed',
#  'elsevier',
#  'reported',
#  'general_manager',
#  'vice_president',
#  'responsible',
#  'brand',
#  'product',
#  'mgt',
#  'customer',
#  'service',
#  'business',
#  'development',
#  'renewal',
#  'revenue_annually',
#  'generated',
#  'business',
#  'development',
#  'revenue',
#  'k',
#  'annually',
#  'reseller',
#  'agreement',
#  'directed',
#  'database',
#  'software',
#  'relaunch',
#  'emphasis',
#  'brand',
#  'product',
#  'repositioning',
#  'outsourcing',
#  'service',
#  'growth',
#  'developed',
#  'annual',
#  'marketing',
#  'plan',
#  'including',
#  'direct_mail',
#  'advertising',
#  'tradeshows',
#  'public_relation',
#  'product',
#  'sale',
#  'strategy',
#  'led',
#  'redesign',
#  'brand',
#  'relaunch',
#  'offering',
#  'integrated',
#  'marketing',
#  'multiple',
#  'target',
#  'audience',
#  'industry',
#  'segment',
#  'led',
#  'acquisition',
#  'merger',
#  'opportunity',
#  'evaluating',
#  'market',
#  'position',
#  'financial',
#  'performance',
#  'due_diligence',
#  'initial',
#  'interest',
#  ...]

# %%
len(all_sentences)
# Out:
# 625

# %%
#Actualizamos columna 'tokens_Content_CV' de nuestro DF con los bigramas:
df_candidatos_f['tokens_Content_CV'] = all_sentences

# %%
df_candidatos_f
# Out:
#                  Candidate_Name  \
# 0     DataScientist_Karla_Lewis
# 1     DataScientist_Rahul_Malik
# 2          HCM_Federico_Calonge
# 3              HCM_Robert_Smith
# 4    MLEngineer_Bradly_Johnston
# ..                          ...
# 620              382-CONSULTANT
# 621              383-CONSULTANT
# 622              384-CONSULTANT
# 623              385-CONSULTANT
# 624              386-CONSULTANT
#
#                                             Content_CV  \
# 0    \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 1    \nRAHUL MALIK\nNLP Data Scientist\nCONTACT WOR...
# 2    \n                                            ...
# 3    \nSap Hcm Consultant Phone: (123) 456 78 99\nE...
# 4    \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
# ..                                                 ...
# 620           CONSULTANT TO OWNER           Educati...
# 621         Pavithra  Shetty           Summary     ...
# 622           BUSINESS CONSULTANT       Professiona...
# 623           PRINCIPAL CONSULTANT       Summary   ...
# 624           MARKETING CONSULTANT           Summar...
#
#                                       clean_Content_CV  \
# 0    data scientist brooklyn ny data scientist grub...
# 1    nlp data scientist brooklyn ny nlp data scient...
# 2    hcm technical consultant working oracle tool p...
# 3    sap hcm consultant com qwikresume marshville r...
# 4    kasey vista detroit senior software engineer m...
# ..                                                 ...
# 620  consultant owner florida international univers...
# 621  pavithra shetty customer oriented principal co...
# 622  business consultant business sale operation po...
# 623  principal consultant supply chain logistics ma...
# 624  marketing consultant value creator marketing e...
#
#                                      tokens_Content_CV
# 0    [data_scientist, brooklyn, ny, data_scientist,...
# 1    [nlp, data_scientist, brooklyn, ny, nlp, data_...
# 2    [hcm, technical, consultant, working, oracle, ...
# 3    [sap_hcm, consultant, com, qwikresume, marshvi...
# 4    [kasey, vista, detroit, senior, software_engin...
# ..                                                 ...
# 620  [consultant, owner, florida, international, un...
# 621  [pavithra, shetty, customer, oriented, princip...
# 622  [business, consultant, business, sale, operati...
# 623  [principal_consultant, supply_chain, logistics...
# 624  [marketing, consultant, value, creator, market...
#
# [625 rows x 4 columns]

# %%
#Eliminamos al candidato '316-BUSINESS-DEVELOPMENT' ya que su Content_CV está vacio. 
df_candidatos_f =  df_candidatos_f[(df_candidatos_f['Candidate_Name']!='316-BUSINESS-DEVELOPMENT')]
df_candidatos_f
# Out:
#                  Candidate_Name  \
# 0     DataScientist_Karla_Lewis
# 1     DataScientist_Rahul_Malik
# 2          HCM_Federico_Calonge
# 3              HCM_Robert_Smith
# 4    MLEngineer_Bradly_Johnston
# ..                          ...
# 620              382-CONSULTANT
# 621              383-CONSULTANT
# 622              384-CONSULTANT
# 623              385-CONSULTANT
# 624              386-CONSULTANT
#
#                                             Content_CV  \
# 0    \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 1    \nRAHUL MALIK\nNLP Data Scientist\nCONTACT WOR...
# 2    \n                                            ...
# 3    \nSap Hcm Consultant Phone: (123) 456 78 99\nE...
# 4    \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
# ..                                                 ...
# 620           CONSULTANT TO OWNER           Educati...
# 621         Pavithra  Shetty           Summary     ...
# 622           BUSINESS CONSULTANT       Professiona...
# 623           PRINCIPAL CONSULTANT       Summary   ...
# 624           MARKETING CONSULTANT           Summar...
#
#                                       clean_Content_CV  \
# 0    data scientist brooklyn ny data scientist grub...
# 1    nlp data scientist brooklyn ny nlp data scient...
# 2    hcm technical consultant working oracle tool p...
# 3    sap hcm consultant com qwikresume marshville r...
# 4    kasey vista detroit senior software engineer m...
# ..                                                 ...
# 620  consultant owner florida international univers...
# 621  pavithra shetty customer oriented principal co...
# 622  business consultant business sale operation po...
# 623  principal consultant supply chain logistics ma...
# 624  marketing consultant value creator marketing e...
#
#                                      tokens_Content_CV
# 0    [data_scientist, brooklyn, ny, data_scientist,...
# 1    [nlp, data_scientist, brooklyn, ny, nlp, data_...
# 2    [hcm, technical, consultant, working, oracle, ...
# 3    [sap_hcm, consultant, com, qwikresume, marshvi...
# 4    [kasey, vista, detroit, senior, software_engin...
# ..                                                 ...
# 620  [consultant, owner, florida, international, un...
# 621  [pavithra, shetty, customer, oriented, princip...
# 622  [business, consultant, business, sale, operati...
# 623  [principal_consultant, supply_chain, logistics...
# 624  [marketing, consultant, value, creator, market...
#
# [624 rows x 4 columns]

# %% [markdown]
# ###  2-Realizando Comparaciones y obteniendo Similitudes.

# %% [markdown]
# ###### Creamos un nuevo DF concatenando los 2 dataframe de manera que se comparen todos los CVs con todos los Jobs:

# %%
#Nos quedarán 10 x 10 = 100 filas.
df_Jobs_and_Candidates = pd.merge(df_candidatos_f.assign(A=1), df_Jobs.assign(A=1), on='A').drop('A', 1)
df_Jobs_and_Candidates
# Out:
#                  Candidate_Name  \
# 0     DataScientist_Karla_Lewis
# 1     DataScientist_Karla_Lewis
# 2     DataScientist_Karla_Lewis
# 3     DataScientist_Karla_Lewis
# 4     DataScientist_Karla_Lewis
# ...                         ...
# 6245             386-CONSULTANT
# 6246             386-CONSULTANT
# 6247             386-CONSULTANT
# 6248             386-CONSULTANT
# 6249             386-CONSULTANT
#
#                                              Content_CV  \
# 0     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 1     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 2     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 3     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 4     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# ...                                                 ...
# 6245           MARKETING CONSULTANT           Summar...
# 6246           MARKETING CONSULTANT           Summar...
# 6247           MARKETING CONSULTANT           Summar...
# 6248           MARKETING CONSULTANT           Summar...
# 6249           MARKETING CONSULTANT           Summar...
#
#                                        clean_Content_CV  \
# 0     data scientist brooklyn ny data scientist grub...
# 1     data scientist brooklyn ny data scientist grub...
# 2     data scientist brooklyn ny data scientist grub...
# 3     data scientist brooklyn ny data scientist grub...
# 4     data scientist brooklyn ny data scientist grub...
# ...                                                 ...
# 6245  marketing consultant value creator marketing e...
# 6246  marketing consultant value creator marketing e...
# 6247  marketing consultant value creator marketing e...
# 6248  marketing consultant value creator marketing e...
# 6249  marketing consultant value creator marketing e...
#
#                                       tokens_Content_CV  \
# 0     [data_scientist, brooklyn, ny, data_scientist,...
# 1     [data_scientist, brooklyn, ny, data_scientist,...
# 2     [data_scientist, brooklyn, ny, data_scientist,...
# 3     [data_scientist, brooklyn, ny, data_scientist,...
# 4     [data_scientist, brooklyn, ny, data_scientist,...
# ...                                                 ...
# 6245  [marketing, consultant, value, creator, market...
# 6246  [marketing, consultant, value, creator, market...
# 6247  [marketing, consultant, value, creator, market...
# 6248  [marketing, consultant, value, creator, market...
# 6249  [marketing, consultant, value, creator, market...
#
#                         Job_Title  \
# 0                  Data Scientist
# 1                Data Scientist 2
# 2                  HCM Consultant
# 3                HCM Consultant 2
# 4       Machine Learning Engineer
# ...                           ...
# 6245  Machine Learning Engineer 2
# 6246          Security Specialist
# 6247        Security Specialist 2
# 6248     Web Developer Full Stack
# 6249   Web Developer Full Stack 2
#
#                                         Job_Description  \
# 0     Master’s degree or above in a STEM field, incl...
# 1     \nReporting to the Director, Data & Analytics,...
# 2     \nThe Oracle Cloud HCM Absence Consultant will...
# 3     4+ years of experience in PeopleSoft or Oracle...
# 4     Leveraging the latest machine and deep learnin...
# ...                                                 ...
# 6245  Collaborate with a multidisciplinary team to g...
# 6246  Work in a fast-paced environment that combine ...
# 6247  \n    Handling incoming requests for assistanc...
# 6248  \n\n    Graduate Degree in Information Technol...
# 6249  \n· Enter existing website codebases and exten...
#
#                                   clean_Job_Description  \
# 0     master degree stem field including limited com...
# 1     reporting director data analytics senior data ...
# 2     oracle cloud hcm absence consultant responsibl...
# 3     peoplesoft oracle eb implementation support hc...
# 4     leveraging latest machine deep learning techni...
# ...                                                 ...
# 6245  collaborate multidisciplinary team gain insigh...
# 6246  fast paced environment combine technical secur...
# 6247  handling incoming request assistance business ...
# 6248  graduate degree information technology similar...
# 6249  enter existing codebases extend functionality ...
#
#                                  tokens_Job_Description
# 0     [master, degree, stem, field, including, limit...
# 1     [reporting, director, data, analytics, senior,...
# 2     [oracle, cloud, hcm, absence, consultant, resp...
# 3     [peoplesoft, oracle, eb, implementation, suppo...
# 4     [leveraging, latest, machine, deep_learning, t...
# ...                                                 ...
# 6245  [collaborate, multidisciplinary, team, gain, i...
# 6246  [fast, paced, environment, combine, technical,...
# 6247  [handling, incoming, request, assistance, busi...
# 6248  [graduate, degree, information, technology, si...
# 6249  [enter, existing, codebases, extend, functiona...
#
# [6250 rows x 8 columns]

# %%
#Exportamos el csv:
df_Jobs_and_Candidates.to_csv('DF_Exportado_6250_rows.csv',index = False)

# %%
#Si lo queremos importar:
df_Jobs_and_Candidates = pd.read_csv('DF_Exportado_6250_rows.csv')
df_Jobs_and_Candidates.shape
# Out:
# (6250, 8)

# %%
array_unicode_CV = df_Jobs_and_Candidates['clean_Content_CV'].astype('U').values
array_unicode_Jobs= df_Jobs_and_Candidates['clean_Job_Description'].astype('U').values

# %% [markdown]
# ### 2.1- TF-IDF & Cosine Similarity.

# %%
#https://www.py4u.net/discuss/188191
    
#Calculate cosine similarity using tf-idf vectors, between search queries and matched documents.
#Acá mi search query es la columna clean_Content_CV y el matched documents son los clean_Job_Description.
#Cuando hacemos un transform estamos pasandole la query para que se fije los TF-IDF que tiene ya entrenados
#del modelo (cuando hicimos fit ya lo entrenamos... y lo hicimos con los cvs y los job descriptions). 

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import paired_cosine_distances as pcd

# Initialize an instance of tf-idf Vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Generate the tf-idf vectors for the corpus
#tfidf_vectorizer.fit(df_Jobs_and_Candidates['clean_Content_CV'] + " " + df_Jobs_and_Candidates['clean_Job_Description'])
tfidf_vectorizer.fit(array_unicode_CV+array_unicode_Jobs)

A = tfidf_vectorizer.transform(array_unicode_CV)
B = tfidf_vectorizer.transform(array_unicode_Jobs)

# compute and the cosine similarity:
cosine = 1 - pcd(A, B)

df_Jobs_and_Candidates['tfidf_cosine'] = cosine

df_Jobs_and_Candidates
# Out:
#                  Candidate_Name  \
# 0     DataScientist_Karla_Lewis
# 1     DataScientist_Karla_Lewis
# 2     DataScientist_Karla_Lewis
# 3     DataScientist_Karla_Lewis
# 4     DataScientist_Karla_Lewis
# ...                         ...
# 6245             386-CONSULTANT
# 6246             386-CONSULTANT
# 6247             386-CONSULTANT
# 6248             386-CONSULTANT
# 6249             386-CONSULTANT
#
#                                              Content_CV  \
# 0     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 1     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 2     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 3     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 4     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# ...                                                 ...
# 6245           MARKETING CONSULTANT           Summar...
# 6246           MARKETING CONSULTANT           Summar...
# 6247           MARKETING CONSULTANT           Summar...
# 6248           MARKETING CONSULTANT           Summar...
# 6249           MARKETING CONSULTANT           Summar...
#
#                                        clean_Content_CV  \
# 0     data scientist brooklyn ny data scientist grub...
# 1     data scientist brooklyn ny data scientist grub...
# 2     data scientist brooklyn ny data scientist grub...
# 3     data scientist brooklyn ny data scientist grub...
# 4     data scientist brooklyn ny data scientist grub...
# ...                                                 ...
# 6245  marketing consultant value creator marketing e...
# 6246  marketing consultant value creator marketing e...
# 6247  marketing consultant value creator marketing e...
# 6248  marketing consultant value creator marketing e...
# 6249  marketing consultant value creator marketing e...
#
#                                       tokens_Content_CV  \
# 0     ['data_scientist', 'brooklyn', 'ny', 'data_sci...
# 1     ['data_scientist', 'brooklyn', 'ny', 'data_sci...
# 2     ['data_scientist', 'brooklyn', 'ny', 'data_sci...
# 3     ['data_scientist', 'brooklyn', 'ny', 'data_sci...
# 4     ['data_scientist', 'brooklyn', 'ny', 'data_sci...
# ...                                                 ...
# 6245  ['marketing', 'consultant', 'value', 'creator'...
# 6246  ['marketing', 'consultant', 'value', 'creator'...
# 6247  ['marketing', 'consultant', 'value', 'creator'...
# 6248  ['marketing', 'consultant', 'value', 'creator'...
# 6249  ['marketing', 'consultant', 'value', 'creator'...
#
#                         Job_Title  \
# 0                  Data Scientist
# 1                Data Scientist 2
# 2                  HCM Consultant
# 3                HCM Consultant 2
# 4       Machine Learning Engineer
# ...                           ...
# 6245  Machine Learning Engineer 2
# 6246          Security Specialist
# 6247        Security Specialist 2
# 6248     Web Developer Full Stack
# 6249   Web Developer Full Stack 2
#
#                                         Job_Description  \
# 0     Master’s degree or above in a STEM field, incl...
# 1     \nReporting to the Director, Data & Analytics,...
# 2     \nThe Oracle Cloud HCM Absence Consultant will...
# 3     4+ years of experience in PeopleSoft or Oracle...
# 4     Leveraging the latest machine and deep learnin...
# ...                                                 ...
# 6245  Collaborate with a multidisciplinary team to g...
# 6246  Work in a fast-paced environment that combine ...
# 6247  \n    Handling incoming requests for assistanc...
# 6248  \n\n    Graduate Degree in Information Technol...
# 6249  \n· Enter existing website codebases and exten...
#
#                                   clean_Job_Description  \
# 0     master degree stem field including limited com...
# 1     reporting director data analytics senior data ...
# 2     oracle cloud hcm absence consultant responsibl...
# 3     peoplesoft oracle eb implementation support hc...
# 4     leveraging latest machine deep learning techni...
# ...                                                 ...
# 6245  collaborate multidisciplinary team gain insigh...
# 6246  fast paced environment combine technical secur...
# 6247  handling incoming request assistance business ...
# 6248  graduate degree information technology similar...
# 6249  enter existing codebases extend functionality ...
#
#                                  tokens_Job_Description  tfidf_cosine
# 0     ['master', 'degree', 'stem', 'field', 'includi...      0.060513
# 1     ['reporting', 'director', 'data', 'analytics',...      0.115418
# 2     ['oracle', 'cloud', 'hcm', 'absence', 'consult...      0.021795
# 3     ['peoplesoft', 'oracle', 'eb', 'implementation...      0.019523
# 4     ['leveraging', 'latest', 'machine', 'deep_lear...      0.051246
# ...                                                 ...           ...
# 6245  ['collaborate', 'multidisciplinary', 'team', '...      0.041610
# 6246  ['fast', 'paced', 'environment', 'combine', 't...      0.071639
# 6247  ['handling', 'incoming', 'request', 'assistanc...      0.041386
# 6248  ['graduate', 'degree', 'information', 'technol...      0.029146
# 6249  ['enter', 'existing', 'codebases', 'extend', '...      0.038411
#
# [6250 rows x 9 columns]

# %% [markdown]
# ### 2.2- Word Embedding (Word2vec) & WMD.

# %% [markdown]
# #### Usamos un Word2vec entrenado con nuestro vocabulario.

# %% [markdown]
# #### Unimos las columnas 'tokens_Job_Description' de 'df_Jobs' y 'tokens_Content_CV' de 'df_candidatos_f' generando una lista de listas, la cual será nuestro vocabulario que introduciremos a Word EMbedding como entrenamiento:

# %%
list_vocab_Jobs = df_Jobs['tokens_Job_Description']
#list_vocab_Jobs.tolist()

# %%
list_vocab_Jobs
# Out:
# 0        [master_degree, stem, field, including_limited...
# 1        [reporting, director, data, analytics, senior,...
# 2        [oracle, cloud, hcm, absence, consultant, resp...
# 3        [peoplesoft, oracle_eb, implementation, suppor...
# 4        [leveraging_latest, machine, deep_learning, te...
#                                ...
# 20588    [company, description, searching, talented, cr...
# 20589    [location_san, francisco, caterm, full_time, p...
# 20590    [take_pride, knowing, thousand, life, positive...
# 20591    [company, description, offer, youas, world_lea...
# 20592    [c_c, programmingdevelopment, win, programming...
# Name: tokens_Job_Description, Length: 20593, dtype: object

# %%
list_vocab_Candid = df_candidatos_f['tokens_Content_CV']
#list_vocab_Candid.tolist()

# %%
list_vocab_Candid
# Out:
# 0      [data_scientist, brooklyn, ny, data_scientist,...
# 1      [nlp, data_scientist, brooklyn, ny, nlp, data_...
# 2      [hcm, technical, consultant, working, oracle, ...
# 3      [sap_hcm, consultant, com, qwikresume, marshvi...
# 4      [kasey, vista, detroit, senior, software_engin...
#                              ...
# 620    [consultant, owner, florida, international, un...
# 621    [pavithra, shetty, customer, oriented, princip...
# 622    [business, consultant, business, sale, operati...
# 623    [principal_consultant, supply_chain, logistics...
# 624    [marketing, consultant, value, creator, market...
# Name: tokens_Content_CV, Length: 625, dtype: object

# %%
all_vocab = list_vocab_Candid.append(list_vocab_Jobs) #Unimos las listas.

# %%
all_vocab
# Out:
# 0        [data_scientist, brooklyn, ny, data_scientist,...
# 1        [nlp, data_scientist, brooklyn, ny, nlp, data_...
# 2        [hcm, technical, consultant, working, oracle, ...
# 3        [sap_hcm, consultant, com, qwikresume, marshvi...
# 4        [kasey, vista, detroit, senior, software_engin...
#                                ...
# 20588    [company, description, searching, talented, cr...
# 20589    [location_san, francisco, caterm, full_time, p...
# 20590    [take_pride, knowing, thousand, life, positive...
# 20591    [company, description, offer, youas, world_lea...
# 20592    [c_c, programmingdevelopment, win, programming...
# Length: 21218, dtype: object

# %%
lista_all_vocab = all_vocab.tolist()
lista_all_vocab[0]
# Out:
# ['data_scientist',
#  'brooklyn',
#  'ny',
#  'data_scientist',
#  'grubhub',
#  'current',
#  'new_york',
#  'ny',
#  'implemented',
#  'various',
#  'time_series',
#  'forecasting',
#  'technique',
#  'predict',
#  'surge',
#  'customer',
#  'order',
#  'lower',
#  'average',
#  'customer',
#  'wait',
#  'time',
#  'minute',
#  'github',
#  'deployed',
#  'recommendation',
#  'engine',
#  'production',
#  'conditionally',
#  'recommend',
#  'menu',
#  'item',
#  'based',
#  'past',
#  'order',
#  'history',
#  'increase',
#  'average',
#  'order',
#  'size',
#  'designed',
#  'model',
#  'portland',
#  'pilot',
#  'program',
#  'increase',
#  'incentive',
#  'driver',
#  'peak',
#  'ordering',
#  'hour',
#  'resulting_increase',
#  'driver',
#  'b',
#  'availability',
#  'peak',
#  'ordering',
#  'time',
#  'statistic',
#  'rutgers',
#  'university',
#  'data_scientist',
#  'new',
#  'brunswick_nj',
#  'adobe',
#  'new_york',
#  'ny',
#  'worked',
#  'product',
#  'marketing',
#  'team',
#  'identify',
#  'customer',
#  'interaction',
#  'free',
#  'trial',
#  'maximize',
#  'likelihood',
#  'conversion',
#  'resulting',
#  'conversion_rate',
#  'increase',
#  'built',
#  'customer',
#  'attrition',
#  'random',
#  'forest',
#  'model',
#  'improved',
#  'monthly',
#  'python',
#  'numpy_panda',
#  'scikit_learn',
#  'retention',
#  'basis',
#  'point',
#  'customer',
#  'likely',
#  'attrit',
#  'kera',
#  'flask',
#  'servicing',
#  'relevant',
#  'product',
#  'feature',
#  'sql',
#  'mysql',
#  'postgres',
#  'worked_closely',
#  'product',
#  'team',
#  'build',
#  'production',
#  'git',
#  'recommendation',
#  'engine',
#  'python',
#  'improved',
#  'average',
#  'length',
#  'user',
#  'resulted',
#  'k',
#  'incremental',
#  'annual_revenue',
#  'time_series',
#  'forecasting',
#  'productionizing',
#  'model',
#  'recommendation',
#  'engine',
#  'data',
#  'analyst',
#  'customer',
#  'segmentation',
#  'adobe',
#  'new_york',
#  'ny',
#  'aws',
#  'worked',
#  'product',
#  'manager',
#  'perform',
#  'cohort',
#  'analysis',
#  'identiﬁed',
#  'opportunity',
#  'reduce',
#  'pricing',
#  'segment',
#  'user',
#  'boost',
#  'yearly',
#  'revenue',
#  'built',
#  'operational',
#  'reporting',
#  'tableau',
#  'ﬁnd',
#  'area',
#  'improvement',
#  'contractor',
#  'resulting',
#  'annual',
#  'incremental',
#  'revenue',
#  'implemented',
#  'long_term',
#  'pricing',
#  'experiment',
#  'improved',
#  'customer',
#  'lifetime',
#  'value']

# %%
len(lista_all_vocab)
# Out:
# 21218

# %% [markdown]
# #### Modelo word2vec:

# %%
from gensim.models import Word2Vec

#La librería Gensim nos provee una simple API al algoritmo de Google 'word2vec' el cual es usado para crear word embeddings.
#Como vimos previamente, word2vec son modelos de redes neuronales superficiales de dos capas que están entrenadas para
#reconstruir contextos lingüísticos de palabras. 

#Podemos traer word embeddings pre-entrenados con noticias de Google por ejemplo, donde se entrenarán con 3 millones de palabras.
#Pero, nosotros lo que hacemos es utilizar nuestro vocabulario para entrenar y crear nuestros propios embeddings.  

#La entrada de la red neuronal es una palabra representada como un vector “one-hot”, es decir, un vector con tantas posiciones 
#como tamaño tenga el vocabulario. 
#Por ejemplo, si queremos representar la palabra “sol” de un vocabulario de 4 palabras (el sol está cayendo), usaremos un vector
#de de esta dimensión (5) con cero en todas las posiciones menos la correspondiente a la palabra “sol” que tendrá 
#un uno --> [0,1,0,0]
#Y la  salida de la red neuronal será otro vector “one-hot” llamado “Word embedding” de las mismas 4 posiciones que representará
#las probabilidades de cada una de las palabras sean vecinas de la palabra representada en la entrada. [0.12, 1, 0.4, 0.1]
#--> Es 1 en la 2da posición ya que es la misma posición de la palabra. 

#Word embedding es una de las representaciones de un documento de vocabulario más popular. Es capaz de caputar los
#contextos de una palabra en el documento, similitud semantica y sintáctica, relaciones con otras palabras, etc.

#Mediante la siguiente línea de código entrenamos al modelo Word2Vec mediante nuestras 1275 palabras contenidas en “all_Sentences”:
model=gensim.models.Word2Vec(sentences=lista_all_vocab,min_count=2,workers=4,window=4,sg=0) #lo entrenamos con las all_sentences anterior.
#Ver como dividir en train y test. En nuestro caso igualmente no es necesario ya que no vamos a predecir palabras en base a contectos, 
#simplemente vamos a obtener las palabras más similares... entonces usamos TODAS las sentencias como entrenamiento. 
#model = Word2Vec(sentences=lista_all_vocab, size=200, window=4, min_count=1, workers=4)
#Parametros funcion Word2Vec:
#min_count : Ignore all the words where frequency of each word is less than min_count, default value is 5. As we wanted to add all words in corpus, so value we provided is 1.
#size: la longitud del vector denso para representar cada palabra. #VER.
#window: es el tamaño del "filtro" que se usa para analizar el contexto entre una palbras y las otras.  #CREO, VER. 
#workers: las iteraciones de entrenamiento.  #ESO ENTENDI, VER. 
#sg: es si utiliza el algoritmo de entrenamiento CBOW o skip gram. Por defecto estáen 0 (CBOW).

model.save("model")
wrds=list(model.wv.vectors)   #El modelo nos da un vocabulario con palabras con las cuales podemos consultar. 
print(len(wrds))

#ME devuelve 15069 palabras de vocabulario.
# Out:
# 60855

# %%
#Cargamos el modelo:

#from gensim import models
#w2vec_model = models.KeyedVectors.load_word2vec_format('model', binary=True)
#w2vec_model

#from gensim.models import Word2Vec
#model = Word2Vec.load_word2vec_format('model', binary=True)

#word2vec = KeyedVectors.load_word2vec_format('final.model', binary=False)
#from gensim import models
#w2vec_model = models.KeyedVectors.load_word2vec_format('model', binary=True)
#w2vec_model = KeyedVectors.load('model')

# %%
model.wv.get_vector('machine_learning')
# Out:
# array([-9.35329318e-01,  3.30134690e-01, -1.52708888e+00, -9.32685360e-02,
#        -2.32141781e+00,  1.13510227e+00,  1.92877603e+00, -1.08878505e+00,
#        -3.70160900e-02, -1.94043148e+00,  6.59955204e-01, -1.36610961e+00,
#        -8.03965092e-01, -1.07488823e+00,  2.45476127e+00, -2.40702701e+00,
#         1.28087670e-01,  3.92293036e-01, -8.57815683e-01, -1.33548349e-01,
#         7.01223239e-02, -8.53365541e-01,  2.36701274e+00,  9.49352503e-01,
#        -7.31995851e-02,  1.82397389e+00, -5.87599277e-01, -7.96092868e-01,
#         5.39072193e-02,  6.38300657e-01,  6.50366664e-01,  2.47248158e-01,
#         8.03261697e-02, -2.32437849e+00, -1.85387123e+00,  1.27883121e-01,
#        -2.56175542e+00,  3.37904096e-02,  7.70332158e-01, -2.53822785e-02,
#        -8.98168743e-01,  1.01843905e+00,  2.21773219e+00,  3.25790495e-01,
#         5.62601626e-01, -1.13821220e+00, -1.69144189e+00,  1.89986244e-01,
#         1.64483571e+00,  8.70197773e-01,  2.62504839e-03,  1.89018309e-01,
#         7.53653884e-01, -1.79287207e+00,  8.93642426e-01,  1.00115895e+00,
#        -8.52493227e-01,  9.71001744e-01,  1.58073103e+00,  1.58811736e+00,
#         1.76702535e+00,  3.09467733e-01, -3.74142602e-02,  1.78202212e-01,
#        -3.84988785e-01, -4.26538616e-01, -5.62362611e-01,  3.15002775e+00,
#        -6.33281827e-01,  9.18949425e-01,  7.50638843e-01,  2.08433414e+00,
#        -1.23817354e-01,  1.02838624e+00, -4.96072829e-01,  2.53095365e+00,
#         2.81945765e-01, -3.94704908e-01,  4.56633091e-01,  1.49536163e-01,
#        -8.06487441e-01,  9.77765545e-02,  1.25676620e+00,  9.29315269e-01,
#        -1.54039299e+00, -4.59468216e-01, -1.32793963e+00,  2.60189557e+00,
#        -8.78586054e-01,  6.16234243e-01,  5.02669156e-01, -4.06052917e-01,
#         2.08649921e+00,  1.40328407e+00, -7.86856651e-01,  7.75856733e-01,
#        -2.23971438e+00, -9.23514605e-01,  8.29490960e-01, -1.02945685e+00],
#       dtype=float32)

# %%
model.wv.wmdistance('deep_learning', 'machine_learning')
# Out:
# 0.3036559729920758

# %%
#Gracias a nuestros words embeddings obtenidos por el entrenamiento en el modelo word2vec,
#ahora podemos realizar funciones como 'most_similar'....testeamos nuestro modelo: 
ModeloPrueba=model.wv.most_similar("machine_learning")     

#La función most_similar busca palabras que esten semánticamente
#cercas (que sean parecidas) a una palabra dada (En este caso 'machine_learning').

# %%
print(ModeloPrueba)
# Out:
# [('deep_learning', 0.8448491096496582), ('artificial_intelligence', 0.8281981348991394), ('nlp', 0.8264880776405334), ('natural_language', 0.7937481999397278), ('predictive_analytics', 0.7921558618545532), ('algorithm', 0.7918980717658997), ('predictive', 0.7864595055580139), ('predictive_modeling', 0.7853081226348877), ('newsql', 0.7812016010284424), ('data_mining', 0.7807395458221436)]

# %%
#Función WMD que usaremos:
def WMD(tokens_CV_Candidate,tokens_Job_Desc):
    return (model.wv.wmdistance(tokens_CV_Candidate, tokens_Job_Desc))  #'wmdistance' return the word mover distance between two documents.

# %%
#Como prueba obtenemos el WMD comparando para la 1ra fila (entre las columnas tokens_Content_CV y tokens_Job_Description)
first_job_descr = df_Jobs_and_Candidates.loc[0,'tokens_Job_Description']
first_content_cv = df_Jobs_and_Candidates.loc[0,'tokens_Content_CV']

wmd_result = round(WMD(first_job_descr,first_content_cv),3)
print(wmd_result)
 
similarity_wdm = round((1/(1+wmd_result)),3)  
print(similarity_wdm)
# Out:
# 0.113
# 0.898

# %% [markdown]
# #### Usamos el Word2vec descargado.

# %%
#Link del cual descargamos el archivo: https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
EMBEDDING_FILE = '/home/fedricio/Desktop/Embeddings_Utilizados/Word2vec/GoogleNews-vectors-negative300.bin.gz'
word2vec = KeyedVectors.load_word2vec_format(EMBEDDING_FILE, binary=True)
#Vemos si algunos bigramas estan: #word2vec["python"]

# %%
#Función WMD que usaremos:
def WMD(tokens_CV_Candidate,tokens_Job_Desc):
    return (word2vec.wmdistance(tokens_CV_Candidate, tokens_Job_Desc))  #'wmdistance' return the word mover distance between two documents.

# %%
#Como prueba obtenemos el WMD comparando para la 1ra fila (entre las columnas tokens_Content_CV y tokens_Job_Description)
first_job_descr = df_Jobs_and_Candidates.loc[0,'tokens_Job_Description']
first_content_cv = df_Jobs_and_Candidates.loc[0,'tokens_Content_CV']

wmd_result = round(WMD(first_job_descr,first_content_cv),3)
print(wmd_result)
 
similarity_wdm = round((1/(1+wmd_result)),3)  
print(similarity_wdm)
# Out:
# 0.052
# 0.951

# %%
#Aplicamos WMD para TODO el DF... entre el contenido del CV y la descripcion del puesto; 
#y el resultado lo guardamos en las columna 'WMD_Job_Desc'.

#df_Jobs_and_Candidates['WMD_Job_Desc'] = df_Jobs_and_Candidates.apply(lambda row: round(WMD(row['tokens_Content_CV'],row['tokens_Job_Description']),3), axis=1)
#APlicando lo de  --> similarity = 1 / (1 + distance):
#(#similarity = 1 / (1 + distance) https://groups.google.com/g/gensim/c/-pRZnsOEaPQ)
df_Jobs_and_Candidates['WMD_Job_Desc'] = df_Jobs_and_Candidates.apply(lambda row: round((1/(1+(WMD(row['tokens_Content_CV'],row['tokens_Job_Description'])))),3), axis=1)

# %%
df_Jobs_and_Candidates
# Out:
#                  Candidate_Name  \
# 0     DataScientist_Karla_Lewis
# 1     DataScientist_Karla_Lewis
# 2     DataScientist_Karla_Lewis
# 3     DataScientist_Karla_Lewis
# 4     DataScientist_Karla_Lewis
# ...                         ...
# 6245             386-CONSULTANT
# 6246             386-CONSULTANT
# 6247             386-CONSULTANT
# 6248             386-CONSULTANT
# 6249             386-CONSULTANT
#
#                                              Content_CV  \
# 0     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 1     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 2     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 3     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# 4     \nKARLA LEWIS\nData Scientist\nCONTACT WORK EX...
# ...                                                 ...
# 6245           MARKETING CONSULTANT           Summar...
# 6246           MARKETING CONSULTANT           Summar...
# 6247           MARKETING CONSULTANT           Summar...
# 6248           MARKETING CONSULTANT           Summar...
# 6249           MARKETING CONSULTANT           Summar...
#
#                                        clean_Content_CV  \
# 0     data scientist brooklyn ny data scientist grub...
# 1     data scientist brooklyn ny data scientist grub...
# 2     data scientist brooklyn ny data scientist grub...
# 3     data scientist brooklyn ny data scientist grub...
# 4     data scientist brooklyn ny data scientist grub...
# ...                                                 ...
# 6245  marketing consultant value creator marketing e...
# 6246  marketing consultant value creator marketing e...
# 6247  marketing consultant value creator marketing e...
# 6248  marketing consultant value creator marketing e...
# 6249  marketing consultant value creator marketing e...
#
#                                       tokens_Content_CV  \
# 0     ['data_scientist', 'brooklyn', 'ny', 'data_sci...
# 1     ['data_scientist', 'brooklyn', 'ny', 'data_sci...
# 2     ['data_scientist', 'brooklyn', 'ny', 'data_sci...
# 3     ['data_scientist', 'brooklyn', 'ny', 'data_sci...
# 4     ['data_scientist', 'brooklyn', 'ny', 'data_sci...
# ...                                                 ...
# 6245  ['marketing', 'consultant', 'value', 'creator'...
# 6246  ['marketing', 'consultant', 'value', 'creator'...
# 6247  ['marketing', 'consultant', 'value', 'creator'...
# 6248  ['marketing', 'consultant', 'value', 'creator'...
# 6249  ['marketing', 'consultant', 'value', 'creator'...
#
#                         Job_Title  \
# 0                  Data Scientist
# 1                Data Scientist 2
# 2                  HCM Consultant
# 3                HCM Consultant 2
# 4       Machine Learning Engineer
# ...                           ...
# 6245  Machine Learning Engineer 2
# 6246          Security Specialist
# 6247        Security Specialist 2
# 6248     Web Developer Full Stack
# 6249   Web Developer Full Stack 2
#
#                                         Job_Description  \
# 0     Master’s degree or above in a STEM field, incl...
# 1     \nReporting to the Director, Data & Analytics,...
# 2     \nThe Oracle Cloud HCM Absence Consultant will...
# 3     4+ years of experience in PeopleSoft or Oracle...
# 4     Leveraging the latest machine and deep learnin...
# ...                                                 ...
# 6245  Collaborate with a multidisciplinary team to g...
# 6246  Work in a fast-paced environment that combine ...
# 6247  \n    Handling incoming requests for assistanc...
# 6248  \n\n    Graduate Degree in Information Technol...
# 6249  \n· Enter existing website codebases and exten...
#
#                                   clean_Job_Description  \
# 0     master degree stem field including limited com...
# 1     reporting director data analytics senior data ...
# 2     oracle cloud hcm absence consultant responsibl...
# 3     peoplesoft oracle eb implementation support hc...
# 4     leveraging latest machine deep learning techni...
# ...                                                 ...
# 6245  collaborate multidisciplinary team gain insigh...
# 6246  fast paced environment combine technical secur...
# 6247  handling incoming request assistance business ...
# 6248  graduate degree information technology similar...
# 6249  enter existing codebases extend functionality ...
#
#                                  tokens_Job_Description  tfidf_cosine  \
# 0     ['master', 'degree', 'stem', 'field', 'includi...      0.060513
# 1     ['reporting', 'director', 'data', 'analytics',...      0.115418
# 2     ['oracle', 'cloud', 'hcm', 'absence', 'consult...      0.021795
# 3     ['peoplesoft', 'oracle', 'eb', 'implementation...      0.019523
# 4     ['leveraging', 'latest', 'machine', 'deep_lear...      0.051246
# ...                                                 ...           ...
# 6245  ['collaborate', 'multidisciplinary', 'team', '...      0.041610
# 6246  ['fast', 'paced', 'environment', 'combine', 't...      0.071639
# 6247  ['handling', 'incoming', 'request', 'assistanc...      0.041386
# 6248  ['graduate', 'degree', 'information', 'technol...      0.029146
# 6249  ['enter', 'existing', 'codebases', 'extend', '...      0.038411
#
#       WMD_Job_Desc
# 0            0.898
# 1            0.903
# 2            0.884
# 3            0.905
# 4            0.896
# ...            ...
# 6245         0.927
# 6246         0.937
# 6247         0.910
# 6248         0.910
# 6249         0.936
#
# [6250 rows x 10 columns]

# %% [markdown]
# ### Vemos como ejemplo a Federico Calonge:

# %%
is_Federico_Calonge =  df_Jobs_and_Candidates['Candidate_Name']=='HCM_Federico_Calonge'
new_DF = df_Jobs_and_Candidates[is_Federico_Calonge]
print(new_DF.shape)
new_DF
# Out:
# (10, 10)
#           Candidate_Name                                         Content_CV  \
# 20  HCM_Federico_Calonge  \n                                            ...
# 21  HCM_Federico_Calonge  \n                                            ...
# 22  HCM_Federico_Calonge  \n                                            ...
# 23  HCM_Federico_Calonge  \n                                            ...
# 24  HCM_Federico_Calonge  \n                                            ...
# 25  HCM_Federico_Calonge  \n                                            ...
# 26  HCM_Federico_Calonge  \n                                            ...
# 27  HCM_Federico_Calonge  \n                                            ...
# 28  HCM_Federico_Calonge  \n                                            ...
# 29  HCM_Federico_Calonge  \n                                            ...
#
#                                      clean_Content_CV  \
# 20  hcm technical consultant working oracle tool p...
# 21  hcm technical consultant working oracle tool p...
# 22  hcm technical consultant working oracle tool p...
# 23  hcm technical consultant working oracle tool p...
# 24  hcm technical consultant working oracle tool p...
# 25  hcm technical consultant working oracle tool p...
# 26  hcm technical consultant working oracle tool p...
# 27  hcm technical consultant working oracle tool p...
# 28  hcm technical consultant working oracle tool p...
# 29  hcm technical consultant working oracle tool p...
#
#                                     tokens_Content_CV  \
# 20  ['hcm', 'technical', 'consultant', 'working', ...
# 21  ['hcm', 'technical', 'consultant', 'working', ...
# 22  ['hcm', 'technical', 'consultant', 'working', ...
# 23  ['hcm', 'technical', 'consultant', 'working', ...
# 24  ['hcm', 'technical', 'consultant', 'working', ...
# 25  ['hcm', 'technical', 'consultant', 'working', ...
# 26  ['hcm', 'technical', 'consultant', 'working', ...
# 27  ['hcm', 'technical', 'consultant', 'working', ...
# 28  ['hcm', 'technical', 'consultant', 'working', ...
# 29  ['hcm', 'technical', 'consultant', 'working', ...
#
#                       Job_Title  \
# 20               Data Scientist
# 21             Data Scientist 2
# 22               HCM Consultant
# 23             HCM Consultant 2
# 24    Machine Learning Engineer
# 25  Machine Learning Engineer 2
# 26          Security Specialist
# 27        Security Specialist 2
# 28     Web Developer Full Stack
# 29   Web Developer Full Stack 2
#
#                                       Job_Description  \
# 20  Master’s degree or above in a STEM field, incl...
# 21  \nReporting to the Director, Data & Analytics,...
# 22  \nThe Oracle Cloud HCM Absence Consultant will...
# 23  4+ years of experience in PeopleSoft or Oracle...
# 24  Leveraging the latest machine and deep learnin...
# 25  Collaborate with a multidisciplinary team to g...
# 26  Work in a fast-paced environment that combine ...
# 27  \n    Handling incoming requests for assistanc...
# 28  \n\n    Graduate Degree in Information Technol...
# 29  \n· Enter existing website codebases and exten...
#
#                                 clean_Job_Description  \
# 20  master degree stem field including limited com...
# 21  reporting director data analytics senior data ...
# 22  oracle cloud hcm absence consultant responsibl...
# 23  peoplesoft oracle eb implementation support hc...
# 24  leveraging latest machine deep learning techni...
# 25  collaborate multidisciplinary team gain insigh...
# 26  fast paced environment combine technical secur...
# 27  handling incoming request assistance business ...
# 28  graduate degree information technology similar...
# 29  enter existing codebases extend functionality ...
#
#                                tokens_Job_Description  tfidf_cosine  \
# 20  ['master', 'degree', 'stem', 'field', 'includi...      0.069849
# 21  ['reporting', 'director', 'data', 'analytics',...      0.083858
# 22  ['oracle', 'cloud', 'hcm', 'absence', 'consult...      0.314486
# 23  ['peoplesoft', 'oracle', 'eb', 'implementation...      0.367655
# 24  ['leveraging', 'latest', 'machine', 'deep_lear...      0.085925
# 25  ['collaborate', 'multidisciplinary', 'team', '...      0.061773
# 26  ['fast', 'paced', 'environment', 'combine', 't...      0.040321
# 27  ['handling', 'incoming', 'request', 'assistanc...      0.032068
# 28  ['graduate', 'degree', 'information', 'technol...      0.021652
# 29  ['enter', 'existing', 'codebases', 'extend', '...      0.056635
#
#     WMD_Job_Desc
# 20         0.904
# 21         0.906
# 22         0.901
# 23         0.932
# 24         0.904
# 25         0.930
# 26         0.899
# 27         0.891
# 28         0.881
# 29         0.920

# %% [markdown]
# Observamos altos valores de similitud para los puestos 'HCM Consultant' y 'HCM Consultant 2' (algo esperado).

# %%
is_Bradly_Johnston =  df_Jobs_and_Candidates['Candidate_Name']=='MLEngineer_Bradly_Johnston'
new_DF = df_Jobs_and_Candidates[is_Bradly_Johnston]
print(new_DF.shape)
new_DF
# Out:
# (10, 10)
#                 Candidate_Name  \
# 40  MLEngineer_Bradly_Johnston
# 41  MLEngineer_Bradly_Johnston
# 42  MLEngineer_Bradly_Johnston
# 43  MLEngineer_Bradly_Johnston
# 44  MLEngineer_Bradly_Johnston
# 45  MLEngineer_Bradly_Johnston
# 46  MLEngineer_Bradly_Johnston
# 47  MLEngineer_Bradly_Johnston
# 48  MLEngineer_Bradly_Johnston
# 49  MLEngineer_Bradly_Johnston
#
#                                            Content_CV  \
# 40  \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
# 41  \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
# 42  \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
# 43  \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
# 44  \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
# 45  \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
# 46  \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
# 47  \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
# 48  \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
# 49  \nBradly Johnston\n435 Kasey Vista, Detroit\n+...
#
#                                      clean_Content_CV  \
# 40  kasey vista detroit senior software engineer m...
# 41  kasey vista detroit senior software engineer m...
# 42  kasey vista detroit senior software engineer m...
# 43  kasey vista detroit senior software engineer m...
# 44  kasey vista detroit senior software engineer m...
# 45  kasey vista detroit senior software engineer m...
# 46  kasey vista detroit senior software engineer m...
# 47  kasey vista detroit senior software engineer m...
# 48  kasey vista detroit senior software engineer m...
# 49  kasey vista detroit senior software engineer m...
#
#                                     tokens_Content_CV  \
# 40  ['kasey', 'vista', 'detroit', 'senior', 'softw...
# 41  ['kasey', 'vista', 'detroit', 'senior', 'softw...
# 42  ['kasey', 'vista', 'detroit', 'senior', 'softw...
# 43  ['kasey', 'vista', 'detroit', 'senior', 'softw...
# 44  ['kasey', 'vista', 'detroit', 'senior', 'softw...
# 45  ['kasey', 'vista', 'detroit', 'senior', 'softw...
# 46  ['kasey', 'vista', 'detroit', 'senior', 'softw...
# 47  ['kasey', 'vista', 'detroit', 'senior', 'softw...
# 48  ['kasey', 'vista', 'detroit', 'senior', 'softw...
# 49  ['kasey', 'vista', 'detroit', 'senior', 'softw...
#
#                       Job_Title  \
# 40               Data Scientist
# 41             Data Scientist 2
# 42               HCM Consultant
# 43             HCM Consultant 2
# 44    Machine Learning Engineer
# 45  Machine Learning Engineer 2
# 46          Security Specialist
# 47        Security Specialist 2
# 48     Web Developer Full Stack
# 49   Web Developer Full Stack 2
#
#                                       Job_Description  \
# 40  Master’s degree or above in a STEM field, incl...
# 41  \nReporting to the Director, Data & Analytics,...
# 42  \nThe Oracle Cloud HCM Absence Consultant will...
# 43  4+ years of experience in PeopleSoft or Oracle...
# 44  Leveraging the latest machine and deep learnin...
# 45  Collaborate with a multidisciplinary team to g...
# 46  Work in a fast-paced environment that combine ...
# 47  \n    Handling incoming requests for assistanc...
# 48  \n\n    Graduate Degree in Information Technol...
# 49  \n· Enter existing website codebases and exten...
#
#                                 clean_Job_Description  \
# 40  master degree stem field including limited com...
# 41  reporting director data analytics senior data ...
# 42  oracle cloud hcm absence consultant responsibl...
# 43  peoplesoft oracle eb implementation support hc...
# 44  leveraging latest machine deep learning techni...
# 45  collaborate multidisciplinary team gain insigh...
# 46  fast paced environment combine technical secur...
# 47  handling incoming request assistance business ...
# 48  graduate degree information technology similar...
# 49  enter existing codebases extend functionality ...
#
#                                tokens_Job_Description  tfidf_cosine  \
# 40  ['master', 'degree', 'stem', 'field', 'includi...      0.196025
# 41  ['reporting', 'director', 'data', 'analytics',...      0.346808
# 42  ['oracle', 'cloud', 'hcm', 'absence', 'consult...      0.059270
# 43  ['peoplesoft', 'oracle', 'eb', 'implementation...      0.058595
# 44  ['leveraging', 'latest', 'machine', 'deep_lear...      0.286638
# 45  ['collaborate', 'multidisciplinary', 'team', '...      0.333604
# 46  ['fast', 'paced', 'environment', 'combine', 't...      0.064902
# 47  ['handling', 'incoming', 'request', 'assistanc...      0.044034
# 48  ['graduate', 'degree', 'information', 'technol...      0.048537
# 49  ['enter', 'existing', 'codebases', 'extend', '...      0.066777
#
#     WMD_Job_Desc
# 40         0.924
# 41         0.910
# 42         0.898
# 43         0.923
# 44         0.924
# 45         0.941
# 46         0.918
# 47         0.898
# 48         0.905
# 49         0.927

# %% [markdown]
# ### 3-Exportamos el CSV con los resultados para utilizarlo en el Notebook "2-KMEANS_&_KNN".

# %%
#Exportamos el csv:
df_Jobs_and_Candidates.to_csv('DF_Exportado_Jobs_And_Candidates_own_model.csv',index = False)
#Si lo queremos importar:
DF_J_and_C = pd.read_csv('DF_Exportado_Jobs_And_Candidates_own_model.csv')
DF_J_and_C.tail()
# Out:
#       Candidate_Name                                         Content_CV  \
# 6245  386-CONSULTANT           MARKETING CONSULTANT           Summar...
# 6246  386-CONSULTANT           MARKETING CONSULTANT           Summar...
# 6247  386-CONSULTANT           MARKETING CONSULTANT           Summar...
# 6248  386-CONSULTANT           MARKETING CONSULTANT           Summar...
# 6249  386-CONSULTANT           MARKETING CONSULTANT           Summar...
#
#                                        clean_Content_CV  \
# 6245  marketing consultant value creator marketing e...
# 6246  marketing consultant value creator marketing e...
# 6247  marketing consultant value creator marketing e...
# 6248  marketing consultant value creator marketing e...
# 6249  marketing consultant value creator marketing e...
#
#                                       tokens_Content_CV  \
# 6245  ['marketing', 'consultant', 'value', 'creator'...
# 6246  ['marketing', 'consultant', 'value', 'creator'...
# 6247  ['marketing', 'consultant', 'value', 'creator'...
# 6248  ['marketing', 'consultant', 'value', 'creator'...
# 6249  ['marketing', 'consultant', 'value', 'creator'...
#
#                         Job_Title  \
# 6245  Machine Learning Engineer 2
# 6246          Security Specialist
# 6247        Security Specialist 2
# 6248     Web Developer Full Stack
# 6249   Web Developer Full Stack 2
#
#                                         Job_Description  \
# 6245  Collaborate with a multidisciplinary team to g...
# 6246  Work in a fast-paced environment that combine ...
# 6247  \n    Handling incoming requests for assistanc...
# 6248  \n\n    Graduate Degree in Information Technol...
# 6249  \n· Enter existing website codebases and exten...
#
#                                   clean_Job_Description  \
# 6245  collaborate multidisciplinary team gain insigh...
# 6246  fast paced environment combine technical secur...
# 6247  handling incoming request assistance business ...
# 6248  graduate degree information technology similar...
# 6249  enter existing codebases extend functionality ...
#
#                                  tokens_Job_Description  tfidf_cosine  \
# 6245  ['collaborate', 'multidisciplinary', 'team', '...      0.041610
# 6246  ['fast', 'paced', 'environment', 'combine', 't...      0.071639
# 6247  ['handling', 'incoming', 'request', 'assistanc...      0.041386
# 6248  ['graduate', 'degree', 'information', 'technol...      0.029146
# 6249  ['enter', 'existing', 'codebases', 'extend', '...      0.038411
#
#       WMD_Job_Desc
# 6245         0.927
# 6246         0.937
# 6247         0.910
# 6248         0.910
# 6249         0.936
